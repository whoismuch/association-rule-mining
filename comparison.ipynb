# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpgrowth
from mlxtend.frequent_patterns import association_rules
import time

# %%
data = pd.read_csv('Market_Basket_Optimisation.csv', header=None)
data
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# 0     green grapes  whole weat flour  yams  cottage cheese  energy drink
# 1              NaN               NaN   NaN             NaN           NaN
# 2              NaN               NaN   NaN             NaN           NaN
# 3              NaN               NaN   NaN             NaN           NaN
# 4        green tea               NaN   NaN             NaN           NaN
# ...            ...               ...   ...             ...           ...
# 7496           NaN               NaN   NaN             NaN           NaN
# 7497     magazines         green tea   NaN             NaN           NaN
# 7498           NaN               NaN   NaN             NaN           NaN
# 7499           NaN               NaN   NaN             NaN           NaN
# 7500           NaN               NaN   NaN             NaN           NaN
#
#                 9               10         11     12     13             14  \
# 0     tomato juice  low fat yogurt  green tea  honey  salad  mineral water
# 1              NaN             NaN        NaN    NaN    NaN            NaN
# 2              NaN             NaN        NaN    NaN    NaN            NaN
# 3              NaN             NaN        NaN    NaN    NaN            NaN
# 4              NaN             NaN        NaN    NaN    NaN            NaN
# ...            ...             ...        ...    ...    ...            ...
# 7496           NaN             NaN        NaN    NaN    NaN            NaN
# 7497           NaN             NaN        NaN    NaN    NaN            NaN
# 7498           NaN             NaN        NaN    NaN    NaN            NaN
# 7499           NaN             NaN        NaN    NaN    NaN            NaN
# 7500           NaN             NaN        NaN    NaN    NaN            NaN
#
#           15                 16               17       18         19
# 0     salmon  antioxydant juice  frozen smoothie  spinach  olive oil
# 1        NaN                NaN              NaN      NaN        NaN
# 2        NaN                NaN              NaN      NaN        NaN
# 3        NaN                NaN              NaN      NaN        NaN
# 4        NaN                NaN              NaN      NaN        NaN
# ...      ...                ...              ...      ...        ...
# 7496     NaN                NaN              NaN      NaN        NaN
# 7497     NaN                NaN              NaN      NaN        NaN
# 7498     NaN                NaN              NaN      NaN        NaN
# 7499     NaN                NaN              NaN      NaN        NaN
# 7500     NaN                NaN              NaN      NaN        NaN
#
# [7501 rows x 20 columns]

# %%
processed_dataset = [[value for value in row if not pd.isnull(value)] for row in data.values.tolist()]
dataset = processed_dataset
dataset
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
#   'low fat yogurt'],
#  ['turkey', 'eggs'],
#  ['turkey',
#   'fresh tuna',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'black tea',
#   'salmon',
#   'eggs',
#   'chicken',
#   'extra dark chocolate'],
#  ['meatballs', 'milk', 'honey', 'french fries', 'protein bar'],
#  ['red wine', 'shrimp', 'pasta', 'pepper', 'eggs', 'chocolate', 'shampoo'],
#  ['rice', 'sparkling water'],
#  ['spaghetti', 'mineral water', 'ham', 'body spray', 'pancakes', 'green tea'],
#  ['burgers',
#   'grated cheese',
#   'shrimp',
#   'pasta',
#   'avocado',
#   'honey',
#   'white wine',
#   'toothpaste'],
#  ['eggs'],
#  ['parmesan cheese', 'spaghetti', 'soup', 'avocado', 'milk', 'fresh bread'],
#  ['ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'energy bar',
#   'black tea',
#   'salmon',
#   'frozen smoothie',
#   'escalope'],
#  ['sparkling water'],
#  ['mineral water', 'eggs', 'chicken', 'chocolate', 'french fries'],
#  ['frozen vegetables', 'spaghetti', 'yams', 'mineral water'],
#  ['herb & pepper', 'tomato sauce', 'light cream', 'magazines'],
#  ['mineral water', 'chocolate', 'avocado', 'eggs'],
#  ['turkey', 'french fries', 'strawberries'],
#  ['frozen vegetables', 'strong cheese', 'chocolate'],
#  ['cookies'],
#  ['pickles', 'spaghetti', 'salmon', 'escalope'],
#  ['energy bar', 'french fries'],
#  ['red wine', 'ground beef', 'mineral water'],
#  ['mineral water', 'cake', 'cottage cheese'],
#  ['pickles', 'champagne', 'green tea'],
#  ['spaghetti'],
#  ['fresh tuna',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'honey',
#   'whole wheat rice',
#   'frozen smoothie',
#   'escalope'],
#  ['spaghetti'],
#  ['soup', 'meatballs', 'hot dogs', 'sparkling water'],
#  ['escalope'],
#  ['soup',
#   'avocado',
#   'french fries',
#   'hot dogs',
#   'brownies',
#   'body spray',
#   'pancakes',
#   'green tea'],
#  ['mineral water', 'chicken', 'cereals', 'clothes accessories'],
#  ['mineral water', 'bug spray'],
#  ['avocado', 'muffins'],
#  ['burgers', 'black tea', 'green tea'],
#  ['spaghetti', 'chocolate', 'brownies', 'white wine', 'green tea'],
#  ['fresh tuna', 'mineral water', 'eggs'],
#  ['spaghetti', 'muffins'],
#  ['spaghetti', 'chocolate'],
#  ['french fries', 'escalope', 'champagne'],
#  ['tomato sauce', 'light mayo'],
#  ['turkey',
#   'fresh tuna',
#   'frozen vegetables',
#   'tomatoes',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'milk',
#   'olive oil'],
#  ['eggs', 'cookies'],
#  ['soup',
#   'chicken',
#   'gums',
#   'soda',
#   'body spray',
#   'energy drink',
#   'green tea'],
#  ['turkey',
#   'frozen vegetables',
#   'mineral water',
#   'cider',
#   'cooking oil',
#   'green tea'],
#  ['spaghetti'],
#  ['clothes accessories'],
#  ['energy drink'],
#  ['soup', 'bug spray', 'shallot', 'protein bar', 'green tea'],
#  ['turkey', 'eggs'],
#  ['french fries'],
#  ['chocolate', 'milk'],
#  ['herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'avocado',
#   'cider',
#   'whole wheat rice'],
#  ['cookies'],
#  ['shrimp', 'pasta'],
#  ['grated cheese', 'herb & pepper', 'tomatoes', 'tomato sauce', 'corn'],
#  ['burgers', 'escalope', 'shallot'],
#  ['cookies'],
#  ['yogurt cake'],
#  ['soup', 'eggs'],
#  ['cookies'],
#  ['mineral water', 'chocolate', 'low fat yogurt'],
#  ['eggs', 'strawberries'],
#  ['grated cheese', 'ground beef', 'spaghetti', 'mineral water', 'white wine'],
#  ['mint'],
#  ['eggs', 'cake', 'french fries'],
#  ['burgers', 'spaghetti', 'milk', 'french fries', 'green tea'],
#  ['mineral water', 'energy bar', 'butter', 'french fries'],
#  ['burgers',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'eggs',
#   'cooking oil'],
#  ['energy bar'],
#  ['energy bar', 'energy drink'],
#  ['chocolate', 'frozen smoothie'],
#  ['low fat yogurt'],
#  ['asparagus', 'salad'],
#  ['burgers', 'french fries', 'low fat yogurt', 'green tea'],
#  ['low fat yogurt'],
#  ['burgers',
#   'herb & pepper',
#   'shrimp',
#   'pasta',
#   'spaghetti',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'energy bar',
#   'french wine',
#   'eggs',
#   'salt'],
#  ['champagne', 'low fat yogurt'],
#  ['champagne'],
#  ['burgers', 'almonds', 'eggs', 'french fries', 'cookies', 'green tea'],
#  ['ham', 'soup', 'escalope', 'body spray'],
#  ['turkey',
#   'ham',
#   'frozen vegetables',
#   'pepper',
#   'oil',
#   'extra dark chocolate',
#   'tea',
#   'magazines'],
#  ['muffins', 'eggs', 'cookies'],
#  ['cookies'],
#  ['frozen vegetables',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'green tea'],
#  ['mineral water', 'barbecue sauce', 'chocolate'],
#  ['burgers',
#   'herb & pepper',
#   'energy bar',
#   'almonds',
#   'eggs',
#   'corn',
#   'mayonnaise',
#   'zucchini'],
#  ['turkey',
#   'burgers',
#   'ground beef',
#   'chocolate',
#   'soup',
#   'almonds',
#   'eggs',
#   'hot dogs',
#   'cottage cheese'],
#  ['ham', 'spaghetti', 'chocolate', 'eggs'],
#  ['ground beef', 'energy bar', 'pet food', 'carrots', 'protein bar'],
#  ['ground beef',
#   'tomato sauce',
#   'spaghetti',
#   'mineral water',
#   'almonds',
#   'eggs'],
#  ['mineral water', 'olive oil', 'gums', 'cooking oil'],
#  ['shrimp',
#   'pasta',
#   'mineral water',
#   'soup',
#   'avocado',
#   'milk',
#   'olive oil',
#   'green grapes',
#   'eggs',
#   'bug spray'],
#  ['shrimp',
#   'pasta',
#   'soup',
#   'cake',
#   'cooking oil',
#   'chicken',
#   'light mayo',
#   'low fat yogurt'],
#  ['spaghetti',
#   'mineral water',
#   'chocolate',
#   'french fries',
#   'champagne',
#   'escalope',
#   'mushroom cream sauce',
#   'fresh bread'],
#  ['shrimp', 'pasta', 'mineral water', 'eggs'],
#  ['burgers', 'oil', 'tomato juice', 'fresh bread'],
#  ['french wine', 'eggs', 'chocolate', 'low fat yogurt'],
#  ['chicken', 'eggs', 'french fries', 'pancakes'],
#  ['turkey', 'herb & pepper', 'salmon', 'white wine', 'candy bars'],
#  ['grated cheese',
#   'spaghetti',
#   'olive oil',
#   'eggs',
#   'french fries',
#   'green tea'],
#  ['mineral water', 'energy bar'],
#  ['eggs', 'french fries'],
#  ['burgers',
#   'tomatoes',
#   'mineral water',
#   'soup',
#   'milk',
#   'almonds',
#   'eggs',
#   'chocolate',
#   'tomato juice'],
#  ['muffins'],
#  ['pasta'],
#  ['tomatoes', 'spaghetti', 'frozen smoothie'],
#  ['ground beef', 'spaghetti', 'milk'],
#  ['french fries'],
#  ['chocolate', 'milk'],
#  ['burgers',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'eggs',
#   'chocolate',
#   'french fries',
#   'pancakes',
#   'low fat yogurt'],
#  ['ground beef', 'mineral water', 'antioxydant juice', 'protein bar'],
#  ['grated cheese',
#   'whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'cake',
#   'energy drink'],
#  ['grated cheese'],
#  ['pancakes'],
#  ['frozen smoothie'],
#  ['carrots', 'green tea'],
#  ['chocolate'],
#  ['turkey',
#   'burgers',
#   'chocolate',
#   'olive oil',
#   'eggs',
#   'cooking oil',
#   'corn'],
#  ['frozen vegetables',
#   'tomatoes',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'pancakes',
#   'chicken',
#   'chili',
#   'tea',
#   'french fries',
#   'tomato juice',
#   'fresh bread'],
#  ['cookies'],
#  ['ground beef'],
#  ['turkey', 'eggs', 'chocolate', 'frozen smoothie', 'tomato juice'],
#  ['frozen vegetables', 'cooking oil', 'mashed potato'],
#  ['frozen vegetables',
#   'ground beef',
#   'tomato sauce',
#   'mineral water',
#   'meatballs',
#   'olive oil',
#   'light cream',
#   'tomato juice'],
#  ['red wine',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'milk',
#   'eggs',
#   'cake',
#   'gums',
#   'cooking oil',
#   'chocolate',
#   'frozen smoothie'],
#  ['chocolate',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'avocado',
#   'milk',
#   'olive oil',
#   'eggs',
#   'rice',
#   'french fries',
#   'brownies'],
#  ['chocolate',
#   'shrimp',
#   'pasta',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'nonfat milk',
#   'eggs'],
#  ['turkey',
#   'shrimp',
#   'pasta',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'eggs',
#   'chicken',
#   'french fries'],
#  ['cookies'],
#  ['turkey', 'tomatoes', 'cake'],
#  ['yams',
#   'mineral water',
#   'soup',
#   'milk',
#   'pancakes',
#   'whole wheat rice',
#   'barbecue sauce',
#   'carrots',
#   'chocolate',
#   'champagne'],
#  ['rice'],
#  ['chocolate', 'milk'],
#  ['shrimp', 'pasta', 'frozen vegetables', 'water spray'],
#  ['burgers', 'mineral water', 'milk', 'eggs', 'whole wheat rice', 'mint'],
#  ['mineral water', 'vegetables mix', 'cake', 'frozen smoothie', 'brownies'],
#  ['cookies'],
#  ['shrimp', 'pasta', 'chicken', 'chocolate bread'],
#  ['shallot'],
#  ['shrimp', 'pasta', 'spaghetti', 'eggs', 'hot dogs', 'green tea'],
#  ['burgers'],
#  ['red wine',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'strong cheese',
#   'light cream',
#   'cooking oil'],
#  ['burgers',
#   'grated cheese',
#   'spaghetti',
#   'avocado',
#   'milk',
#   'oil',
#   'french fries'],
#  ['herb & pepper',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'olive oil'],
#  ['shrimp', 'pasta', 'yams', 'milk', 'chocolate'],
#  ['butter', 'green tea'],
#  ['light mayo'],
#  ['low fat yogurt'],
#  ['herb & pepper', 'shrimp', 'pasta', 'spaghetti', 'milk'],
#  ['burgers', 'eggs'],
#  ['turkey',
#   'herb & pepper',
#   'ground beef',
#   'soup',
#   'avocado',
#   'milk',
#   'black tea',
#   'eggs',
#   'barbecue sauce',
#   'carrots',
#   'cookies',
#   'tomato juice',
#   'fresh bread'],
#  ['cookies'],
#  ['escalope'],
#  ['pepper', 'french fries', 'strawberries', 'pancakes', 'low fat yogurt'],
#  ['frozen vegetables', 'yams', 'chicken', 'honey', 'light mayo'],
#  ['chocolate', 'champagne'],
#  ['herb & pepper', 'honey', 'cake', 'rice', 'protein bar'],
#  ['burgers',
#   'chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'milk',
#   'light mayo',
#   'asparagus'],
#  ['chocolate', 'mineral water', 'corn', 'cottage cheese', 'green tea'],
#  ['muffins'],
#  ['ham', 'french wine', 'escalope'],
#  ['spaghetti', 'milk', 'whole wheat rice', 'mint green tea'],
#  ['chocolate', 'body spray'],
#  ['frozen vegetables', 'french fries', 'hot dogs'],
#  ['candy bars'],
#  ['burgers',
#   'shrimp',
#   'pasta',
#   'milk',
#   'green tea',
#   'french fries',
#   'cookies',
#   'white wine'],
#  ['parmesan cheese', 'ground beef'],
#  ['pancakes', 'whole wheat rice', 'candy bars'],
#  ['eggs', 'eggplant', 'cookies'],
#  ['frozen vegetables', 'mineral water'],
#  ['chocolate'],
#  ['turkey', 'spaghetti', 'milk', 'whole wheat rice', 'chocolate'],
#  ['whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'soup',
#   'meatballs',
#   'chicken',
#   'blueberries',
#   'cooking oil',
#   'champagne',
#   'yogurt cake',
#   'protein bar'],
#  ['cooking oil', 'tomato juice'],
#  ['frozen vegetables', 'milk', 'eggs', 'french fries', 'green tea'],
#  ['fresh tuna',
#   'spaghetti',
#   'olive oil',
#   'french wine',
#   'eggs',
#   'french fries',
#   'champagne',
#   'pancakes',
#   'light mayo'],
#  ['red wine', 'honey', 'hot dogs'],
#  ['milk', 'bacon', 'eggs', 'french fries', 'fresh bread'],
#  ['french fries', 'yogurt cake'],
#  ['milk'],
#  ['french fries'],
#  ['chocolate'],
#  ['burgers', 'ham', 'red wine'],
#  ['shrimp',
#   'pasta',
#   'tomatoes',
#   'energy bar',
#   'french wine',
#   'antioxydant juice',
#   'french fries',
#   'frozen smoothie',
#   'brownies'],
#  ['green tea'],
#  ['low fat yogurt'],
#  ['turkey',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'spinach',
#   'soda',
#   'energy drink',
#   'salt'],
#  ['turkey', 'eggs'],
#  ['bug spray', 'hot dogs'],
#  ['oil'],
#  ['soup',
#   'energy bar',
#   'chicken',
#   'eggs',
#   'cake',
#   'french fries',
#   'body spray',
#   'strawberries'],
#  ['spaghetti', 'chocolate', 'yogurt cake'],
#  ['turkey', 'mineral water', 'meatballs'],
#  ['ground beef',
#   'mineral water',
#   'chocolate',
#   'fromage blanc',
#   'bacon',
#   'hot dogs'],
#  ['frozen vegetables', 'mineral water', 'vegetables mix', 'escalope'],
#  ['herb & pepper', 'red wine', 'tomatoes'],
#  ['whole wheat pasta', 'olive oil', 'cereals', 'brownies', 'green tea'],
#  ['cookies'],
#  ['olive oil', 'cookies', 'mushroom cream sauce'],
#  ['ground beef', 'pancakes', 'cooking oil', 'gluten free bar', 'light mayo'],
#  ['mineral water', 'french fries'],
#  ['herb & pepper'],
#  ['salmon'],
#  ['eggs', 'escalope'],
#  ['mineral water', 'tomato juice'],
#  ['mineral water'],
#  ['shrimp', 'mineral water', 'soup', 'black tea'],
#  ['cake', 'frozen smoothie'],
#  ['turkey',
#   'burgers',
#   'grated cheese',
#   'tomatoes',
#   'chocolate',
#   'fromage blanc',
#   'honey',
#   'whole wheat rice'],
#  ['frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'olive oil',
#   'pancakes'],
#  ['turkey',
#   'burgers',
#   'ground beef',
#   'milk',
#   'olive oil',
#   'cake',
#   'fresh bread'],
#  ['whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'soup',
#   'chutney',
#   'cereals',
#   'energy drink',
#   'protein bar'],
#  ['eggs', 'whole wheat rice', 'cake', 'green tea', 'escalope'],
#  ['ground beef', 'yams', 'soup', 'avocado', 'salmon', 'green tea'],
#  ['milk'],
#  ['spaghetti', 'chocolate'],
#  ['whole wheat pasta', 'honey'],
#  ['whole wheat pasta', 'green tea'],
#  ['spaghetti', 'meatballs', 'vegetables mix', 'chocolate'],
#  ['eggs', 'low fat yogurt'],
#  ['fresh tuna',
#   'shrimp',
#   'pasta',
#   'mineral water',
#   'olive oil',
#   'eggs',
#   'cake',
#   'brownies',
#   'tomato juice'],
#  ['mineral water', 'green grapes', 'hot dogs', 'fresh bread'],
#  ['frozen vegetables', 'meatballs', 'eggs', 'chocolate'],
#  ['chocolate'],
#  ['meatballs', 'milk'],
#  ['low fat yogurt'],
#  ['green tea'],
#  ['escalope', 'pasta'],
#  ['pepper',
#   'chocolate',
#   'olive oil',
#   'french wine',
#   'salmon',
#   'rice',
#   'light mayo',
#   'fresh bread',
#   'magazines'],
#  ['red wine',
#   'french wine',
#   'vegetables mix',
#   'rice',
#   'clothes accessories',
#   'hot dogs',
#   'green tea'],
#  ['burgers',
#   'dessert wine',
#   'spaghetti',
#   'chicken',
#   'cake',
#   'protein bar',
#   'green tea'],
#  ['french wine', 'cake', 'fresh bread'],
#  ['burgers', 'frozen vegetables', 'flax seed', 'eggs'],
#  ['red wine'],
#  ['pepper', 'mineral water', 'energy bar', 'green grapes'],
#  ['milk', 'eggs', 'cake', 'chocolate', 'french fries', 'green tea'],
#  ['french fries'],
#  ['almonds'],
#  ['burgers', 'mineral water', 'green tea'],
#  ['milk', 'pancakes'],
#  ['pancakes', 'eggs', 'salt', 'tomato juice'],
#  ['mineral water'],
#  ['ham', 'spaghetti', 'mineral water', 'olive oil'],
#  ['salt', 'tomato juice', 'fresh bread'],
#  ['spaghetti', 'mushroom cream sauce'],
#  ['spaghetti', 'mineral water', 'eggs', 'pet food'],
#  ['frozen vegetables', 'spaghetti'],
#  ['energy drink'],
#  ['muffins'],
#  ['turkey', 'milk'],
#  ['cookies'],
#  ['chocolate'],
#  ['spaghetti',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   'chocolate',
#   'escalope'],
#  ['shrimp', 'frozen vegetables', 'pepper', 'spaghetti', 'green tea'],
#  ['burgers',
#   'fresh tuna',
#   'red wine',
#   'mineral water',
#   'french fries',
#   'hand protein bar',
#   'low fat yogurt'],
#  ['pancakes', 'eggs', 'energy drink', 'fresh bread'],
#  ['strong cheese',
#   'salmon',
#   'green tea',
#   'french fries',
#   'frozen smoothie',
#   'hot dogs'],
#  ['grated cheese',
#   'shrimp',
#   'pasta',
#   'tomatoes',
#   'milk',
#   'frozen smoothie',
#   'sandwich'],
#  ['herb & pepper', 'whole wheat pasta', 'olive oil', 'pancakes', 'eggs'],
#  ['spaghetti', 'antioxydant juice'],
#  ['chocolate', 'milk', 'almonds', 'eggs', 'strawberries', 'white wine'],
#  ['french fries', 'strawberries'],
#  ['mineral water'],
#  ['eggs'],
#  ['escalope'],
#  ['cake'],
#  ['whole wheat pasta', 'antioxydant juice', 'body spray', 'green tea'],
#  ['mineral water', 'oil', 'frozen smoothie'],
#  ['french fries', 'champagne'],
#  ['chocolate', 'french fries'],
#  ['frozen vegetables', 'spaghetti', 'eggs'],
#  ['hot dogs'],
#  ['chocolate', 'cookies'],
#  ['pancakes'],
#  ['shrimp', 'butter', 'chicken', 'salmon'],
#  ['chocolate', 'cookies', 'babies food'],
#  ['pepper', 'spaghetti', 'cake', 'chocolate', 'french fries', 'fresh bread'],
#  ['avocado', 'oil', 'cereals', 'french fries'],
#  ['herb & pepper',
#   'spaghetti',
#   'mineral water',
#   'spinach',
#   'eggs',
#   'oil',
#   'cooking oil',
#   'green tea',
#   'shampoo',
#   'tomato juice',
#   'low fat yogurt'],
#  ['herb & pepper',
#   'frozen vegetables',
#   'ground beef',
#   'pepper',
#   'spaghetti',
#   'mint green tea',
#   'french fries'],
#  ['french fries'],
#  ['green tea', 'tomato juice'],
#  ['eggs', 'whole wheat rice', 'chocolate'],
#  ['grated cheese',
#   'herb & pepper',
#   'red wine',
#   'spaghetti',
#   'mineral water',
#   'salmon',
#   'eggs',
#   'cooking oil',
#   'green tea'],
#  ['french fries',
#   'cookies',
#   'shallot',
#   'tomato juice',
#   'fresh bread',
#   'low fat yogurt'],
#  ['burgers', 'fresh tuna', 'spaghetti', 'muffins', 'honey'],
#  ['herb & pepper', 'ground beef', 'spaghetti', 'eggs', 'chicken'],
#  ['grated cheese', 'muffins', 'tomato juice', 'mayonnaise'],
#  ['whole wheat pasta',
#   'yams',
#   'mineral water',
#   'muffins',
#   'frozen smoothie',
#   'hot dogs',
#   'energy drink'],
#  ['burgers',
#   'spaghetti',
#   'soup',
#   'milk',
#   'olive oil',
#   'salmon',
#   'eggs',
#   'blueberries'],
#  ['chocolate', 'champagne', 'magazines'],
#  ['frozen vegetables',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'french wine',
#   'green grapes',
#   'rice',
#   'chocolate'],
#  ['tomato sauce', 'chocolate'],
#  ['milk', 'eggs'],
#  ['pet food'],
#  ['yogurt cake'],
#  ['green tea'],
#  ['escalope', 'pasta'],
#  ['herb & pepper', 'ground beef'],
#  ['mineral water', 'honey', 'brownies'],
#  ['turkey', 'eggs', 'cake', 'energy drink'],
#  ['turkey',
#   'burgers',
#   'dessert wine',
#   'ground beef',
#   'soup',
#   'salmon',
#   'eggs',
#   'gums',
#   'tomato juice',
#   'candy bars'],
#  ['spaghetti', 'mineral water', 'chicken'],
#  ['turkey', 'ground beef', 'carrots', 'french fries', 'melons'],
#  ['mineral water', 'eggs', 'low fat yogurt'],
#  ['turkey', 'cooking oil', 'shampoo'],
#  ['spaghetti', 'hot dogs'],
#  ['chocolate', 'green tea'],
#  ['grated cheese',
#   'pepper',
#   'mineral water',
#   'chocolate',
#   'eggs',
#   'cake',
#   'mashed potato',
#   'tomato juice'],
#  ['chocolate'],
#  ['spaghetti', 'olive oil', 'strong cheese', 'pancakes'],
#  ['red wine', 'mineral water', 'soup', 'rice', 'cookies'],
#  ['red wine', 'shrimp', 'spaghetti'],
#  ['green tea'],
#  ['mineral water', 'chicken', 'french fries', 'frozen smoothie'],
#  ['muffins'],
#  ['cake', 'chocolate'],
#  ['fresh tuna',
#   'tomatoes',
#   'mineral water',
#   'soup',
#   'avocado',
#   'meatballs',
#   'olive oil'],
#  ['turkey', 'french fries'],
#  ['burgers',
#   'turkey',
#   'herb & pepper',
#   'ground beef',
#   'pancakes',
#   'eggs',
#   'light cream',
#   'rice',
#   'champagne',
#   'fresh bread'],
#  ['escalope'],
#  ['chocolate', 'escalope', 'fresh bread'],
#  ['ham',
#   'spaghetti',
#   'french wine',
#   'vegetables mix',
#   'chocolate',
#   'french fries'],
#  ['avocado', 'light mayo'],
#  ['spaghetti', 'yams', 'butter', 'chocolate'],
#  ['energy bar', 'eggs', 'french fries'],
#  ['fresh tuna', 'barbecue sauce', 'eggplant'],
#  ['energy drink'],
#  ['whole wheat rice', 'french fries', 'hot dogs', 'green tea'],
#  ['mineral water', 'chicken', 'green tea'],
#  ['eggs', 'cake', 'mushroom cream sauce'],
#  ['escalope'],
#  ['antioxydant juice', 'escalope'],
#  ['shrimp', 'spaghetti', 'french fries'],
#  ['grated cheese', 'spaghetti', 'salmon', 'tomato juice'],
#  ['spaghetti', 'green tea'],
#  ['champagne', 'protein bar'],
#  ['mineral water', 'avocado', 'chocolate'],
#  ['tomatoes', 'champagne', 'green tea'],
#  ['chicken', 'french fries', 'escalope'],
#  ['frozen vegetables',
#   'tomatoes',
#   'eggs',
#   'green tea',
#   'frozen smoothie',
#   'light mayo'],
#  ['ground beef',
#   'chicken',
#   'cider',
#   'green grapes',
#   'honey',
#   'chocolate',
#   'french fries',
#   'champagne',
#   'frozen smoothie',
#   'escalope'],
#  ['french fries', 'champagne'],
#  ['mineral water', 'soup'],
#  ['frozen vegetables', 'spaghetti', 'milk', 'chocolate', 'babies food'],
#  ['honey', 'whole wheat rice'],
#  ['whole wheat rice', 'chicken', 'tomato juice'],
#  ['pancakes'],
#  ['green tea', 'protein bar', 'tomato juice', 'candy bars'],
#  ['french fries'],
#  ['mineral water'],
#  ['escalope'],
#  ['grated cheese',
#   'herb & pepper',
#   'whole wheat pasta',
#   'yams',
#   'mineral water',
#   'bacon',
#   'nonfat milk',
#   'spinach'],
#  ['spaghetti', 'milk'],
#  ['milk', 'chocolate', 'white wine'],
#  ['sandwich'],
#  ['chocolate', 'light mayo'],
#  ['shrimp',
#   'whole wheat pasta',
#   'spaghetti',
#   'meatballs',
#   'chicken',
#   'frozen smoothie',
#   'tomato juice'],
#  ['red wine', 'ground beef', 'spaghetti', 'mineral water', 'eggs'],
#  ['yams', 'melons'],
#  ['spaghetti', 'cooking oil'],
#  ['french fries'],
#  ['mineral water',
#   'milk',
#   'spinach',
#   'cooking oil',
#   'chocolate',
#   'frozen smoothie',
#   'hot dogs'],
#  ['tomato sauce', 'milk'],
#  ['shrimp', 'cider', 'eggs', 'french fries'],
#  ['champagne'],
#  ['salad'],
#  ['french fries'],
#  ['frozen vegetables',
#   'mineral water',
#   'energy bar',
#   'honey',
#   'rice',
#   'green tea'],
#  ['french fries', 'salad'],
#  ['honey', 'chocolate', 'french fries', 'brownies'],
#  ['green tea', 'strawberries', 'gluten free bar'],
#  ['frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'salmon',
#   'honey',
#   'extra dark chocolate',
#   'green tea',
#   'mushroom cream sauce',
#   'gluten free bar'],
#  ['grated cheese', 'tomatoes', 'mineral water', 'meatballs'],
#  ['shrimp', 'chocolate', 'water spray'],
#  ['turkey'],
#  ['turkey', 'eggs'],
#  ['turkey',
#   'frozen vegetables',
#   'tomatoes',
#   'soup',
#   'butter',
#   'french wine',
#   'pancakes',
#   'eggs',
#   'tomato juice',
#   'fresh bread',
#   'green tea'],
#  ['spaghetti'],
#  ['milk', 'frozen smoothie', 'low fat yogurt'],
#  ['burgers',
#   'mineral water',
#   'milk',
#   'whole wheat rice',
#   'cereals',
#   'chocolate',
#   'french fries'],
#  ['mineral water'],
#  ['tomatoes', 'mineral water', 'soup', 'cake', 'chocolate'],
#  ['mineral water'],
#  ['ground beef', 'spaghetti'],
#  ['pepper', 'frozen smoothie'],
#  ['yogurt cake'],
#  ['red wine', 'pancakes'],
#  ['candy bars'],
#  ['eggs', 'french fries', 'low fat yogurt'],
#  ['cookies'],
#  ['cookies'],
#  ['spaghetti',
#   'soup',
#   'vegetables mix',
#   'spinach',
#   'french fries',
#   'escalope',
#   'cauliflower',
#   'toothpaste'],
#  ['cookies'],
#  ['soup', 'olive oil', 'eggs', 'soda', 'corn'],
#  ['chocolate', 'frozen smoothie', 'low fat yogurt'],
#  ['spaghetti',
#   'mineral water',
#   'milk',
#   'pancakes',
#   'chocolate',
#   'french fries'],
#  ['mineral water'],
#  ['herb & pepper',
#   'frozen vegetables',
#   'tomato sauce',
#   'mineral water',
#   'soup',
#   'milk',
#   'olive oil',
#   'almonds'],
#  ['burgers', 'eggs'],
#  ['french fries'],
#  ['frozen smoothie', 'cottage cheese'],
#  ['tomatoes', 'mineral water', 'chocolate', 'light mayo'],
#  ['salmon',
#   'escalope',
#   'shallot',
#   'strawberries',
#   'fresh bread',
#   'low fat yogurt'],
#  ['energy bar'],
#  ['red wine',
#   'ground beef',
#   'spaghetti',
#   'pancakes',
#   'blueberries',
#   'oil',
#   'cooking oil',
#   'tomato juice'],
#  ['ground beef',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'frozen smoothie',
#   'champagne'],
#  ['cookies'],
#  ['salmon', 'escalope'],
#  ['cookies'],
#  ['low fat yogurt'],
#  ['eggs'],
#  ['red wine', 'butter', 'hot dogs'],
#  ['tomatoes', 'mineral water', 'soup', 'mashed potato'],
#  ['cookies'],
#  ['parmesan cheese', 'ground beef', 'salmon', 'pancakes', 'champagne'],
#  ['ground beef', 'yams', 'chocolate', 'olive oil', 'eggs'],
#  ['shrimp', 'salmon', 'eggs', 'cookies', 'hot dogs'],
#  ['magazines', 'mint'],
#  ['turkey',
#   'mineral water',
#   'eggs',
#   'cooking oil',
#   'extra dark chocolate',
#   'escalope'],
#  ['mineral water', 'mushroom cream sauce'],
#  ['grated cheese',
#   'frozen vegetables',
#   'mineral water',
#   'soup',
#   'milk',
#   'french wine'],
#  ['chocolate', 'cake'],
#  ['burgers', 'salt', 'white wine'],
#  ['energy drink'],
#  ['olive oil', 'cake', 'energy drink'],
#  ['ground beef', 'whole wheat rice'],
#  ['eggs', 'french fries'],
#  ['spaghetti', 'escalope', 'mushroom cream sauce'],
#  ['mineral water',
#   'fromage blanc',
#   'whole wheat rice',
#   'cake',
#   'french fries'],
#  ['turkey',
#   'burgers',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'milk',
#   'eggs',
#   'cake',
#   'light mayo'],
#  ['green tea', 'cottage cheese'],
#  ['fresh tuna', 'eggs', 'champagne'],
#  ['cookies'],
#  ['cookies'],
#  ['cookies'],
#  ['tomatoes', 'mineral water', 'eggplant'],
#  ['grated cheese',
#   'tomatoes',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'honey',
#   'chicken',
#   'chocolate',
#   'french fries'],
#  ['protein bar'],
#  ['herb & pepper',
#   'red wine',
#   'shrimp',
#   'mineral water',
#   'barbecue sauce',
#   'protein bar'],
#  ['burgers',
#   'ham',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'eggs',
#   'french fries',
#   'escalope',
#   'pancakes',
#   'low fat yogurt'],
#  ['french fries'],
#  ['frozen vegetables',
#   'soup',
#   'milk',
#   'eggs',
#   'whole wheat rice',
#   'chocolate',
#   'escalope',
#   'melons'],
#  ['spaghetti'],
#  ['herb & pepper',
#   'shrimp',
#   'soup',
#   'eggs',
#   'oil',
#   'cooking oil',
#   'energy drink',
#   'protein bar',
#   'low fat yogurt'],
#  ['ham',
#   'grated cheese',
#   'herb & pepper',
#   'shrimp',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'carrots'],
#  ['ham',
#   'red wine',
#   'ground beef',
#   'yams',
#   'mineral water',
#   'chocolate',
#   'low fat yogurt'],
#  ['chocolate',
#   'french fries',
#   'mushroom cream sauce',
#   'cottage cheese',
#   'low fat yogurt'],
#  ['eggs'],
#  ['cake', 'cookies'],
#  ['grated cheese', 'mineral water', 'cake', 'chocolate bread'],
#  ['tomatoes', 'almonds', 'cake', 'champagne', 'low fat yogurt'],
#  ['herb & pepper',
#   'shrimp',
#   'frozen vegetables',
#   'milk',
#   'butter',
#   'salmon',
#   'eggs',
#   'chocolate'],
#  ['herb & pepper',
#   'shrimp',
#   'whole wheat pasta',
#   'whole wheat rice',
#   'chicken',
#   'green tea',
#   'cauliflower'],
#  ['eggs', 'corn'],
#  ['shrimp',
#   'frozen vegetables',
#   'tomato sauce',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'olive oil',
#   'salmon',
#   'green beans',
#   'champagne'],
#  ['ham',
#   'herb & pepper',
#   'tomato sauce',
#   'mineral water',
#   'green grapes',
#   'eggs',
#   'gums',
#   'light cream',
#   'oil',
#   'green tea',
#   'mint'],
#  ['energy bar', 'cake', 'chocolate'],
#  ['herb & pepper', 'shrimp', 'spaghetti', 'eggs'],
#  ['fresh tuna', 'mineral water', 'honey', 'cooking oil'],
#  ['red wine',
#   'mineral water',
#   'oil',
#   'ketchup',
#   'chili',
#   'pet food',
#   'eggplant',
#   'green tea',
#   'escalope',
#   'tomato juice',
#   'low fat yogurt'],
#  ['herb & pepper',
#   'shrimp',
#   'mineral water',
#   'pancakes',
#   'eggs',
#   'cake',
#   'blueberries',
#   'tea',
#   'frozen smoothie'],
#  ['ground beef', 'mineral water', 'protein bar'],
#  ['shrimp',
#   'frozen vegetables',
#   'parmesan cheese',
#   'spaghetti',
#   'salmon',
#   'carrots',
#   'frozen smoothie',
#   'pasta',
#   'mashed potato',
#   'shallot',
#   'light mayo',
#   'magazines'],
#  ['milk', 'chocolate'],
#  ['frozen vegetables',
#   'ground beef',
#   'spaghetti',
#   'olive oil',
#   'whole wheat rice',
#   'eggplant',
#   'cottage cheese'],
#  ['turkey', 'ground beef', 'low fat yogurt'],
#  ['herb & pepper',
#   'spaghetti',
#   'mineral water',
#   'whole wheat rice',
#   'cake',
#   'hot dogs',
#   'green tea'],
#  ['green tea'],
#  ['cookies'],
#  ['eggs', 'cookies'],
#  ['spaghetti',
#   'eggs',
#   'ham',
#   'chocolate',
#   'french fries',
#   'champagne',
#   'brownies',
#   'pancakes',
#   'light mayo'],
#  ['red wine', 'spaghetti', 'milk', 'eggs', 'chocolate'],
#  ['turkey',
#   'burgers',
#   'pancakes',
#   'french fries',
#   'strawberries',
#   'green tea'],
#  ['escalope'],
#  ['frozen vegetables', 'pancakes', 'eggs', 'cake'],
#  ['french fries'],
#  ['turkey', 'ground beef', 'pepper', 'spaghetti', 'honey', 'cookies'],
#  ['chocolate',
#   'red wine',
#   'tomato sauce',
#   'olive oil',
#   'chili',
#   'french fries',
#   'cookies',
#   'salt',
#   'fresh bread',
#   'magazines'],
#  ['green tea', 'french fries'],
#  ['mineral water'],
#  ['cooking oil'],
#  ['frozen vegetables', 'spaghetti'],
#  ['ham', 'spaghetti'],
#  ['chicken', 'chocolate', 'cookies'],
#  ['low fat yogurt'],
#  ['eggs', 'cake', 'low fat yogurt'],
#  ['shrimp',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'milk',
#   'bramble',
#   'frozen smoothie',
#   'cottage cheese'],
#  ['mineral water', 'eggs', 'protein bar'],
#  ['turkey', 'shrimp', 'meatballs', 'butter', 'eggs', 'salad', 'green tea'],
#  ['fresh tuna',
#   'spaghetti',
#   'chocolate',
#   'olive oil',
#   'chicken',
#   'french fries'],
#  ['turkey', 'shrimp', 'escalope', 'hot dogs'],
#  ['burgers', 'pepper', 'soup', 'milk', 'pancakes', 'green tea'],
#  ['pancakes'],
#  ['mineral water', 'pancakes', 'eggs', 'french fries'],
#  ['eggs', 'escalope', 'low fat yogurt'],
#  ['mineral water', 'french wine', 'gluten free bar'],
#  ['burgers', 'ground beef', 'spaghetti', 'eggs', 'french fries'],
#  ['soup', 'meatballs', 'milk', 'energy bar'],
#  ['chocolate'],
#  ['herb & pepper'],
#  ['turkey', 'red wine', 'mineral water', 'eggs', 'bramble'],
#  ['burgers',
#   'ham',
#   'frozen vegetables',
#   'tomatoes',
#   'cake',
#   'chicken',
#   'green tea',
#   'toothpaste',
#   'mint'],
#  ['grated cheese', 'mineral water', 'olive oil', 'energy bar'],
#  ['milk', 'cake', 'green tea'],
#  ['mineral water',
#   'almonds',
#   'cooking oil',
#   'cereals',
#   'protein bar',
#   'white wine',
#   'green tea'],
#  ['turkey',
#   'fresh tuna',
#   'mineral water',
#   'milk',
#   'eggs',
#   'cake',
#   'burger sauce',
#   'chicken',
#   'french fries',
#   'frozen smoothie',
#   'fresh bread'],
#  ['herb & pepper',
#   'mineral water',
#   'whole wheat rice',
#   'yogurt cake',
#   'low fat yogurt'],
#  ['tomatoes', 'spaghetti', 'meatballs', 'chicken', 'eggs'],
#  ['burgers', 'mineral water', 'eggs', 'green tea', 'pancakes'],
#  ['cake', 'green tea'],
#  ['chocolate', 'herb & pepper', 'yogurt cake'],
#  ['ground beef',
#   'spaghetti',
#   'mineral water',
#   'almonds',
#   'salmon',
#   'nonfat milk',
#   'green grapes',
#   'pancakes'],
#  ['mineral water', 'vegetables mix', 'eggs'],
#  ['protein bar'],
#  ['eggs', 'eggplant'],
#  ['mayonnaise'],
#  ['milk', 'bug spray', 'oatmeal', 'sandwich', 'asparagus'],
#  ['frozen vegetables', 'soup', 'almonds', 'eggs', 'french fries'],
#  ['frozen vegetables'],
#  ['soup', 'butter', 'shampoo'],
#  ['herb & pepper', 'whole wheat pasta', 'pepper', 'eggs'],
#  ['mineral water',
#   'whole wheat rice',
#   'rice',
#   'cooking oil',
#   'chocolate',
#   'fresh bread',
#   'low fat yogurt'],
#  ['grated cheese', 'butter', 'chocolate', 'french fries', 'cookies'],
#  ['spaghetti',
#   'soup',
#   'milk',
#   'chutney',
#   'cooking oil',
#   'asparagus',
#   'tomato juice'],
#  ['eggs',
#   'french fries',
#   'frozen smoothie',
#   'cookies',
#   'champagne',
#   'cottage cheese',
#   'green tea'],
#  ['turkey', 'tomatoes', 'mineral water', 'eggs', 'blueberries'],
#  ['milk', 'tomato juice', 'low fat yogurt', 'green tea'],
#  ['mineral water', 'soup', 'almonds', 'cereals', 'green tea'],
#  ['chocolate', 'light mayo'],
#  ['turkey', 'herb & pepper', 'chocolate'],
#  ['eggs', 'french fries', 'green tea'],
#  ['mineral water', 'cake', 'chocolate', 'tomato juice'],
#  ['eggs'],
#  ['chocolate',
#   'pepper',
#   'spaghetti',
#   'mineral water',
#   'whole wheat rice',
#   'champagne',
#   'mushroom cream sauce'],
#  ['frozen vegetables', 'pepper', 'mineral water', 'chocolate', 'white wine'],
#  ['burgers',
#   'turkey',
#   'spaghetti',
#   'milk',
#   'whole wheat rice',
#   'oil',
#   'tomato juice',
#   'green tea'],
#  ['burgers',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'french wine',
#   'french fries',
#   'light mayo',
#   'low fat yogurt'],
#  ['butter', 'green grapes', 'frozen smoothie', 'low fat yogurt'],
#  ['eggs', 'low fat yogurt'],
#  ['cookies'],
#  ['milk', 'energy drink'],
#  ['olive oil', 'energy drink'],
#  ['eggs', 'cookies'],
#  ['eggs'],
#  ['energy bar', 'eggs'],
#  ['eggs'],
#  ['eggs', 'green tea'],
#  ['escalope'],
#  ['shrimp', 'soup', 'milk', 'almonds', 'eggs', 'oil', 'chocolate'],
#  ['chocolate', 'french fries'],
#  ['cake'],
#  ['pancakes', 'eggs', 'cake', 'green tea', 'toothpaste'],
#  ['herb & pepper', 'tomatoes', 'ground beef', 'eggs', 'cooking oil'],
#  ['cider', 'eggs', 'chocolate', 'low fat yogurt'],
#  ['frozen vegetables', 'cider', 'eggs', 'french fries'],
#  ['yams', 'cookies', 'toothpaste'],
#  ['mineral water', 'milk', 'escalope', 'champagne', 'hot dogs', 'fresh bread'],
#  ['ham',
#   'herb & pepper',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'pancakes',
#   'eggs'],
#  ['pepper',
#   'mineral water',
#   'escalope',
#   'shallot',
#   'protein bar',
#   'white wine'],
#  ['turkey', 'parmesan cheese', 'spaghetti', 'meatballs', 'butter'],
#  ['herb & pepper', 'eggs', 'escalope'],
#  ['herb & pepper'],
#  ['burgers', 'escalope', 'shallot'],
#  ['chocolate', 'pepper', 'tomato sauce', 'tomato juice'],
#  ['cookies'],
#  ['burgers',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'escalope',
#   'melons'],
#  ['frozen vegetables', 'mineral water', 'soup', 'milk', 'olive oil'],
#  ['turkey', 'eggs', 'french fries', 'asparagus', 'low fat yogurt', 'zucchini'],
#  ['burgers', 'frozen vegetables', 'gums'],
#  ['herb & pepper', 'frozen vegetables', 'ground beef', 'milk'],
#  ['frozen vegetables', 'cake', 'light cream', 'mashed potato'],
#  ['milk'],
#  ['turkey', 'eggs', 'barbecue sauce'],
#  ['escalope'],
#  ['parmesan cheese', 'french fries'],
#  ['energy bar', 'eggs'],
#  ['soup', 'escalope', 'mint'],
#  ['muffins', 'chicken', 'zucchini'],
#  ['burgers', 'eggs', 'french fries', 'cookies', 'green tea'],
#  ['spaghetti'],
#  ['avocado', 'energy bar', 'chocolate'],
#  ['cookies'],
#  ['green tea'],
#  ['whole wheat pasta', 'spaghetti', 'mineral water', 'olive oil'],
#  ['grated cheese',
#   'frozen vegetables',
#   'eggs',
#   'gums',
#   'escalope',
#   'low fat yogurt'],
#  ['grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'pancakes',
#   'chocolate',
#   'escalope',
#   'tomato juice'],
#  ['chocolate', 'spaghetti', 'yams', 'flax seed', 'salmon', 'frozen smoothie'],
#  ['burger sauce', 'oil'],
#  ['eggs', 'french fries', 'energy drink'],
#  ['mineral water'],
#  ['grated cheese', 'ground beef', 'mineral water', 'olive oil'],
#  ['eggs', 'low fat yogurt'],
#  ['parmesan cheese', 'spaghetti', 'soda', 'pet food', 'white wine'],
#  ['turkey',
#   'shrimp',
#   'olive oil',
#   'chicken',
#   'eggs',
#   'extra dark chocolate',
#   'melons',
#   'fresh bread'],
#  ['pickles',
#   'ground beef',
#   'yams',
#   'milk',
#   'strong cheese',
#   'salmon',
#   'muffins',
#   'french fries',
#   'escalope'],
#  ['pepper', 'spaghetti', 'light cream'],
#  ['frozen vegetables', 'mineral water', 'eggs'],
#  ['spaghetti', 'chicken', 'tea', 'pancakes', 'gluten free bar'],
#  ['fresh tuna',
#   'turkey',
#   'herb & pepper',
#   'spaghetti',
#   'mineral water',
#   'mint'],
#  ['spaghetti', 'mineral water', 'cooking oil', 'escalope'],
#  ['soup'],
#  ['burgers', 'herb & pepper', 'spaghetti'],
#  ['cookies', 'shallot', 'strawberries'],
#  ['fresh tuna',
#   'chocolate',
#   'shrimp',
#   'whole wheat pasta',
#   'pepper',
#   'mineral water',
#   'soup',
#   'milk',
#   'salmon'],
#  ['yams',
#   'mineral water',
#   'avocado',
#   'milk',
#   'butter',
#   'cooking oil',
#   'chocolate',
#   'cottage cheese'],
#  ['ham', 'eggs', 'french fries', 'energy drink'],
#  ['mineral water', 'avocado'],
#  ['cookies'],
#  ['chocolate', 'butter', 'eggs', 'green tea', 'cottage cheese', 'mayonnaise'],
#  ['eggs', 'mushroom cream sauce', 'low fat yogurt'],
#  ['antioxydant juice', 'chocolate'],
#  ['ground beef', 'spaghetti', 'french fries', 'green tea'],
#  ['cake'],
#  ['turkey',
#   'red wine',
#   'mineral water',
#   'pancakes',
#   'eggs',
#   'whole wheat rice',
#   'cooking oil',
#   'chocolate',
#   'zucchini'],
#  ['chocolate', 'parmesan cheese', 'mineral water', 'olive oil', 'bacon'],
#  ['green grapes', 'gums'],
#  ['shrimp',
#   'frozen vegetables',
#   'parmesan cheese',
#   'milk',
#   'eggs',
#   'cooking oil',
#   'chocolate',
#   'french fries'],
#  ['ground beef', 'mineral water', 'milk', 'eggs'],
#  ['escalope'],
#  ['turkey', 'cookies'],
#  ['ground beef', 'mineral water', 'chocolate', 'green tea'],
#  ['whole wheat pasta',
#   'spaghetti',
#   'olive oil',
#   'butter',
#   'chocolate',
#   'french fries',
#   'tomato juice',
#   'low fat yogurt'],
#  ['red wine'],
#  ['frozen vegetables',
#   'mineral water',
#   'eggs',
#   'gums',
#   'cooking oil',
#   'frozen smoothie',
#   'cottage cheese',
#   'low fat yogurt'],
#  ['turkey', 'grated cheese', 'energy bar', 'vegetables mix', 'brownies'],
#  ['turkey', 'burgers', 'nonfat milk', 'cooking oil', 'energy drink'],
#  ['french fries', 'low fat yogurt'],
#  ['muffins'],
#  ['herb & pepper',
#   'mineral water',
#   'salmon',
#   'whole wheat rice',
#   'cake',
#   'green tea'],
#  ['mineral water', 'cake', 'chocolate', 'low fat yogurt', 'candy bars'],
#  ['grated cheese',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'milk',
#   'olive oil',
#   'light cream',
#   'chicken'],
#  ['mineral water', 'strawberries'],
#  ['escalope'],
#  ['grated cheese',
#   'parmesan cheese',
#   'butter',
#   'whole wheat rice',
#   'cooking oil'],
#  ['ground beef', 'mint'],
#  ['cookies'],
#  ['ground beef', 'avocado', 'milk', 'chicken', 'rice'],
#  ['frozen vegetables', 'soup', 'eggs', 'low fat yogurt'],
#  ['herb & pepper',
#   'ground beef',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'black tea',
#   'french wine',
#   'pancakes',
#   'rice',
#   'green tea',
#   'toothpaste'],
#  ['shrimp',
#   'parmesan cheese',
#   'mineral water',
#   'eggs',
#   'cake',
#   'oil',
#   'cooking oil',
#   'toothpaste',
#   'low fat yogurt'],
#  ['ham',
#   'herb & pepper',
#   'frozen vegetables',
#   'tomatoes',
#   'spaghetti',
#   'olive oil',
#   'black tea',
#   'vegetables mix',
#   'cooking oil',
#   'green tea',
#   'frozen smoothie',
#   'mint'],
#  ['chicken', 'cider', 'eggs'],
#  ['shrimp', 'tomato sauce', 'mineral water', 'chocolate', 'escalope', 'mint'],
#  ['energy drink'],
#  ['ham',
#   'spaghetti',
#   'mineral water',
#   'energy bar',
#   'eggs',
#   'cooking oil',
#   'pancakes',
#   'fresh bread',
#   'low fat yogurt'],
#  ['shrimp', 'frozen vegetables', 'tomatoes'],
#  ['turkey',
#   'herb & pepper',
#   'frozen vegetables',
#   'ground beef',
#   'yams',
#   'mineral water',
#   'salmon'],
#  ['shrimp', 'mineral water'],
#  ['turkey', 'ground beef', 'spaghetti', 'soup', 'escalope', 'yogurt cake'],
#  ['shrimp',
#   'pepper',
#   'mineral water',
#   'soup',
#   'milk',
#   'eggs',
#   'rice',
#   'barbecue sauce',
#   'clothes accessories',
#   'cookies'],
#  ['burgers', 'pancakes'],
#  ['low fat yogurt'],
#  ['mineral water', 'milk'],
#  ['milk'],
#  ['chocolate'],
#  ['whole wheat pasta', 'mineral water', 'olive oil', 'pancakes'],
#  ['yams', 'mineral water', 'eggs', 'cake'],
#  ['turkey', 'french fries'],
#  ['shrimp',
#   'spaghetti',
#   'yams',
#   'mineral water',
#   'chocolate',
#   'olive oil',
#   'light cream',
#   'chicken',
#   'green tea',
#   'french fries',
#   'sandwich',
#   'white wine'],
#  ['mineral water', 'milk', 'salmon', 'green tea', 'cookies', 'fresh bread'],
#  ['spaghetti', 'olive oil'],
#  ['herb & pepper', 'spaghetti'],
#  ['spaghetti',
#   'mineral water',
#   'soup',
#   'salmon',
#   'pancakes',
#   'chicken',
#   'mint green tea',
#   'low fat yogurt'],
#  ['frozen vegetables',
#   'whole wheat pasta',
#   'ground beef',
#   'mineral water',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'almonds',
#   'french wine',
#   'yogurt cake',
#   'fresh bread'],
#  ['green tea'],
#  ['burgers',
#   'grated cheese',
#   'spaghetti',
#   'nonfat milk',
#   'eggs',
#   'gums',
#   'chocolate',
#   'tomato juice',
#   'low fat yogurt'],
#  ['ham',
#   'ground beef',
#   'olive oil',
#   'energy bar',
#   'chicken',
#   'brownies',
#   'white wine'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'cooking oil',
#   'frozen smoothie',
#   'green tea'],
#  ['vegetables mix', 'champagne'],
#  ['olive oil'],
#  ['herb & pepper', 'ground beef', 'escalope', 'pancakes', 'green tea'],
#  ['herb & pepper',
#   'frozen vegetables',
#   'ground beef',
#   'tomato sauce',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'french wine',
#   'eggs',
#   'whole wheat rice',
#   'chocolate',
#   'escalope',
#   'hot dogs',
#   'green tea'],
#  ['yams', 'carrots'],
#  ['chicken'],
#  ['turkey',
#   'burgers',
#   'herb & pepper',
#   'ground beef',
#   'yams',
#   'mineral water',
#   'avocado',
#   'milk',
#   'almonds',
#   'muffins',
#   'eggs',
#   'french fries'],
#  ['whole wheat pasta', 'salmon', 'antioxydant juice', 'mint green tea'],
#  ['chocolate', 'french fries', 'strawberries', 'fresh bread'],
#  ['burgers',
#   'chocolate',
#   'shrimp',
#   'whole wheat pasta',
#   'ground beef',
#   'soup',
#   'energy bar',
#   ' asparagus'],
#  ['mineral water',
#   'butter',
#   'pancakes',
#   'french fries',
#   'frozen smoothie',
#   'white wine',
#   'low fat yogurt'],
#  ['muffins', 'eggs'],
#  ['turkey', 'shrimp', 'frozen vegetables', 'eggs'],
#  ['burgers', 'eggs', 'yogurt cake'],
#  ['burgers',
#   'fresh tuna',
#   'shrimp',
#   'frozen vegetables',
#   'whole wheat pasta',
#   'yams',
#   'mineral water',
#   'olive oil',
#   'almonds',
#   'cake',
#   'chicken',
#   'extra dark chocolate'],
#  ['herb & pepper', 'ground beef', 'mineral water', 'chicken'],
#  ['frozen smoothie'],
#  ['chicken', 'tomato juice'],
#  ['whole wheat pasta', 'olive oil'],
#  ['milk', 'energy bar', 'green tea'],
#  ['grated cheese', 'herb & pepper'],
#  ['escalope', 'green tea'],
#  ['soup', 'meatballs', 'milk', 'almonds', 'green tea'],
#  ['herb & pepper', 'pet food', 'cookies'],
#  ['grated cheese',
#   'whole wheat pasta',
#   'olive oil',
#   'energy bar',
#   'light cream',
#   'oil',
#   'french fries',
#   'pancakes',
#   'low fat yogurt'],
#  ['honey'],
#  ['parmesan cheese',
#   'mineral water',
#   'fromage blanc',
#   'eggs',
#   'honey',
#   'frozen smoothie'],
#  ['bramble', 'zucchini'],
#  ['ground beef',
#   'pepper',
#   'milk',
#   'eggs',
#   'green tea',
#   'chocolate',
#   'white wine'],
#  ['chocolate',
#   'red wine',
#   'butter',
#   'french fries',
#   'cookies',
#   'low fat yogurt'],
#  ['chocolate', 'spaghetti', 'bug spray'],
#  ['cookies'],
#  ['spaghetti',
#   'mineral water',
#   'vegetables mix',
#   'eggs',
#   'whole wheat rice',
#   'fresh bread'],
#  ['chocolate',
#   'grated cheese',
#   'mineral water',
#   'salmon',
#   'whole wheat rice',
#   'burger sauce',
#   'escalope',
#   'mushroom cream sauce',
#   'low fat yogurt'],
#  ['spaghetti', 'champagne'],
#  ['frozen vegetables', 'mineral water'],
#  ['mineral water', 'body spray', 'low fat yogurt'],
#  ['herb & pepper', 'red wine', 'whole wheat pasta', 'cake', 'tomato juice'],
#  ['burgers', 'parmesan cheese', 'eggs', 'french fries', 'hot dogs'],
#  ['mineral water', 'eggs', 'pancakes'],
#  ['eggs', 'french fries'],
#  ['shrimp', 'frozen vegetables', 'tomatoes', 'spaghetti'],
#  ['mineral water',
#   'almonds',
#   'pancakes',
#   'chocolate',
#   'french fries',
#   'green tea'],
#  ['cake', 'french fries', 'escalope'],
#  ['frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'black tea',
#   'french wine',
#   'cider',
#   'chutney',
#   'salmon'],
#  ['almonds', 'cake', 'low fat yogurt'],
#  ['french fries'],
#  ['hot dogs'],
#  ['mineral water',
#   'soup',
#   'chicken',
#   'light cream',
#   'green tea',
#   'chocolate',
#   'champagne',
#   'low fat yogurt'],
#  ['ground beef', 'olive oil'],
#  ['french fries', 'cookies', 'green tea'],
#  ['soup',
#   'blueberries',
#   'cooking oil',
#   'chocolate',
#   'cookies',
#   'champagne',
#   'salt'],
#  ['chocolate', 'french fries', 'frozen smoothie', 'escalope', 'fresh bread'],
#  ['yams', 'mint'],
#  ['frozen vegetables',
#   'ground beef',
#   'salmon',
#   'muffins',
#   'chocolate',
#   'magazines'],
#  ['fresh tuna',
#   'herb & pepper',
#   'parmesan cheese',
#   'milk',
#   'olive oil',
#   'pancakes',
#   'honey',
#   'cake',
#   'chocolate'],
#  ['grated cheese',
#   'shrimp',
#   'butter',
#   'whole wheat rice',
#   'french fries',
#   'escalope',
#   'cookies',
#   'cottage cheese'],
#  ['energy bar', 'eggs', 'french fries', 'champagne', 'body spray'],
#  ['burgers', 'eggs', 'french fries'],
#  ['burgers',
#   'shrimp',
#   'mineral water',
#   'milk',
#   'eggs',
#   'chocolate',
#   'french fries',
#   'fresh bread'],
#  ['ground beef',
#   'mineral water',
#   'chocolate',
#   'milk',
#   'chicken',
#   'nonfat milk',
#   'green tea'],
#  ['mineral water', 'chicken'],
#  ['turkey', 'ground beef', 'spaghetti', 'milk', 'eggs', 'cake'],
#  ['french fries', 'green tea'],
#  ['french fries', 'escalope'],
#  ['turkey', 'sparkling water'],
#  ['whole wheat pasta',
#   'mineral water',
#   'olive oil',
#   'carrots',
#   'protein bar',
#   'low fat yogurt'],
#  ['cookies'],
#  ['turkey', 'grated cheese', 'honey', 'green beans', 'french fries'],
#  ['turkey',
#   'red wine',
#   'mineral water',
#   'chocolate',
#   'soup',
#   'light cream',
#   'rice',
#   'oil',
#   'chicken',
#   'barbecue sauce'],
#  ['turkey', 'eggs'],
#  ['low fat yogurt'],
#  ['nonfat milk', 'low fat yogurt'],
#  ['frozen vegetables', 'low fat yogurt'],
#  ['herb & pepper',
#   'parmesan cheese',
#   'whole wheat pasta',
#   'mineral water',
#   'milk',
#   'eggs',
#   'low fat yogurt',
#   'mint'],
#  ['yogurt cake', 'mint'],
#  ['sandwich', 'salt'],
#  ['shrimp', 'fresh bread', 'green tea'],
#  ['pepper', 'tomato sauce', 'escalope'],
#  ['mineral water', 'cake', 'protein bar', 'toothpaste'],
#  ['candy bars'],
#  ['red wine'],
#  ['spaghetti', 'mineral water', 'honey', 'strawberries'],
#  ['mineral water', 'eggs', 'green tea'],
#  ['grated cheese',
#   'frozen vegetables',
#   'parmesan cheese',
#   'french wine',
#   'french fries',
#   'fresh bread',
#   'green tea'],
#  ['frozen vegetables',
#   'parmesan cheese',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'avocado',
#   'milk',
#   'olive oil',
#   'muffins',
#   'cake'],
#  ['chocolate',
#   'grated cheese',
#   'shrimp',
#   'spaghetti',
#   'olive oil',
#   'honey',
#   'strawberries',
#   'mint'],
#  ['spaghetti', 'strawberries'],
#  ['burgers', 'chocolate', 'mushroom cream sauce'],
#  ['mineral water', 'olive oil', 'extra dark chocolate'],
#  ['eggs', 'green tea'],
#  ['tomato juice'],
#  ['muffins', 'low fat yogurt'],
#  ['soup',
#   'olive oil',
#   'pancakes',
#   'light cream',
#   'champagne',
#   'low fat yogurt'],
#  ['mineral water', 'vegetables mix', 'low fat yogurt'],
#  ['pepper',
#   'mineral water',
#   'avocado',
#   'pancakes',
#   'eggs',
#   'honey',
#   'green tea',
#   'chocolate'],
#  ['pickles', 'burgers', 'almonds', 'honey', 'frozen smoothie'],
#  ['bug spray', 'clothes accessories', 'cottage cheese'],
#  ['frozen vegetables',
#   'ground beef',
#   'spaghetti',
#   'pancakes',
#   'honey',
#   'whole wheat rice',
#   'green beans',
#   'french fries',
#   'frozen smoothie',
#   'mashed potato'],
#  ['spaghetti', 'mineral water', 'milk'],
#  ['pancakes'],
#  ['muffins'],
#  ['frozen vegetables', 'oil', 'cereals'],
#  ['turkey',
#   'shrimp',
#   'mineral water',
#   'milk',
#   'almonds',
#   'strong cheese',
#   'cake',
#   'frozen smoothie'],
#  ['chocolate', 'rice', 'eggplant', 'hand protein bar', 'zucchini'],
#  ['spaghetti', 'meatballs', 'nonfat milk', 'hot dogs'],
#  ['frozen vegetables', 'cake', 'cookies', 'pancakes'],
#  ['butter', 'bug spray', 'french fries', 'yogurt cake', 'green tea'],
#  ['herb & pepper'],
#  ['soup', 'milk', 'cider', 'chicken', 'green beans'],
#  ['shrimp',
#   'spaghetti',
#   'mineral water',
#   'avocado',
#   'milk',
#   'salmon',
#   'frozen smoothie',
#   'escalope',
#   'hot dogs'],
#  ['milk', 'whole wheat rice', 'escalope', 'champagne'],
#  ['escalope', 'pasta', 'mushroom cream sauce'],
#  ['parmesan cheese'],
#  ['grated cheese', 'spaghetti', 'french fries'],
#  ['burgers',
#   'shrimp',
#   'whole wheat pasta',
#   'spaghetti',
#   'mineral water',
#   'milk',
#   'olive oil',
#   'chicken',
#   'salmon',
#   'pancakes',
#   'cake'],
#  ['turkey',
#   'chocolate',
#   'grated cheese',
#   'frozen vegetables',
#   'ground beef',
#   'spaghetti',
#   'milk',
#   'butter',
#   'bacon',
#   'whole wheat rice'],
#  ['turkey',
#   'pepper',
#   'chocolate',
#   'fromage blanc',
#   'eggs',
#   'green tea',
#   'escalope'],
#  ['tomatoes', 'ground beef', 'avocado', 'milk', 'pancakes', 'green tea'],
#  ['turkey', 'mineral water', 'green tea', 'protein bar'],
#  ['mineral water', 'low fat yogurt'],
#  ['pancakes', 'tomato juice', 'candy bars'],
#  ['yams',
#   'avocado',
#   'bacon',
#   'oil',
#   'french fries',
#   'brownies',
#   'pancakes',
#   'zucchini',
#   'green tea'],
#  ['shrimp',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'milk',
#   'olive oil',
#   'chicken',
#   'cake',
#   'burger sauce',
#   'oil'],
#  ['chicken', 'cooking oil', 'tea'],
#  ['burgers',
#   'soup',
#   'vegetables mix',
#   'pancakes',
#   'body spray',
#   'melons',
#   'protein bar',
#   'asparagus',
#   'mayonnaise',
#   'mint',
#   'green tea'],
#  ['shrimp', 'pepper'],
#  ['spaghetti', 'olive oil', 'blueberries'],
#  ['muffins'],
#  ['grated cheese', 'herb & pepper', 'muffins', 'eggs', 'low fat yogurt'],
#  ['grated cheese',
#   'frozen vegetables',
#   'spaghetti',
#   'milk',
#   'gums',
#   'light cream',
#   'cooking oil',
#   'gluten free bar'],
#  ['pepper', 'pancakes', 'french fries', 'tomato juice'],
#  ['frozen vegetables',
#   'tomatoes',
#   'parmesan cheese',
#   'ground beef',
#   'tomato sauce',
#   'milk',
#   'extra dark chocolate',
#   'melons',
#   'mint',
#   'green tea'],
#  ['olive oil', 'chicken', 'chocolate', 'cookies', 'green tea'],
#  ['whole wheat pasta',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'french wine',
#   'pancakes',
#   'eggs',
#   'frozen smoothie',
#   'sandwich',
#   'tomato juice'],
#  ['eggs', 'cottage cheese'],
#  ['muffins', 'cottage cheese'],
#  ['green tea', 'frozen smoothie', 'white wine'],
#  ['mineral water', 'chocolate', 'rice', 'champagne'],
#  ['mineral water'],
#  ['shrimp', 'whole wheat pasta', 'meatballs', 'milk'],
#  ['herb & pepper',
#   'parmesan cheese',
#   'ground beef',
#   'pepper',
#   'spaghetti',
#   'cream',
#   'black tea',
#   'almonds',
#   'french wine',
#   'pancakes',
#   'eggs'],
#  ['grated cheese',
#   'shrimp',
#   'parmesan cheese',
#   'ground beef',
#   'mineral water',
#   'mint'],
#  ['mineral water', 'rice'],
#  ['pancakes'],
#  ['mineral water', 'honey'],
#  ['burgers', 'ground beef', 'pancakes', 'salt'],
#  ['parmesan cheese', 'soda', 'french fries', 'brownies'],
#  ['whole wheat rice'],
#  ['ground beef',
#   'spaghetti',
#   'chicken',
#   'rice',
#   'oil',
#   'cooking oil',
#   'hot dogs',
#   'mint'],
#  ['butter', 'chocolate'],
#  ['pepper'],
#  ['herb & pepper', 'chocolate', 'champagne', 'yogurt cake', 'green tea'],
#  ['grated cheese', 'mineral water', 'eggs', 'escalope'],
#  ['cookies', 'yogurt cake', 'light mayo', 'green tea'],
#  ['milk', 'cooking oil'],
#  ['milk',
#   'olive oil',
#   'light cream',
#   'cooking oil',
#   'chicken',
#   'extra dark chocolate',
#   'cereals',
#   'french fries',
#   'frozen smoothie',
#   'pancakes',
#   'tomato juice',
#   'fresh bread',
#   'low fat yogurt'],
#  ['tomatoes',
#   'soup',
#   'avocado',
#   'milk',
#   'yogurt cake',
#   'energy drink',
#   'low fat yogurt',
#   'green tea'],
#  ['ham', 'chocolate', 'ground beef', 'mineral water', 'oil'],
#  ['green tea', 'champagne', 'escalope'],
#  ['chocolate'],
#  ['escalope', 'pasta'],
#  ['burgers',
#   'mineral water',
#   'olive oil',
#   'rice',
#   'antioxydant juice',
#   'frozen smoothie'],
#  ['green tea'],
#  ['grated cheese',
#   'tomato sauce',
#   'spaghetti',
#   'milk',
#   'pancakes',
#   'energy drink',
#   'white wine'],
#  ['turkey', 'spaghetti', 'strong cheese', 'strawberries'],
#  ['muffins'],
#  ['ground beef', 'spaghetti', 'cider', 'cooking oil', 'cookies'],
#  ['burgers',
#   'frozen vegetables',
#   'parmesan cheese',
#   'spaghetti',
#   'fromage blanc',
#   'vegetables mix',
#   'pancakes',
#   'honey',
#   'hot dogs',
#   'low fat yogurt'],
#  ['ground beef'],
#  ['green beans'],
#  ['frozen vegetables',
#   'mineral water',
#   'honey',
#   'whole wheat rice',
#   'champagne',
#   'escalope'],
#  ['parmesan cheese',
#   'milk',
#   'butter',
#   'black tea',
#   'eggs',
#   'frozen smoothie',
#   'light mayo',
#   'shampoo',
#   'low fat yogurt',
#   'green tea'],
#  ['mineral water', 'cake'],
#  ['turkey',
#   'mineral water',
#   'milk',
#   'pancakes',
#   'whole wheat rice',
#   'cooking oil',
#   'frozen smoothie',
#   'cookies',
#   'green tea'],
#  ['avocado', 'chocolate', 'french fries'],
#  ['green tea'],
#  ['chocolate', 'eggs', 'bug spray'],
#  ['grated cheese', 'muffins', 'french fries', 'body spray'],
#  ['mineral water', 'eggs', 'blueberries', 'soda', 'escalope'],
#  ['whole wheat rice'],
#  ['nonfat milk', 'cookies', 'mushroom cream sauce'],
#  ['french fries', 'champagne'],
#  ['mineral water', 'salmon'],
#  ['olive oil'],
#  ['turkey',
#   'tomatoes',
#   'ground beef',
#   'soup',
#   'milk',
#   'butter',
#   'honey',
#   'cake',
#   'mint green tea',
#   'brownies',
#   'salt'],
#  ['parmesan cheese',
#   'spaghetti',
#   'mineral water',
#   'chocolate',
#   'napkins',
#   'low fat yogurt'],
#  ['burgers',
#   'parmesan cheese',
#   'chocolate',
#   'soup',
#   'milk',
#   'olive oil',
#   'energy bar',
#   'butter',
#   'almonds',
#   'fromage blanc',
#   'eggs',
#   'cake',
#   'pancakes'],
#  ['shrimp', 'honey', 'pasta', 'energy drink', 'green tea'],
#  ['fresh tuna',
#   'chocolate',
#   'milk',
#   'french wine',
#   'muffins',
#   'pancakes',
#   'champagne',
#   'frozen smoothie'],
#  ['strawberries'],
#  ['herb & pepper'],
#  ['herb & pepper',
#   'frozen vegetables',
#   'tomatoes',
#   'parmesan cheese',
#   'ground beef',
#   'fromage blanc',
#   'eggs',
#   'honey',
#   'cake',
#   'rice',
#   'cereals',
#   'french fries',
#   'champagne'],
#  ['spaghetti',
#   'mineral water',
#   'milk',
#   'strong cheese',
#   'cereals',
#   'escalope',
#   'cottage cheese'],
#  ['turkey',
#   'burgers',
#   'fresh tuna',
#   'spaghetti',
#   'pancakes',
#   'eggs',
#   'cake',
#   'cottage cheese',
#   'energy drink',
#   'gluten free bar'],
#  ['eggplant'],
#  ['burgers',
#   'spaghetti',
#   'mineral water',
#   'almonds',
#   'honey',
#   'extra dark chocolate',
#   'carrots',
#   'mashed potato'],
#  ['chocolate',
#   'french fries',
#   'frozen smoothie',
#   'cottage cheese',
#   'strawberries',
#   'light mayo'],
#  ['strong cheese'],
#  ['chocolate', 'french fries'],
#  ['chocolate', 'french fries', 'strawberries'],
#  ['turkey',
#   'frozen vegetables',
#   'avocado',
#   'cake',
#   'light cream',
#   'cooking oil',
#   'chicken',
#   'chocolate bread',
#   'mashed potato'],
#  ['olive oil', 'energy bar', 'shallot'],
#  ['turkey', 'shrimp'],
#  ['chocolate', 'spaghetti', 'champagne', 'yogurt cake'],
#  ['shrimp',
#   'mineral water',
#   'chocolate',
#   'avocado',
#   'butter',
#   'zucchini',
#   'green tea'],
#  ['muffins', 'green tea', 'brownies'],
#  ['yogurt cake'],
#  ['turkey',
#   'tomato sauce',
#   'milk',
#   'butter',
#   'bacon',
#   'salmon',
#   'cooking oil',
#   'chocolate',
#   'french fries',
#   'hot dogs',
#   'melons',
#   'protein bar',
#   'mint'],
#  ['grated cheese'],
#  ['butter', 'burger sauce', 'brownies', 'pancakes'],
#  ['butter',
#   'pancakes',
#   'whole wheat rice',
#   'green tea',
#   'french fries',
#   'cookies',
#   'shallot',
#   'low fat yogurt'],
#  ['shrimp', 'chocolate', 'butter', 'cooking oil', 'escalope'],
#  ['burgers',
#   'red wine',
#   'frozen vegetables',
#   'pepper',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'honey',
#   'whole wheat rice',
#   'cooking oil',
#   'cereals'],
#  ['turkey',
#   'ground beef',
#   'spaghetti',
#   'pancakes',
#   'eggs',
#   'cake',
#   'chili',
#   'pet food',
#   'chocolate'],
#  ['shrimp', 'milk', 'butter', 'chicken', 'salt', 'mayonnaise', 'green tea'],
#  ['fresh tuna',
#   'mineral water',
#   'fromage blanc',
#   'honey',
#   'gums',
#   'chocolate',
#   'french fries',
#   'frozen smoothie',
#   'sparkling water',
#   'strawberries',
#   'green tea'],
#  ['chocolate', 'cookies'],
#  ['sparkling water', 'light mayo'],
#  ['frozen vegetables',
#   'tomatoes',
#   'spaghetti',
#   'chicken',
#   'french fries',
#   'escalope'],
#  ['turkey',
#   'burgers',
#   'butter',
#   'vegetables mix',
#   'green grapes',
#   'pancakes',
#   'eggs',
#   'cake',
#   'barbecue sauce',
#   'green tea'],
#  ['red wine', 'shrimp', 'yams', 'eggs', 'burger sauce', 'yogurt cake'],
#  ['french fries', 'light mayo'],
#  ['burgers', 'ground beef', 'eggs', 'chocolate', 'champagne', 'zucchini'],
#  ['mushroom cream sauce'],
#  ['butter', 'mint green tea'],
#  ['whole wheat rice'],
#  ['gums'],
#  ['mineral water', 'french fries', 'champagne', 'green tea'],
#  ['cereals', 'salt', 'green tea'],
#  ['shrimp',
#   'spaghetti',
#   'chocolate',
#   'french fries',
#   'escalope',
#   'cookies',
#   'brownies',
#   'pancakes',
#   'melons'],
#  ['ham',
#   'spaghetti',
#   'yams',
#   'chicken',
#   'cooking oil',
#   'chocolate',
#   'hot dogs'],
#  ['eggs'],
#  ['ground beef', 'olive oil', 'bug spray', 'frozen smoothie', 'hot dogs'],
#  ['frozen vegetables',
#   'spaghetti',
#   'mineral water',
#   'soup',
#   'olive oil',
#   'escalope'],
#  ['whole wheat rice', 'oil', 'chicken', 'french fries', 'escalope'],
#  ['green tea'],
#  ['parmesan cheese', 'whole wheat rice', 'escalope', 'champagne'],
#  ['fresh tuna',
#   'frozen vegetables',
#   'chicken',
#   'fromage blanc',
#   'honey',
#   'light mayo'],
#  ['ground beef'],
#  ['muffins', 'champagne', 'cookies', 'fresh bread', 'green tea'],
#  ['frozen vegetables', 'spaghetti', 'chocolate', 'escalope', 'fresh bread'],
#  ['pickles', 'spaghetti', 'french fries', 'frozen smoothie'],
#  ['avocado'],
#  ['sandwich'],
#  ['spaghetti', 'milk', 'oil', 'shampoo'],
#  ['champagne'],
#  ['spaghetti'],
#  ['champagne'],
#  ['avocado', 'milk', 'butter', 'french fries', 'cookies'],
#  ['turkey',
#   'frozen vegetables',
#   'chicken',
#   'eggs',
#   'frozen smoothie',
#   'cauliflower',
#   'low fat yogurt'],
#  ['burgers',
#   'shrimp',
#   'tomatoes',
#   'milk',
#   'energy bar',
#   'almonds',
#   'chicken',
#   'chocolate',
#   'french fries',
#   'body spray'],
#  ['burgers',
#   'milk',
#   'cake',
#   'cooking oil',
#   'french fries',
#   'escalope',
#   'zucchini'],
#  ['tomatoes',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'olive oil',
#   'whole wheat rice',
#   'cake',
#   'frozen smoothie',
#   'protein bar'],
#  ['fresh tuna',
#   'red wine',
#   'pepper',
#   'spaghetti',
#   'fromage blanc',
#   'salmon',
#   'pancakes',
#   'eggs',
#   'honey',
#   'green tea'],
#  ['milk', 'low fat yogurt'],
#  ['shrimp', 'parmesan cheese', 'soup', 'chocolate', 'brownies'],
#  ['spaghetti', 'chicken'],
#  ['grated cheese', 'vegetables mix', 'nonfat milk', 'green tea'],
#  ['fresh tuna',
#   'parmesan cheese',
#   'cider',
#   'muffins',
#   'spinach',
#   'honey',
#   'oil'],
#  ['cake'],
#  ['shrimp', 'chocolate', 'mushroom cream sauce', 'candy bars'],
#  ['candy bars'],
#  ['avocado', 'honey'],
#  ['shrimp', 'frozen vegetables', 'tomatoes', 'cottage cheese'],
#  ['french fries'],
#  ['strawberries'],
#  ['ground beef', 'almonds', 'french fries', 'escalope'],
#  ['grated cheese', 'spaghetti'],
#  ['turkey', 'mineral water', 'butter', 'frozen smoothie'],
#  ['frozen vegetables', 'spaghetti', 'french fries', 'light mayo', 'green tea'],
#  ['burgers',
#   'ham',
#   'spaghetti',
#   'whole wheat rice',
#   'eggplant',
#   'chocolate',
#   'cookies',
#   'shallot',
#   'green tea'],
#  ['grated cheese',
#   'frozen vegetables',
#   'spaghetti',
#   'avocado',
#   'milk',
#   'blueberries',
#   'light cream',
#   'rice',
#   'green tea',
#   'chocolate',
#   'french fries',
#   'frozen smoothie',
#   'cookies',
#   'hot dogs'],
#  ['burgers', 'shrimp', 'tomatoes', 'bacon', 'whole wheat rice', 'green tea'],
#  ['parmesan cheese', 'pancakes'],
#  ['parmesan cheese', 'cake', 'hot dogs', 'green tea'],
#  ['spaghetti', 'milk', 'fromage blanc', 'ketchup', 'chocolate', 'babies food'],
#  ['mint'],
#  ['chocolate', 'mint'],
#  ['butter', 'french fries', 'salt', 'fresh bread'],
#  ['chocolate', 'french fries', 'strawberries', 'yogurt cake', 'light mayo'],
#  ['eggs', 'eggplant', 'cookies'],
#  ['yogurt cake'],
#  ['herb & pepper',
#   'spaghetti',
#   'meatballs',
#   'milk',
#   'olive oil',
#   'chicken',
#   'honey',
#   'frozen smoothie',
#   'escalope',
#   'pancakes'],
#  ['frozen vegetables', 'rice', 'chocolate'],
#  ['herb & pepper',
#   'ground beef',
#   'spaghetti',
#   'chocolate',
#   'milk',
#   'eggs',
#   'light cream'],
#  ['eggs', 'champagne'],
#  ['whole wheat pasta', 'ground beef', 'olive oil', 'blueberries', 'escalope'],
#  ['burgers',
#   'red wine',
#   'mineral water',
#   'eggs',
#   'oil',
#   'carrots',
#   'hand protein bar',
#   'tomato juice'],
#  ['chocolate',
#   'grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'soup',
#   'olive oil'],
#  ['burgers',
#   'shrimp',
#   'mineral water',
#   'chicken',
#   'fromage blanc',
#   'salmon',
#   'eggs',
#   'cake',
#   'frozen smoothie',
#   'strawberries'],
#  ['green tea'],
#  ['cookies'],
#  ['french fries', 'cookies'],
#  ['milk', 'butter', 'eggs'],
#  ['eggs', 'mushroom cream sauce', 'low fat yogurt'],
#  ['eggs', 'green tea'],
#  ['mineral water', 'whole wheat rice'],
#  ['shrimp',
#   'frozen vegetables',
#   'parmesan cheese',
#   'mineral water',
#   'whole wheat rice',
#   'cake'],
#  ['whole wheat rice', 'pancakes'],
#  ['frozen vegetables',
#   'spaghetti',
#   'olive oil',
#   'butter',
#   'salmon',
#   'oil',
#   'cooking oil',
#   'frozen smoothie',
#   'cauliflower'],
#  ['green tea'],
#  ['fresh tuna', 'eggs', 'escalope', 'strawberries'],
#  ['spaghetti', 'soup', 'milk', 'carrots', 'chocolate'],
#  ['burgers', 'mineral water', 'soup', 'meatballs', 'olive oil'],
#  ['grated cheese',
#   'mineral water',
#   'cooking oil',
#   'french fries',
#   'cookies',
#   'low fat yogurt'],
#  ['shrimp', 'milk', 'olive oil', 'french fries'],
#  ['frozen vegetables', 'mineral water', 'pancakes', 'cake', 'tomato juice'],
#  ['spaghetti', 'milk', 'chicken'],
#  ['grated cheese',
#   'mineral water',
#   'chicken',
#   'french fries',
#   'cottage cheese',
#   'pancakes'],
#  ['ground beef', 'mineral water', 'milk', 'eggs', 'mint'],
#  ['shrimp', 'body spray', 'green tea'],
#  ['frozen smoothie'],
#  ['herb & pepper', 'frozen vegetables', 'mineral water', 'muffins', 'cereals'],
#  ['turkey',
#   'tomatoes',
#   'spaghetti',
#   'milk',
#   'cider',
#   'eggs',
#   'honey',
#   'cake',
#   'green tea',
#   'french fries',
#   'brownies',
#   'tomato juice'],
#  ...]

# %% [markdown]
# mlxtend
# https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

start_time = time.time()
frequent_itemsets_fpgrowth = fpgrowth(df, min_support=0.03, use_colnames=True)
print(f'Время выполнения метода: {time.time() - start_time}')
frequent_itemsets_fpgrowth
# Out:
# Время выполнения метода: 0.15456342697143555
#      support                            itemsets
# 0   0.238368                     (mineral water)
# 1   0.132116                         (green tea)
# 2   0.076523                    (low fat yogurt)
# 3   0.071457                            (shrimp)
# 4   0.065858                         (olive oil)
# 5   0.063325                   (frozen smoothie)
# 6   0.047460                             (honey)
# 7   0.042528                            (salmon)
# 8   0.033329                           (avocado)
# 9   0.031862                    (cottage cheese)
# 10  0.030396                      (tomato juice)
# 11  0.179709                              (eggs)
# 12  0.087188                           (burgers)
# 13  0.062525                            (turkey)
# 14  0.129583                              (milk)
# 15  0.058526                  (whole wheat rice)
# 16  0.170911                      (french fries)
# 17  0.050527                              (soup)
# 18  0.174110                         (spaghetti)
# 19  0.095321                 (frozen vegetables)
# 20  0.080389                           (cookies)
# 21  0.051060                       (cooking oil)
# 22  0.046794                         (champagne)
# 23  0.163845                         (chocolate)
# 24  0.059992                           (chicken)
# 25  0.068391                          (tomatoes)
# 26  0.095054                          (pancakes)
# 27  0.052393                     (grated cheese)
# 28  0.043061                       (fresh bread)
# 29  0.098254                       (ground beef)
# 30  0.079323                          (escalope)
# 31  0.049460                     (herb & pepper)
# 32  0.081056                              (cake)
# 33  0.032396                          (hot dogs)
# 34  0.033729                          (brownies)
# 35  0.030129                            (butter)
# 36  0.031063          (green tea, mineral water)
# 37  0.050927               (eggs, mineral water)
# 38  0.047994               (milk, mineral water)
# 39  0.035462                   (milk, spaghetti)
# 40  0.032129                   (milk, chocolate)
# 41  0.030796                        (milk, eggs)
# 42  0.036395                (eggs, french fries)
# 43  0.033729       (french fries, mineral water)
# 44  0.059725          (spaghetti, mineral water)
# 45  0.036528                   (eggs, spaghetti)
# 46  0.035729  (frozen vegetables, mineral water)
# 47  0.033196                   (eggs, chocolate)
# 48  0.052660          (chocolate, mineral water)
# 49  0.034395           (french fries, chocolate)
# 50  0.039195              (spaghetti, chocolate)
# 51  0.033729           (pancakes, mineral water)
# 52  0.040928        (ground beef, mineral water)
# 53  0.039195            (spaghetti, ground beef)

# %%
start_time = time.time()
frequent_itemsets_apriori = apriori(df, min_support=0.03, use_colnames=True)
print(f'Время выполнения метода: {time.time() - start_time}')
frequent_itemsets_apriori
# Out:
# Время выполнения метода: 0.06768918037414551
#      support                            itemsets
# 0   0.033329                           (avocado)
# 1   0.033729                          (brownies)
# 2   0.087188                           (burgers)
# 3   0.030129                            (butter)
# 4   0.081056                              (cake)
# 5   0.046794                         (champagne)
# 6   0.059992                           (chicken)
# 7   0.163845                         (chocolate)
# 8   0.080389                           (cookies)
# 9   0.051060                       (cooking oil)
# 10  0.031862                    (cottage cheese)
# 11  0.179709                              (eggs)
# 12  0.079323                          (escalope)
# 13  0.170911                      (french fries)
# 14  0.043061                       (fresh bread)
# 15  0.063325                   (frozen smoothie)
# 16  0.095321                 (frozen vegetables)
# 17  0.052393                     (grated cheese)
# 18  0.132116                         (green tea)
# 19  0.098254                       (ground beef)
# 20  0.049460                     (herb & pepper)
# 21  0.047460                             (honey)
# 22  0.032396                          (hot dogs)
# 23  0.076523                    (low fat yogurt)
# 24  0.129583                              (milk)
# 25  0.238368                     (mineral water)
# 26  0.065858                         (olive oil)
# 27  0.095054                          (pancakes)
# 28  0.042528                            (salmon)
# 29  0.071457                            (shrimp)
# 30  0.050527                              (soup)
# 31  0.174110                         (spaghetti)
# 32  0.030396                      (tomato juice)
# 33  0.068391                          (tomatoes)
# 34  0.062525                            (turkey)
# 35  0.058526                  (whole wheat rice)
# 36  0.033196                   (eggs, chocolate)
# 37  0.034395           (french fries, chocolate)
# 38  0.032129                   (milk, chocolate)
# 39  0.052660          (chocolate, mineral water)
# 40  0.039195              (spaghetti, chocolate)
# 41  0.036395                (eggs, french fries)
# 42  0.030796                        (milk, eggs)
# 43  0.050927               (eggs, mineral water)
# 44  0.036528                   (eggs, spaghetti)
# 45  0.033729       (french fries, mineral water)
# 46  0.035729  (frozen vegetables, mineral water)
# 47  0.031063          (green tea, mineral water)
# 48  0.040928        (ground beef, mineral water)
# 49  0.039195            (spaghetti, ground beef)
# 50  0.047994               (milk, mineral water)
# 51  0.035462                   (milk, spaghetti)
# 52  0.033729           (pancakes, mineral water)
# 53  0.059725          (spaghetti, mineral water)

# %%
start_time = time.time()
association_rules(frequent_itemsets_fpgrowth, metric="confidence", min_threshold=0.28)
print(f'Время выполнения метода: {time.time() - start_time}')
# Out:
# Время выполнения метода: 0.005567789077758789

# %%
start_time = time.time()
association_rules(frequent_itemsets_apriori, metric="lift", min_threshold=1)
print(f'Время выполнения метода: {time.time() - start_time}')
# Out:
# Время выполнения метода: 0.0075397491455078125

# %% [markdown]
# https://github.com/evandempsey/fp-growth

# %%
# !pip install pyfpgrowth
import pyfpgrowth
# Out:
# Requirement already satisfied: pyfpgrowth in c:\users\lesya\documents\study\ml\association-rule-mining\venv\lib\site-packages (1.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
start_time = time.time()
frequent_itemsets_fpgrowth_2 = pyfpgrowth.find_frequent_patterns(dataset, 5)
print(f'Время выполнения метода: {time.time() - start_time}')
print(f'Количество частых наборов: {len(frequent_itemsets_fpgrowth_2)}')

frequent_itemsets_fpgrowth_2
# Out:
# Время выполнения метода: 1.343292236328125
# Количество частых наборов: 12049
# {('napkins',): 5,
#  ('cream',): 7,
#  ('bramble',): 14,
#  ('bramble', 'mineral water'): 5,
#  ('tea', 'tomatoes'): 5,
#  ('frozen smoothie', 'tea'): 5,
#  ('ground beef', 'tea'): 5,
#  ('frozen vegetables', 'ground beef', 'tea'): 5,
#  ('soup', 'tea'): 6,
#  ('pancakes', 'tea'): 7,
#  ('chocolate', 'tea'): 7,
#  ('escalope', 'tea'): 7,
#  ('milk', 'tea'): 7,
#  ('eggs', 'tea'): 8,
#  ('frozen vegetables', 'tea'): 10,
#  ('spaghetti', 'tea'): 11,
#  ('mineral water', 'tea'): 11,
#  ('cereals', 'chutney'): 5,
#  ('chutney', 'ground beef'): 5,
#  ('chutney', 'ground beef', 'mineral water'): 5,
#  ('chutney', 'grated cheese'): 5,
#  ('chutney', 'milk'): 6,
#  ('chocolate', 'chutney'): 6,
#  ('chutney', 'frozen vegetables'): 7,
#  ('chutney', 'spaghetti'): 11,
#  ('chutney', 'mineral water', 'spaghetti'): 6,
#  ('chutney', 'eggs'): 11,
#  ('chutney', 'eggs', 'mineral water'): 7,
#  ('chutney', 'mineral water'): 13,
#  ('cake', 'mashed potato'): 5,
#  ('mashed potato', 'soup'): 5,
#  ('escalope', 'mashed potato'): 5,
#  ('frozen vegetables', 'mashed potato'): 6,
#  ('eggs', 'mashed potato'): 6,
#  ('french fries', 'mashed potato'): 7,
#  ('chocolate', 'mashed potato'): 8,
#  ('mashed potato', 'mineral water'): 11,
#  ('mashed potato', 'spaghetti'): 11,
#  ('cake', 'chocolate bread'): 5,
#  ('chocolate bread', 'low fat yogurt'): 5,
#  ('chicken', 'chocolate bread'): 6,
#  ('chocolate bread', 'frozen vegetables'): 6,
#  ('chocolate bread', 'green tea'): 6,
#  ('chocolate bread', 'french fries'): 6,
#  ('chocolate bread', 'spaghetti'): 6,
#  ('chocolate bread', 'whole wheat rice'): 6,
#  ('chocolate bread', 'red wine'): 8,
#  ('chocolate bread', 'mineral water', 'red wine'): 5,
#  ('chocolate bread', 'mineral water'): 14,
#  ('dessert wine', 'green tea'): 5,
#  ('dessert wine', 'soup'): 5,
#  ('dessert wine', 'tomatoes'): 5,
#  ('dessert wine', 'frozen smoothie'): 5,
#  ('dessert wine', 'french fries'): 5,
#  ('champagne', 'dessert wine'): 5,
#  ('burgers', 'dessert wine'): 6,
#  ('dessert wine', 'ground beef'): 7,
#  ('dessert wine', 'ground beef', 'salmon'): 5,
#  ('dessert wine', 'eggs'): 7,
#  ('dessert wine', 'salmon'): 8,
#  ('dessert wine', 'mineral water', 'salmon'): 5,
#  ('dessert wine', 'milk'): 8,
#  ('dessert wine', 'milk', 'mineral water'): 5,
#  ('dessert wine', 'spaghetti'): 10,
#  ('dessert wine', 'mineral water'): 12,
#  ('green tea', 'ketchup'): 6,
#  ('cooking oil', 'ketchup'): 6,
#  ('ketchup', 'olive oil'): 6,
#  ('ketchup', 'tomatoes'): 6,
#  ('ketchup', 'whole wheat rice'): 6,
#  ('grated cheese', 'ketchup'): 6,
#  ('ground beef', 'ketchup'): 6,
#  ('ketchup', 'turkey'): 8,
#  ('french fries', 'ketchup', 'turkey'): 5,
#  ('french fries', 'ketchup'): 9,
#  ('ketchup', 'mineral water'): 10,
#  ('ketchup', 'mineral water', 'pancakes'): 5,
#  ('ketchup', 'milk'): 10,
#  ('ketchup', 'milk', 'spaghetti'): 5,
#  ('ketchup', 'spaghetti'): 11,
#  ('ketchup', 'pancakes', 'spaghetti'): 5,
#  ('ketchup', 'pancakes'): 12,
#  ('chicken', 'oatmeal'): 5,
#  ('oatmeal', 'soup'): 5,
#  ('oatmeal', 'shrimp'): 5,
#  ('oatmeal', 'olive oil'): 6,
#  ('oatmeal', 'pancakes'): 6,
#  ('french fries', 'oatmeal'): 6,
#  ('eggs', 'oatmeal'): 6,
#  ('frozen vegetables', 'oatmeal'): 6,
#  ('milk', 'oatmeal'): 7,
#  ('ground beef', 'oatmeal'): 8,
#  ('ground beef', 'mineral water', 'oatmeal'): 5,
#  ('green tea', 'oatmeal'): 8,
#  ('oatmeal', 'spaghetti'): 8,
#  ('chocolate', 'oatmeal'): 10,
#  ('chocolate', 'mineral water', 'oatmeal'): 7,
#  ('mineral water', 'oatmeal'): 13,
#  ('sandwich', 'tomatoes'): 5,
#  ('green tea', 'sandwich'): 5,
#  ('mineral water', 'sandwich'): 5,
#  ('honey', 'sandwich'): 5,
#  ('escalope', 'sandwich'): 5,
#  ('frozen smoothie', 'sandwich'): 6,
#  ('french fries', 'sandwich'): 6,
#  ('chocolate', 'sandwich'): 7,
#  ('sandwich', 'spaghetti'): 8,
#  ('babies food', 'spaghetti'): 5,
#  ('babies food', 'low fat yogurt'): 5,
#  ('babies food', 'french fries'): 6,
#  ('babies food', 'shrimp'): 6,
#  ('babies food', 'cookies'): 7,
#  ('babies food', 'burgers'): 7,
#  ('babies food', 'milk'): 8,
#  ('babies food', 'chocolate', 'milk'): 5,
#  ('babies food', 'chocolate'): 13,
#  ('asparagus', 'soup'): 5,
#  ('asparagus', 'pancakes'): 5,
#  ('asparagus', 'olive oil'): 5,
#  ('asparagus', 'salmon'): 5,
#  ('asparagus', 'eggs'): 6,
#  ('asparagus', 'green tea'): 6,
#  ('asparagus', 'spaghetti'): 7,
#  ('asparagus', 'mineral water', 'spaghetti'): 5,
#  ('asparagus', 'chocolate'): 9,
#  ('asparagus', 'chocolate', 'mineral water'): 6,
#  ('asparagus', 'french fries'): 9,
#  ('asparagus', 'milk'): 10,
#  ('asparagus', 'milk', 'mineral water'): 5,
#  ('asparagus', 'mineral water'): 16,
#  ('corn', 'soup'): 5,
#  ('corn', 'green tea'): 6,
#  ('corn', 'frozen vegetables'): 6,
#  ('corn', 'milk'): 7,
#  ('corn', 'tomatoes'): 8,
#  ('corn', 'eggs'): 8,
#  ('burgers', 'corn'): 9,
#  ('chocolate', 'corn'): 10,
#  ('corn', 'mineral water'): 11,
#  ('corn', 'spaghetti'): 11,
#  ('cauliflower', 'whole wheat rice'): 5,
#  ('cauliflower', 'tomatoes'): 5,
#  ('cauliflower', 'red wine'): 5,
#  ('cauliflower', 'green tea'): 6,
#  ('cauliflower', 'low fat yogurt'): 6,
#  ('cauliflower', 'chocolate'): 6,
#  ('cauliflower', 'french fries'): 7,
#  ('cauliflower', 'frozen vegetables'): 7,
#  ('cauliflower', 'olive oil'): 7,
#  ('cauliflower', 'olive oil', 'spaghetti'): 5,
#  ('cauliflower', 'hot dogs'): 7,
#  ('cauliflower', 'hot dogs', 'mineral water'): 5,
#  ('cauliflower', 'eggs'): 8,
#  ('cauliflower', 'milk'): 8,
#  ('cauliflower', 'milk', 'mineral water'): 5,
#  ('cauliflower', 'ground beef'): 9,
#  ('cauliflower', 'ground beef', 'spaghetti'): 5,
#  ('cauliflower', 'spaghetti'): 11,
#  ('cauliflower', 'mineral water', 'spaghetti'): 5,
#  ('cauliflower', 'mineral water'): 14,
#  ('olive oil', 'salad'): 5,
#  ('salad', 'shrimp'): 6,
#  ('cereals', 'salad'): 6,
#  ('french fries', 'salad'): 7,
#  ('milk', 'salad'): 7,
#  ('green tea', 'salad'): 8,
#  ('mineral water', 'salad'): 9,
#  ('eggs', 'salad'): 9,
#  ('cooking oil', 'shampoo'): 5,
#  ('milk', 'shampoo'): 5,
#  ('burgers', 'shampoo'): 5,
#  ('hot dogs', 'shampoo'): 5,
#  ('pancakes', 'shampoo'): 5,
#  ('eggs', 'shampoo'): 6,
#  ('low fat yogurt', 'shampoo'): 6,
#  ('shampoo', 'tomatoes'): 6,
#  ('frozen vegetables', 'shampoo'): 6,
#  ('chocolate', 'shampoo'): 7,
#  ('french fries', 'shampoo'): 7,
#  ('green tea', 'shampoo'): 9,
#  ('shampoo', 'spaghetti'): 11,
#  ('mineral water', 'shampoo'): 11,
#  ('mineral water', 'shampoo', 'spaghetti'): 6,
#  ('hand protein bar', 'red wine'): 5,
#  ('butter', 'hand protein bar'): 5,
#  ('cookies', 'hand protein bar'): 5,
#  ('frozen vegetables', 'hand protein bar'): 5,
#  ('hand protein bar', 'pancakes'): 5,
#  ('hand protein bar', 'mineral water', 'pancakes'): 5,
#  ('hand protein bar', 'honey'): 5,
#  ('hand protein bar', 'tomato juice'): 6,
#  ('hand protein bar', 'milk'): 6,
#  ('hand protein bar', 'olive oil'): 6,
#  ('hand protein bar', 'shrimp'): 6,
#  ('chocolate', 'hand protein bar', 'shrimp'): 5,
#  ('burgers', 'hand protein bar'): 7,
#  ('burgers', 'hand protein bar', 'mineral water'): 6,
#  ('cooking oil', 'hand protein bar'): 7,
#  ('french fries', 'hand protein bar'): 8,
#  ('green tea', 'hand protein bar'): 9,
#  ('hand protein bar', 'protein bar'): 9,
#  ('hand protein bar', 'tomatoes'): 9,
#  ('chocolate', 'hand protein bar'): 11,
#  ('hand protein bar', 'mineral water', 'spaghetti'): 5,
#  ('chocolate', 'hand protein bar', 'spaghetti'): 7,
#  ('hand protein bar', 'mineral water'): 15,
#  ('mint green tea', 'salmon'): 5,
#  ('mint green tea', 'soup'): 5,
#  ('chicken', 'mint green tea'): 5,
#  ('mint green tea', 'turkey'): 5,
#  ('escalope', 'mint green tea'): 5,
#  ('mint green tea', 'olive oil'): 5,
#  ('frozen vegetables', 'mint green tea'): 6,
#  ('low fat yogurt', 'mint green tea'): 6,
#  ('mint green tea', 'pancakes'): 6,
#  ('chocolate', 'mint green tea'): 6,
#  ('ground beef', 'mint green tea'): 7,
#  ('cake', 'mint green tea'): 7,
#  ('eggs', 'mint green tea'): 7,
#  ('eggs', 'french fries', 'mint green tea'): 5,
#  ('mineral water', 'mint green tea'): 10,
#  ('mineral water', 'mint green tea', 'spaghetti'): 5,
#  ('mint green tea', 'spaghetti'): 11,
#  ('french fries', 'mint green tea', 'spaghetti'): 6,
#  ('milk', 'mint green tea'): 12,
#  ('french fries', 'milk', 'mint green tea'): 5,
#  ('french fries', 'mint green tea'): 14,
#  ('burger sauce', 'escalope'): 5,
#  ('blueberries', 'burger sauce'): 5,
#  ('burger sauce', 'cooking oil'): 5,
#  ('burger sauce', 'fresh bread'): 6,
#  ('burger sauce', 'oil'): 6,
#  ('burger sauce', 'salmon'): 6,
#  ('burger sauce', 'mineral water', 'salmon'): 5,
#  ('burger sauce', 'olive oil'): 6,
#  ('burger sauce', 'olive oil', 'spaghetti'): 5,
#  ('burger sauce', 'green tea'): 6,
#  ('burger sauce', 'herb & pepper'): 6,
#  ('burger sauce', 'turkey'): 7,
#  ('burger sauce', 'cake'): 7,
#  ('burger sauce', 'pancakes'): 7,
#  ('burger sauce', 'chicken', 'frozen smoothie'): 5,
#  ('burger sauce', 'frozen smoothie', 'mineral water'): 5,
#  ('burger sauce', 'french fries', 'milk'): 5,
#  ('burger sauce', 'french fries', 'ground beef'): 5,
#  ('burger sauce', 'shrimp'): 8,
#  ('burger sauce', 'mineral water', 'shrimp'): 5,
#  ('burger sauce', 'shrimp', 'spaghetti'): 6,
#  ('burger sauce', 'mineral water', 'shrimp', 'spaghetti'): 5,
#  ('burger sauce', 'chocolate', 'spaghetti'): 5,
#  ('burger sauce', 'chocolate', 'mineral water'): 6,
#  ('burger sauce', 'milk', 'mineral water'): 6,
#  ('burger sauce', 'milk', 'spaghetti'): 7,
#  ('burger sauce', 'chicken', 'ground beef'): 5,
#  ('burger sauce', 'ground beef', 'spaghetti'): 6,
#  ('burger sauce', 'chicken', 'spaghetti'): 6,
#  ('burger sauce', 'chicken', 'mineral water'): 8,
#  ('burger sauce', 'eggs', 'mineral water'): 6,
#  ('burger sauce', 'chicken', 'eggs', 'mineral water'): 5,
#  ('burger sauce', 'chicken', 'eggs'): 7,
#  ('burger sauce', 'mineral water'): 18,
#  ('burger sauce', 'mineral water', 'spaghetti'): 10,
#  ('burger sauce', 'spaghetti'): 18,
#  ('milk', 'pickles'): 5,
#  ('frozen smoothie', 'pickles'): 5,
#  ('herb & pepper', 'pickles'): 5,
#  ('eggs', 'pickles'): 5,
#  ('mineral water', 'pickles'): 6,
#  ('pancakes', 'pickles'): 6,
#  ('chocolate', 'pickles'): 6,
#  ('cake', 'pickles'): 6,
#  ('pickles', 'tomatoes'): 6,
#  ('pickles', 'spaghetti'): 10,
#  ('french fries', 'pickles'): 12,
#  ('green tea', 'pickles'): 13,
#  ('mayonnaise', 'tomato juice'): 5,
#  ('frozen vegetables', 'mayonnaise'): 5,
#  ('low fat yogurt', 'mayonnaise'): 5,
#  ('mayonnaise', 'tomatoes'): 5,
#  ('mayonnaise', 'olive oil'): 6,
#  ('mayonnaise', 'mineral water', 'olive oil'): 5,
#  ('french fries', 'mayonnaise'): 6,
#  ('ground beef', 'mayonnaise'): 6,
#  ('ground beef', 'mayonnaise', 'mineral water'): 5,
#  ('burgers', 'mayonnaise'): 7,
#  ('burgers', 'mayonnaise', 'mineral water'): 5,
#  ('chocolate', 'mayonnaise'): 7,
#  ('chocolate', 'mayonnaise', 'spaghetti'): 5,
#  ('mayonnaise', 'soup'): 7,
#  ('mayonnaise', 'mineral water', 'soup'): 5,
#  ('mayonnaise', 'milk'): 7,
#  ('magazines', 'mayonnaise'): 7,
#  ('magazines', 'mayonnaise', 'mineral water'): 5,
#  ('eggs', 'mayonnaise'): 9,
#  ('eggs', 'mayonnaise', 'mineral water'): 7,
#  ('mayonnaise', 'pancakes'): 9,
#  ('mayonnaise', 'mineral water', 'pancakes'): 7,
#  ('green tea', 'mayonnaise'): 10,
#  ('green tea', 'mayonnaise', 'mineral water'): 6,
#  ('mayonnaise', 'spaghetti'): 14,
#  ('mayonnaise', 'mineral water', 'spaghetti'): 8,
#  ('mayonnaise', 'mineral water'): 22,
#  ('chili', 'pepper'): 5,
#  ('chili', 'fresh bread'): 5,
#  ('chili', 'oil'): 5,
#  ('chili', 'red wine'): 5,
#  ('chili', 'turkey'): 5,
#  ('chili', 'salmon'): 5,
#  ('chili', 'milk'): 6,
#  ('chili', 'escalope'): 7,
#  ('chili', 'escalope', 'mineral water'): 6,
#  ('chili', 'olive oil'): 7,
#  ('chili', 'ground beef', 'olive oil'): 5,
#  ('cake', 'chili'): 7,
#  ('chili', 'eggs'): 7,
#  ('chili', 'herb & pepper'): 7,
#  ('chili', 'cooking oil'): 7,
#  ('chicken', 'chili', 'cooking oil'): 5,
#  ('chili', 'tomatoes'): 8,
#  ('chili', 'spaghetti', 'tomatoes'): 6,
#  ('chili', 'green tea'): 8,
#  ('chicken', 'chili'): 9,
#  ('chicken', 'chili', 'spaghetti'): 5,
#  ('chili', 'pancakes'): 9,
#  ('chili', 'french fries'): 9,
#  ('chili', 'shrimp'): 9,
#  ('chili', 'ground beef', 'mineral water'): 5,
#  ('chili', 'ground beef', 'spaghetti'): 7,
#  ('chili', 'chocolate'): 13,
#  ('chili', 'chocolate', 'spaghetti'): 6,
#  ('chili', 'mineral water'): 16,
#  ('chili', 'mineral water', 'spaghetti'): 9,
#  ('chili', 'spaghetti'): 18,
#  ('light mayo', 'sparkling water'): 5,
#  ('salmon', 'sparkling water'): 5,
#  ('honey', 'sparkling water'): 6,
#  ('frozen smoothie', 'honey', 'sparkling water'): 5,
#  ('cake', 'sparkling water'): 6,
#  ('escalope', 'sparkling water'): 6,
#  ('spaghetti', 'sparkling water'): 6,
#  ('pancakes', 'sparkling water'): 6,
#  ('burgers', 'sparkling water'): 7,
#  ('frozen vegetables', 'sparkling water'): 7,
#  ('eggs', 'sparkling water'): 7,
#  ('chocolate', 'sparkling water'): 8,
#  ('chocolate', 'frozen smoothie', 'sparkling water'): 5,
#  ('green tea', 'sparkling water'): 9,
#  ('milk', 'sparkling water'): 9,
#  ('milk', 'mineral water', 'sparkling water'): 5,
#  ('ground beef', 'sparkling water'): 9,
#  ('french fries', 'sparkling water'): 10,
#  ('french fries', 'hot dogs', 'sparkling water'): 5,
#  ('frozen smoothie', 'sparkling water'): 11,
#  ('frozen smoothie', 'mineral water', 'sparkling water'): 6,
#  ('hot dogs', 'sparkling water'): 12,
#  ('mineral water', 'sparkling water'): 13,
#  ('chicken', 'soda'): 5,
#  ('green tea', 'soda'): 5,
#  ('soda', 'white wine'): 5,
#  ('low fat yogurt', 'soda'): 5,
#  ('frozen vegetables', 'soda'): 7,
#  ('chocolate', 'soda'): 7,
#  ('ground beef', 'soda'): 7,
#  ('milk', 'soda'): 7,
#  ('milk', 'mineral water', 'soda'): 5,
#  ('eggs', 'soda'): 8,
#  ('eggs', 'mineral water', 'soda'): 5,
#  ('soda', 'spaghetti'): 9,
#  ('mineral water', 'soda'): 12,
#  ('low fat yogurt', 'pet food'): 5,
#  ('pancakes', 'pet food'): 5,
#  ('cooking oil', 'pet food'): 5,
#  ('pet food', 'tomatoes'): 5,
#  ('chocolate', 'pet food'): 6,
#  ('green tea', 'pet food'): 8,
#  ('cake', 'pet food'): 8,
#  ('cake', 'mineral water', 'pet food'): 5,
#  ('frozen vegetables', 'pet food'): 8,
#  ('pet food', 'soup'): 8,
#  ('french fries', 'pet food'): 8,
#  ('ground beef', 'pet food'): 10,
#  ('pet food', 'turkey'): 10,
#  ('eggs', 'pet food', 'spaghetti'): 5,
#  ('mineral water', 'pet food', 'spaghetti'): 5,
#  ('pet food', 'red wine'): 12,
#  ('mineral water', 'pet food', 'red wine'): 5,
#  ('eggs', 'pet food'): 13,
#  ('eggs', 'mineral water', 'pet food'): 7,
#  ('mineral water', 'pet food'): 15,
#  ('cooking oil', 'gluten free bar'): 5,
#  ('gluten free bar', 'milk'): 5,
#  ('fresh tuna', 'gluten free bar'): 5,
#  ('cottage cheese', 'gluten free bar'): 5,
#  ('burgers', 'gluten free bar'): 5,
#  ('gluten free bar', 'muffins'): 5,
#  ('escalope', 'gluten free bar'): 5,
#  ('fresh bread', 'gluten free bar'): 5,
#  ('chocolate', 'gluten free bar'): 6,
#  ('gluten free bar', 'salmon'): 7,
#  ('frozen vegetables', 'gluten free bar'): 7,
#  ('gluten free bar', 'low fat yogurt'): 7,
#  ('gluten free bar', 'light mayo'): 8,
#  ('gluten free bar', 'green tea'): 8,
#  ('gluten free bar', 'grated cheese'): 8,
#  ('gluten free bar', 'spaghetti'): 10,
#  ('gluten free bar', 'pancakes', 'spaghetti'): 6,
#  ('french fries', 'gluten free bar'): 10,
#  ('eggs', 'french fries', 'gluten free bar'): 5,
#  ('eggs', 'gluten free bar'): 12,
#  ('eggs', 'gluten free bar', 'pancakes'): 6,
#  ('gluten free bar', 'pancakes'): 16,
#  ('gluten free bar', 'mineral water'): 16,
#  ('spinach', 'vegetables mix'): 5,
#  ('energy drink', 'spinach'): 5,
#  ('spinach', 'tomato juice'): 5,
#  ('olive oil', 'spinach'): 5,
#  ('shrimp', 'spinach'): 5,
#  ('oil', 'spinach'): 5,
#  ('herb & pepper', 'spinach'): 5,
#  ('cooking oil', 'spinach'): 5,
#  ('spinach', 'tomatoes'): 5,
#  ('fresh tuna', 'spinach'): 6,
#  ('cake', 'spinach'): 6,
#  ('light mayo', 'spinach'): 6,
#  ('salmon', 'spinach'): 7,
#  ('honey', 'spinach'): 7,
#  ('spinach', 'turkey'): 7,
#  ('grated cheese', 'spinach'): 7,
#  ('chocolate', 'spinach'): 7,
#  ('frozen smoothie', 'spinach'): 9,
#  ('frozen smoothie', 'mineral water', 'spinach'): 8,
#  ('green tea', 'spinach'): 10,
#  ('eggs', 'spaghetti', 'spinach'): 5,
#  ('eggs', 'mineral water', 'spinach'): 5,
#  ('milk', 'spinach'): 12,
#  ('milk', 'mineral water', 'spinach'): 8,
#  ('spaghetti', 'spinach'): 14,
#  ('mineral water', 'spaghetti', 'spinach'): 10,
#  ('french fries', 'spinach'): 16,
#  ('french fries', 'mineral water', 'spinach'): 5,
#  ('mineral water', 'spinach'): 20,
#  ('shallot', 'white wine'): 5,
#  ('escalope', 'shallot', 'white wine'): 5,
#  ('ground beef', 'shallot'): 5,
#  ('shallot', 'tomato juice'): 6,
#  ('frozen vegetables', 'shallot'): 6,
#  ('milk', 'shallot'): 6,
#  ('burgers', 'shallot'): 7,
#  ('salmon', 'shallot'): 7,
#  ('shallot', 'spaghetti'): 9,
#  ('mineral water', 'shallot'): 9,
#  ('chocolate', 'shallot'): 10,
#  ('chocolate', 'french fries', 'shallot'): 5,
#  ('green tea', 'low fat yogurt', 'shallot'): 5,
#  ('french fries', 'low fat yogurt', 'shallot'): 8,
#  ('cookies', 'french fries', 'low fat yogurt', 'shallot'): 7,
#  ('cookies', 'low fat yogurt', 'shallot'): 9,
#  ('escalope', 'shallot'): 14,
#  ('cookies', 'french fries', 'shallot'): 9,
#  ('cookies', 'green tea', 'shallot'): 9,
#  ('green tea', 'shallot'): 17,
#  ('french fries', 'green tea', 'shallot'): 9,
#  ('french fries', 'shallot'): 20,
#  ('strong cheese', 'turkey'): 5,
#  ('honey', 'strong cheese'): 5,
#  ('salmon', 'strong cheese'): 6,
#  ('frozen smoothie', 'strong cheese'): 6,
#  ('almonds', 'strong cheese'): 6,
#  ('almonds', 'spaghetti', 'strong cheese'): 5,
#  ('french wine', 'strong cheese'): 6,
#  ('eggs', 'strong cheese'): 6,
#  ('pepper', 'strong cheese'): 6,
#  ('strong cheese', 'tomatoes'): 6,
#  ('chicken', 'strong cheese'): 6,
#  ('burgers', 'strong cheese'): 7,
#  ('shrimp', 'strong cheese'): 8,
#  ('mineral water', 'shrimp', 'strong cheese'): 7,
#  ('shrimp', 'spaghetti', 'strong cheese'): 5,
#  ('mineral water', 'shrimp', 'spaghetti', 'strong cheese'): 5,
#  ('green tea', 'strong cheese'): 9,
#  ('ground beef', 'milk', 'strong cheese'): 5,
#  ('frozen vegetables', 'ground beef', 'strong cheese'): 5,
#  ('frozen vegetables', 'ground beef', 'spaghetti', 'strong cheese'): 5,
#  ('ground beef', 'mineral water', 'strong cheese'): 6,
#  ('ground beef', 'mineral water', 'spaghetti', 'strong cheese'): 5,
#  ('ground beef', 'spaghetti', 'strong cheese'): 7,
#  ('olive oil', 'pancakes', 'strong cheese'): 5,
#  ('pancakes', 'spaghetti', 'strong cheese'): 5,
#  ('mineral water', 'pancakes', 'strong cheese'): 5,
#  ('mineral water', 'olive oil', 'strong cheese'): 7,
#  ('olive oil', 'spaghetti', 'strong cheese'): 8,
#  ('french fries', 'strong cheese'): 11,
#  ('chocolate', 'frozen vegetables', 'strong cheese'): 5,
#  ('frozen vegetables', 'mineral water', 'strong cheese'): 6,
#  ('frozen vegetables', 'spaghetti', 'strong cheese'): 6,
#  ('chocolate', 'mineral water', 'strong cheese'): 6,
#  ('chocolate', 'milk', 'strong cheese'): 6,
#  ('chocolate', 'milk', 'spaghetti', 'strong cheese'): 5,
#  ('chocolate', 'spaghetti', 'strong cheese'): 8,
#  ('milk', 'spaghetti', 'strong cheese'): 10,
#  ('milk', 'mineral water', 'spaghetti', 'strong cheese'): 8,
#  ('milk', 'mineral water', 'strong cheese'): 12,
#  ('mineral water', 'strong cheese'): 24,
#  ('mineral water', 'spaghetti', 'strong cheese'): 14,
#  ('spaghetti', 'strong cheese'): 28,
#  ('cookies', 'toothpaste'): 5,
#  ('oil', 'toothpaste'): 5,
#  ('frozen smoothie', 'toothpaste'): 5,
#  ('escalope', 'toothpaste'): 6,
#  ('eggplant', 'toothpaste'): 6,
#  ('shrimp', 'toothpaste'): 7,
#  ('tomatoes', 'toothpaste'): 7,
#  ('avocado', 'toothpaste'): 8,
#  ('burgers', 'toothpaste'): 8,
#  ('chicken', 'toothpaste'): 8,
#  ('frozen vegetables', 'toothpaste'): 8,
#  ('frozen vegetables', 'mineral water', 'toothpaste'): 5,
#  ('herb & pepper', 'spaghetti', 'toothpaste'): 5,
#  ('ground beef', 'herb & pepper', 'toothpaste'): 6,
#  ('french fries', 'toothpaste'): 9,
#  ('milk', 'spaghetti', 'toothpaste'): 5,
#  ('eggs', 'milk', 'toothpaste'): 6,
#  ('green tea', 'toothpaste'): 10,
#  ('green tea', 'ground beef', 'toothpaste'): 5,
#  ('eggs', 'toothpaste'): 10,
#  ('eggs', 'mineral water', 'toothpaste'): 6,
#  ('chocolate', 'toothpaste'): 10,
#  ('chocolate', 'pancakes', 'toothpaste'): 5,
#  ('ground beef', 'pancakes', 'toothpaste'): 5,
#  ('pancakes', 'spaghetti', 'toothpaste'): 6,
#  ('cake', 'toothpaste'): 13,
#  ('cooking oil', 'ground beef', 'toothpaste'): 5,
#  ('ground beef', 'spaghetti', 'toothpaste'): 8,
#  ('cooking oil', 'toothpaste'): 14,
#  ('cooking oil', 'spaghetti', 'toothpaste'): 6,
#  ('spaghetti', 'toothpaste'): 16,
#  ('mineral water', 'spaghetti', 'toothpaste'): 5,
#  ('mineral water', 'toothpaste'): 17,
#  ('clothes accessories', 'soup'): 5,
#  ('clothes accessories', 'tomatoes'): 5,
#  ('clothes accessories', 'oil'): 5,
#  ('cake', 'clothes accessories'): 5,
#  ('clothes accessories', 'salmon'): 5,
#  ('clothes accessories', 'mineral water', 'salmon'): 5,
#  ('clothes accessories', 'olive oil'): 5,
#  ('clothes accessories', 'mint'): 5,
#  ('clothes accessories', 'rice'): 6,
#  ('clothes accessories', 'cookies'): 6,
#  ('clothes accessories', 'low fat yogurt'): 6,
#  ('clothes accessories', 'whole wheat rice'): 8,
#  ('clothes accessories', 'mineral water', 'whole wheat rice'): 6,
#  ('clothes accessories', 'fresh bread'): 8,
#  ('clothes accessories', 'eggs'): 9,
#  ('chocolate', 'clothes accessories', 'frozen vegetables'): 5,
#  ('clothes accessories', 'frozen vegetables', 'mineral water'): 5,
#  ('clothes accessories', 'frozen smoothie'): 9,
#  ('clothes accessories', 'pancakes'): 9,
#  ('clothes accessories', 'mineral water', 'pancakes'): 6,
#  ('clothes accessories', 'herb & pepper'): 10,
#  ('clothes accessories', 'ground beef', 'spaghetti'): 5,
#  ('clothes accessories', 'ground beef', 'herb & pepper'): 5,
#  ('clothes accessories', 'ground beef', 'mineral water'): 7,
#  ('clothes accessories', 'shrimp'): 12,
#  ('clothes accessories', 'mineral water', 'shrimp'): 7,
#  ('clothes accessories', 'milk', 'shrimp'): 6,
#  ('clothes accessories', 'milk', 'mineral water', 'shrimp'): 5,
#  ('clothes accessories', 'milk', 'mineral water'): 7,
#  ('clothes accessories', 'spaghetti'): 12,
#  ('clothes accessories', 'mineral water', 'spaghetti'): 6,
#  ('chocolate', 'clothes accessories'): 13,
#  ('chocolate', 'clothes accessories', 'mineral water'): 5,
#  ('clothes accessories', 'french fries', 'mineral water'): 5,
#  ('clothes accessories', 'french fries', 'green tea'): 6,
#  ('clothes accessories', 'green tea'): 18,
#  ('clothes accessories', 'mineral water'): 20,
#  ('bug spray', 'soup'): 5,
#  ('bug spray', 'butter'): 5,
#  ('bug spray', 'cake'): 5,
#  ('bug spray', 'cooking oil'): 5,
#  ('bug spray', 'whole wheat rice'): 5,
#  ('bug spray', 'hot dogs'): 6,
#  ('bug spray', 'frozen smoothie'): 6,
#  ('bug spray', 'pepper'): 7,
#  ('bug spray', 'turkey'): 7,
#  ('bug spray', 'tomatoes'): 7,
#  ('bug spray', 'frozen vegetables'): 7,
#  ('bug spray', 'frozen vegetables', 'spaghetti'): 5,
#  ('bug spray', 'burgers'): 8,
#  ('bug spray', 'burgers', 'spaghetti'): 5,
#  ('bug spray', 'low fat yogurt'): 8,
#  ('bug spray', 'low fat yogurt', 'spaghetti'): 5,
#  ('bug spray', 'escalope'): 9,
#  ('bug spray', 'milk', 'shrimp'): 6,
#  ('bug spray', 'mineral water', 'shrimp'): 6,
#  ('bug spray', 'shrimp', 'spaghetti'): 6,
#  ('bug spray', 'pancakes', 'spaghetti'): 5,
#  ('bug spray', 'mineral water', 'pancakes'): 5,
#  ('bug spray', 'green tea'): 11,
#  ('bug spray', 'milk', 'olive oil'): 5,
#  ('bug spray', 'ground beef', 'olive oil'): 6,
#  ('bug spray', 'french fries'): 11,
#  ('bug spray', 'eggs'): 12,
#  ('bug spray', 'chocolate', 'ground beef'): 5,
#  ('bug spray', 'chocolate', 'spaghetti'): 7,
#  ('bug spray', 'chicken', 'mineral water'): 7,
#  ('bug spray', 'chicken', 'spaghetti'): 7,
#  ('bug spray', 'milk'): 14,
#  ('bug spray', 'milk', 'mineral water'): 5,
#  ('bug spray', 'ground beef', 'mineral water'): 5,
#  ('bug spray', 'ground beef', 'spaghetti'): 7,
#  ('bug spray', 'mineral water'): 20,
#  ('bug spray', 'mineral water', 'spaghetti'): 6,
#  ('bug spray', 'spaghetti'): 20,
#  ('bacon', 'brownies'): 5,
#  ('bacon', 'salmon'): 5,
#  ('bacon', 'tomatoes'): 5,
#  ('bacon', 'soup'): 5,
#  ('bacon', 'pepper'): 5,
#  ('bacon', 'frozen smoothie'): 5,
#  ('bacon', 'grated cheese'): 6,
#  ('bacon', 'butter'): 6,
#  ('bacon', 'eggplant'): 6,
#  ('bacon', 'whole wheat pasta'): 7,
#  ('bacon', 'low fat yogurt'): 7,
#  ('bacon', 'cake'): 7,
#  ('bacon', 'cake', 'mineral water'): 5,
#  ('bacon', 'herb & pepper', 'mineral water'): 5,
#  ('bacon', 'ground beef', 'herb & pepper'): 5,
#  ('bacon', 'ground beef', 'herb & pepper', 'spaghetti'): 5,
#  ('bacon', 'herb & pepper', 'spaghetti'): 6,
#  ('bacon', 'frozen vegetables', 'mineral water'): 5,
#  ('bacon', 'frozen vegetables', 'spaghetti'): 6,
#  ('bacon', 'red wine'): 8,
#  ('bacon', 'red wine', 'spaghetti'): 5,
#  ('bacon', 'olive oil'): 9,
#  ('bacon', 'mineral water', 'olive oil'): 6,
#  ('bacon', 'turkey'): 9,
#  ('bacon', 'chicken'): 9,
#  ('bacon', 'barbecue sauce'): 9,
#  ('bacon', 'barbecue sauce', 'eggs'): 5,
#  ('bacon', 'whole wheat rice'): 10,
#  ('bacon', 'milk', 'whole wheat rice'): 5,
#  ('bacon', 'cooking oil', 'eggs'): 5,
#  ('bacon', 'cooking oil', 'mineral water'): 5,
#  ('bacon', 'eggs', 'milk'): 5,
#  ('bacon', 'ground beef', 'milk'): 6,
#  ('bacon', 'ground beef', 'milk', 'spaghetti'): 5,
#  ('bacon', 'milk', 'spaghetti'): 8,
#  ('bacon', 'chocolate', 'ground beef'): 5,
#  ('bacon', 'chocolate', 'milk'): 5,
#  ('bacon', 'chocolate', 'spaghetti'): 5,
#  ('bacon', 'burgers', 'pancakes'): 5,
#  ('bacon', 'burgers', 'pancakes', 'spaghetti'): 5,
#  ('bacon', 'burgers', 'green tea'): 6,
#  ('bacon', 'burgers', 'eggs', 'green tea'): 5,
#  ('bacon', 'burgers', 'spaghetti'): 8,
#  ('bacon', 'burgers', 'eggs', 'spaghetti'): 5,
#  ('bacon', 'burgers', 'eggs'): 9,
#  ('bacon', 'ground beef', 'pancakes'): 7,
#  ('bacon', 'ground beef', 'pancakes', 'spaghetti'): 6,
#  ('bacon', 'ground beef', 'spaghetti'): 11,
#  ('bacon', 'french fries', 'pancakes'): 5,
#  ('bacon', 'eggs', 'pancakes'): 5,
#  ('bacon', 'eggs', 'pancakes', 'spaghetti'): 5,
#  ('bacon', 'mineral water', 'pancakes'): 7,
#  ('bacon', 'mineral water', 'pancakes', 'spaghetti'): 6,
#  ('bacon', 'pancakes', 'spaghetti'): 13,
#  ('bacon', 'green tea', 'ground beef'): 5,
#  ('bacon', 'green tea', 'pancakes'): 6,
#  ('bacon', 'french fries', 'green tea'): 6,
#  ('bacon', 'green tea', 'spaghetti'): 6,
#  ('bacon', 'eggs', 'green tea'): 7,
#  ('bacon', 'french fries', 'mineral water'): 5,
#  ('bacon', 'french fries', 'spaghetti'): 6,
#  ('bacon', 'eggs', 'french fries'): 7,
#  ('bacon', 'eggs', 'mineral water'): 7,
#  ('bacon', 'eggs', 'spaghetti'): 8,
#  ('bacon', 'mineral water'): 23,
#  ('bacon', 'mineral water', 'spaghetti'): 10,
#  ('bacon', 'spaghetti'): 24,
#  ('fresh bread', 'green beans'): 5,
#  ('green beans', 'soup'): 6,
#  ('green beans', 'honey'): 6,
#  ('french fries', 'green beans', 'honey'): 5,
#  ('grated cheese', 'green beans'): 6,
#  ('green beans', 'turkey'): 6,
#  ('chicken', 'green beans'): 6,
#  ('green beans', 'rice'): 6,
#  ('burgers', 'green beans'): 6,
#  ('green beans', 'salmon'): 7,
#  ('green beans', 'whole wheat rice'): 7,
#  ('green beans', 'tomatoes'): 7,
#  ('green beans', 'spaghetti', 'tomatoes'): 6,
#  ('green beans', 'olive oil'): 8,
#  ('french wine', 'green beans'): 8,
#  ('eggs', 'green beans'): 9,
#  ('green beans', 'red wine'): 9,
#  ('french fries', 'green beans', 'red wine'): 5,
#  ('frozen vegetables', 'green beans', 'shrimp'): 5,
#  ('green beans', 'mineral water', 'shrimp'): 5,
#  ('green beans', 'shrimp', 'spaghetti'): 5,
#  ('chocolate', 'green beans'): 10,
#  ('chocolate', 'green beans', 'spaghetti'): 6,
#  ('frozen smoothie', 'frozen vegetables', 'green beans'): 5,
#  ('frozen smoothie', 'green beans', 'milk'): 5,
#  ('french fries', 'green beans', 'pancakes'): 5,
#  ('green beans', 'mineral water', 'pancakes'): 6,
#  ('green beans', 'mineral water', 'pancakes', 'spaghetti'): 5,
#  ('green beans', 'pancakes', 'spaghetti'): 7,
#  ('french fries', 'green beans', 'ground beef'): 6,
#  ('green beans', 'ground beef', 'spaghetti'): 8,
#  ('green beans', 'green tea', 'spaghetti'): 5,
#  ('french fries', 'green beans', 'green tea'): 5,
#  ('frozen vegetables', 'green beans', 'spaghetti'): 5,
#  ('frozen vegetables', 'green beans', 'mineral water'): 6,
#  ('french fries', 'frozen vegetables', 'green beans'): 6,
#  ('green beans', 'milk', 'mineral water'): 5,
#  ('french fries', 'green beans', 'milk'): 7,
#  ('french fries', 'green beans', 'mineral water'): 7,
#  ('green beans', 'mineral water', 'spaghetti'): 9,
#  ('french fries', 'green beans'): 20,
#  ('french fries', 'green beans', 'spaghetti'): 9,
#  ('green beans', 'spaghetti'): 26,
#  ('antioxydant juice', 'shrimp'): 5,
#  ('antioxydant juice', 'whole wheat pasta'): 5,
#  ('antioxydant juice', 'chicken'): 5,
#  ('antioxydant juice', 'fresh bread'): 5,
#  ('antioxydant juice', 'pancakes'): 5,
#  ('antioxydant juice', 'eggs'): 6,
#  ('antioxydant juice', 'low fat yogurt'): 7,
#  ('antioxydant juice', 'ground beef'): 7,
#  ('antioxydant juice', 'tomatoes'): 7,
#  ('antioxydant juice', 'milk'): 7,
#  ('antioxydant juice', 'olive oil'): 8,
#  ('antioxydant juice', 'escalope'): 8,
#  ('antioxydant juice', 'frozen smoothie'): 9,
#  ('antioxydant juice', 'frozen smoothie', 'mineral water'): 5,
#  ('antioxydant juice', 'spaghetti'): 9,
#  ('antioxydant juice', 'mineral water', 'spaghetti'): 5,
#  ('antioxydant juice', 'frozen vegetables'): 9,
#  ('antioxydant juice', 'chocolate'): 11,
#  ('antioxydant juice', 'chocolate', 'mineral water'): 5,
#  ('antioxydant juice', 'cereals', 'green tea'): 5,
#  ('antioxydant juice', 'cereals', 'mineral water'): 7,
#  ('antioxydant juice', 'green tea'): 15,
#  ('antioxydant juice', 'green tea', 'mineral water'): 6,
#  ('antioxydant juice', 'french fries'): 18,
#  ('antioxydant juice', 'french fries', 'mineral water'): 6,
#  ('antioxydant juice', 'mineral water'): 20,
#  ('green grapes', 'whole weat flour'): 5,
#  ('green grapes', 'tomato juice'): 5,
#  ('cottage cheese', 'green grapes'): 5,
#  ('green grapes', 'pepper'): 5,
#  ('burgers', 'green grapes'): 5,
#  ('almonds', 'green grapes'): 6,
#  ('green grapes', 'honey'): 6,
#  ('avocado', 'green grapes'): 7,
#  ('green grapes', 'olive oil'): 7,
#  ('green grapes', 'low fat yogurt'): 7,
#  ('green grapes', 'green tea', 'low fat yogurt'): 5,
#  ('fresh bread', 'green grapes'): 7,
#  ('escalope', 'green grapes'): 7,
#  ('butter', 'green grapes'): 7,
#  ('green grapes', 'turkey'): 7,
#  ('cooking oil', 'green grapes'): 7,
#  ('frozen smoothie', 'green grapes'): 8,
#  ('green grapes', 'shrimp'): 8,
#  ('green grapes', 'soup', 'spaghetti'): 5,
#  ('green grapes', 'mineral water', 'soup'): 6,
#  ('green grapes', 'milk'): 9,
#  ('green grapes', 'pancakes'): 9,
#  ('green grapes', 'ground beef', 'mineral water'): 5,
#  ('green grapes', 'ground beef', 'spaghetti'): 6,
#  ('cake', 'green grapes'): 10,
#  ('cake', 'green grapes', 'green tea'): 5,
#  ('green grapes', 'green tea', 'vegetables mix'): 5,
#  ('green grapes', 'mineral water', 'vegetables mix'): 6,
#  ('green grapes', 'salmon'): 11,
#  ('green grapes', 'mineral water', 'salmon'): 8,
#  ('chocolate', 'green grapes'): 12,
#  ('green grapes', 'green tea'): 14,
#  ('green grapes', 'green tea', 'mineral water'): 7,
#  ('eggs', 'french fries', 'green grapes'): 6,
#  ('eggs', 'frozen vegetables', 'green grapes'): 6,
#  ('eggs', 'green grapes', 'mineral water'): 7,
#  ('frozen vegetables', 'green grapes', 'spaghetti'): 7,
#  ('frozen vegetables', 'green grapes', 'mineral water', 'spaghetti'): 6,
#  ('frozen vegetables', 'green grapes', 'mineral water'): 8,
#  ('french fries', 'green grapes'): 16,
#  ('french fries', 'green grapes', 'mineral water'): 6,
#  ('green grapes', 'spaghetti'): 17,
#  ('green grapes', 'mineral water', 'spaghetti'): 10,
#  ('green grapes', 'mineral water'): 24,
#  ('flax seed', 'turkey'): 5,
#  ('flax seed', 'magazines'): 5,
#  ('flax seed', 'herb & pepper'): 5,
#  ('flax seed', 'honey'): 5,
#  ('butter', 'flax seed'): 5,
#  ('flax seed', 'salmon'): 6,
#  ('flax seed', 'olive oil'): 6,
#  ('flax seed', 'pancakes'): 6,
#  ('escalope', 'flax seed'): 7,
#  ('chicken', 'flax seed'): 7,
#  ('cake', 'flax seed'): 7,
#  ('flax seed', 'tomatoes'): 7,
#  ('flax seed', 'frozen vegetables'): 8,
#  ('flax seed', 'frozen smoothie'): 8,
#  ('flax seed', 'ground beef'): 8,
#  ('burgers', 'flax seed'): 9,
#  ('flax seed', 'shrimp'): 9,
#  ('flax seed', 'milk'): 10,
#  ('flax seed', 'mineral water'): 14,
#  ('eggs', 'flax seed', 'mineral water'): 5,
#  ('eggs', 'flax seed', 'french fries'): 5,
#  ('eggs', 'flax seed', 'green tea'): 7,
#  ('chocolate', 'flax seed', 'spaghetti'): 5,
#  ('flax seed', 'french fries', 'spaghetti'): 5,
#  ('flax seed', 'green tea', 'spaghetti'): 5,
#  ('flax seed', 'french fries', 'green tea'): 5,
#  ('chocolate', 'flax seed', 'french fries'): 6,
#  ('chocolate', 'flax seed'): 16,
#  ('chocolate', 'flax seed', 'green tea'): 5,
#  ('flax seed', 'green tea'): 23,
#  ('meatballs', 'salt'): 5,
#  ('french wine', 'salt'): 5,
#  ('energy drink', 'salt'): 5,
#  ('salt', 'tomato juice'): 5,
#  ('magazines', 'salt'): 5,
#  ('salt', 'tomato sauce'): 5,
#  ('red wine', 'salt', 'tomato sauce'): 5,
#  ('chocolate', 'salt', 'tomato sauce'): 5,
#  ('french fries', 'salt', 'tomato sauce'): 5,
#  ('chocolate', 'red wine', 'salt', 'tomato sauce'): 5,
#  ('french fries', 'red wine', 'salt', 'tomato sauce'): 5,
#  ('chocolate', 'french fries', 'salt', 'tomato sauce'): 5,
#  ('chocolate', 'french fries', 'red wine', 'salt', 'tomato sauce'): 5,
#  ('cooking oil', 'salt'): 5,
#  ('cereals', 'salt'): 5,
#  ('protein bar', 'salt'): 5,
#  ('avocado', 'salt'): 5,
#  ('salt', 'whole wheat rice'): 5,
#  ('salt', 'soup'): 6,
#  ('ground beef', 'salt'): 6,
#  ('chicken', 'salt'): 6,
#  ('oil', 'salt'): 6,
#  ('frozen vegetables', 'salt'): 6,
#  ('butter', 'salt'): 7,
#  ('brownies', 'salt'): 7,
#  ('salt', 'tomatoes'): 7,
#  ('cake', 'salt'): 7,
#  ('olive oil', 'salt'): 8,
#  ('salt', 'turkey'): 8,
#  ('fresh bread', 'salt'): 8,
#  ('red wine', 'salt'): 8,
#  ('chocolate', 'red wine', 'salt'): 5,
#  ('french fries', 'red wine', 'salt'): 6,
#  ('chocolate', 'french fries', 'red wine', 'salt'): 5,
#  ('salt', 'shrimp'): 9,
#  ('burgers', 'salt'): 10,
#  ('milk', 'salt'): 10,
#  ('salt', 'spaghetti'): 11,
#  ('pancakes', 'salt'): 11,
#  ('eggs', 'pancakes', 'salt'): 5,
#  ('green tea', 'salt'): 11,
#  ('mineral water', 'salt'): 12,
#  ('eggs', 'salt'): 14,
#  ('chocolate', 'salt'): 14,
#  ('chocolate', 'french fries', 'salt'): 6,
#  ('french fries', 'salt'): 15,
#  ('blueberries', 'champagne'): 5,
#  ('blueberries', 'oil'): 5,
#  ('blueberries', 'red wine'): 5,
#  ('blueberries', 'red wine', 'spaghetti'): 5,
#  ('blueberries', 'ham'): 5,
#  ('blueberries', 'whole wheat pasta'): 6,
#  ('blueberries', 'herb & pepper'): 6,
#  ('blueberries', 'shrimp'): 6,
#  ('blueberries', 'cake'): 6,
#  ('blueberries', 'cookies'): 6,
#  ('blueberries', 'fresh bread'): 6,
#  ('blueberries', 'honey'): 6,
#  ('blueberries', 'salmon'): 7,
#  ('blueberries', 'burgers'): 7,
#  ('blueberries', 'frozen smoothie'): 7,
#  ('blueberries', 'turkey'): 7,
#  ('blueberries', 'tomatoes'): 7,
#  ('blueberries', 'frozen vegetables'): 7,
#  ('blueberries', 'whole wheat rice'): 7,
#  ('blueberries', 'spaghetti', 'whole wheat rice'): 5,
#  ('blueberries', 'light cream'): 8,
#  ('blueberries', 'light cream', 'mineral water'): 6,
#  ('blueberries', 'cooking oil'): 9,
#  ('blueberries', 'cooking oil', 'spaghetti'): 6,
#  ('blueberries', 'chicken'): 9,
#  ('blueberries', 'chicken', 'mineral water'): 7,
#  ('blueberries', 'french fries'): 9,
#  ('blueberries', 'soup'): 10,
#  ('blueberries', 'olive oil'): 11,
#  ('blueberries', 'olive oil', 'spaghetti'): 5,
#  ('blueberries', 'eggs', 'milk'): 5,
#  ('blueberries', 'milk', 'spaghetti'): 5,
#  ('blueberries', 'milk', 'mineral water'): 7,
#  ('blueberries', 'pancakes'): 11,
#  ('blueberries', 'mineral water', 'pancakes'): 8,
#  ('blueberries', 'chocolate', 'grated cheese'): 5,
#  ('blueberries', 'grated cheese', 'mineral water'): 5,
#  ('blueberries', 'grated cheese', 'spaghetti'): 6,
#  ('blueberries', 'escalope', 'spaghetti'): 5,
#  ('blueberries', 'escalope', 'mineral water'): 7,
#  ('blueberries', 'green tea', 'ground beef'): 5,
#  ('blueberries', 'eggs', 'green tea'): 5,
#  ('blueberries', 'eggs', 'spaghetti'): 5,
#  ('blueberries', 'chocolate', 'eggs'): 5,
#  ('blueberries', 'chocolate', 'eggs', 'mineral water'): 5,
#  ('blueberries', 'eggs', 'mineral water'): 12,
#  ('blueberries', 'chocolate', 'ground beef'): 5,
#  ('blueberries', 'chocolate', 'mineral water'): 6,
#  ('blueberries', 'chocolate', 'spaghetti'): 8,
#  ('blueberries', 'ground beef', 'mineral water'): 5,
#  ('blueberries', 'ground beef', 'spaghetti'): 7,
#  ('blueberries', 'spaghetti'): 26,
#  ('blueberries', 'mineral water', 'spaghetti'): 11,
#  ('blueberries', 'mineral water'): 27,
#  ('avocado', 'whole weat flour'): 5,
#  ('olive oil', 'whole weat flour'): 5,
#  ('chocolate', 'whole weat flour'): 5,
#  ('fresh bread', 'whole weat flour'): 5,
#  ('cooking oil', 'whole weat flour'): 5,
#  ('brownies', 'whole weat flour'): 5,
#  ('energy drink', 'whole weat flour'): 6,
#  ('fresh tuna', 'whole weat flour'): 6,
#  ('cereals', 'whole weat flour'): 6,
#  ('energy bar', 'whole weat flour'): 6,
#  ('grated cheese', 'whole weat flour'): 6,
#  ('burgers', 'whole weat flour'): 6,
#  ('french wine', 'whole weat flour'): 6,
#  ('tomato juice', 'whole weat flour'): 7,
#  ('cottage cheese', 'whole weat flour'): 7,
#  ('shrimp', 'whole weat flour'): 7,
#  ('red wine', 'whole weat flour'): 7,
#  ('soup', 'whole weat flour'): 7,
#  ('cake', 'whole weat flour'): 7,
#  ('cake', 'french fries', 'whole weat flour'): 5,
#  ('cake', 'mineral water', 'whole weat flour'): 6,
#  ('cake', 'french fries', 'mineral water', 'whole weat flour'): 5,
#  ('whole weat flour', 'whole wheat rice'): 7,
#  ('mineral water', 'whole weat flour', 'whole wheat rice'): 5,
#  ('frozen smoothie', 'salmon', 'whole weat flour'): 5,
#  ('mineral water', 'salmon', 'whole weat flour'): 5,
#  ('frozen vegetables', 'whole weat flour'): 9,
#  ('herb & pepper', 'pancakes', 'whole weat flour'): 5,
#  ('herb & pepper', 'mineral water', 'pancakes', 'whole weat flour'): 5,
#  ('herb & pepper', 'milk', 'pancakes', 'whole weat flour'): 5,
#  ('herb & pepper', 'milk', 'mineral water', 'pancakes', 'whole weat flour'): 5,
#  ('herb & pepper', 'milk', 'whole weat flour'): 7,
#  ('herb & pepper', 'mineral water', 'whole weat flour'): 7,
#  ('herb & pepper', 'milk', 'mineral water', 'whole weat flour'): 6,
#  ('tomatoes', 'whole weat flour'): 10,
#  ('mineral water', 'tomatoes', 'whole weat flour'): 5,
#  ('eggs', 'whole weat flour'): 10,
#  ('frozen smoothie', 'honey', 'whole weat flour'): 5,
#  ('green tea', 'honey', 'whole weat flour'): 6,
#  ('honey', 'mineral water', 'whole weat flour'): 7,
#  ('low fat yogurt', 'whole weat flour'): 11,
#  ('low fat yogurt', 'mineral water', 'whole weat flour'): 5,
#  ('ground beef', 'pancakes', 'whole weat flour'): 5,
#  ('ground beef', 'milk', 'pancakes', 'whole weat flour'): 5,
#  ('ground beef', 'milk', 'whole weat flour'): 7,
#  ('ground beef', 'milk', 'mineral water', 'whole weat flour'): 6,
#  ('ground beef', 'mineral water', 'whole weat flour'): 8,
#  ('frozen smoothie', 'green tea', 'whole weat flour'): 5,
#  ('french fries', 'frozen smoothie', 'whole weat flour'): 5,
#  ('frozen smoothie', 'mineral water', 'whole weat flour'): 7,
#  ('chicken', 'pancakes', 'whole weat flour'): 5,
#  ('chicken', 'french fries', 'whole weat flour'): 5,
#  ('chicken', 'mineral water', 'whole weat flour'): 5,
#  ('green tea', 'pancakes', 'whole weat flour'): 6,
#  ('french fries', 'pancakes', 'whole weat flour'): 9,
#  ('french fries', 'mineral water', 'pancakes', 'whole weat flour'): 7,
#  ('mineral water', 'pancakes', 'whole weat flour'): 11,
#  ('milk', 'pancakes', 'whole weat flour'): 7,
#  ('milk', 'mineral water', 'pancakes', 'whole weat flour'): 6,
#  ('french fries', 'milk', 'pancakes', 'whole weat flour'): 5,
#  ('french fries', 'milk', 'mineral water', 'pancakes', 'whole weat flour'): 5,
#  ('french fries', 'milk', 'whole weat flour'): 9,
#  ('milk', 'mineral water', 'whole weat flour'): 9,
#  ('french fries', 'milk', 'mineral water', 'whole weat flour'): 6,
#  ('mineral water', 'spaghetti', 'whole weat flour'): 6,
#  ('pancakes', 'spaghetti', 'whole weat flour'): 7,
#  ('green tea', 'whole weat flour'): 18,
#  ('green tea', 'mineral water', 'whole weat flour'): 6,
#  ('french fries', 'whole weat flour'): 19,
#  ('french fries', 'mineral water', 'whole weat flour'): 11,
#  ('mineral water', 'whole weat flour'): 26,
#  ('energy bar', 'zucchini'): 5,
#  ('red wine', 'zucchini'): 5,
#  ('cookies', 'zucchini'): 5,
#  ('herb & pepper', 'zucchini'): 6,
#  ('grated cheese', 'zucchini'): 6,
#  ('protein bar', 'zucchini'): 6,
#  ...}

# %%
start_time = time.time()
association_rules = pyfpgrowth.generate_association_rules(frequent_itemsets_fpgrowth_2, 0.8)
print(f'Время выполнения метода: {time.time() - start_time}')
print(f'Количество ассоциативных правил: {len(association_rules)}')
association_rules
# Out:
# Время выполнения метода: 0.2150592803955078
# Количество ассоциативных правил: 645
# {('ground beef', 'tea'): (('frozen vegetables',), 1.0),
#  ('chutney', 'ground beef'): (('mineral water',), 1.0),
#  ('hand protein bar', 'pancakes'): (('mineral water',), 1.0),
#  ('hand protein bar', 'shrimp'): (('chocolate',), 0.8333333333333334),
#  ('burgers', 'hand protein bar'): (('mineral water',), 0.8571428571428571),
#  ('burger sauce', 'salmon'): (('mineral water',), 0.8333333333333334),
#  ('burger sauce', 'olive oil'): (('spaghetti',), 0.8333333333333334),
#  ('burger sauce', 'mineral water', 'shrimp'): (('spaghetti',), 1.0),
#  ('burger sauce', 'shrimp', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('burger sauce', 'eggs', 'mineral water'): (('chicken',), 0.8333333333333334),
#  ('mayonnaise', 'olive oil'): (('mineral water',), 0.8333333333333334),
#  ('ground beef', 'mayonnaise'): (('mineral water',), 0.8333333333333334),
#  ('chili', 'escalope'): (('mineral water',), 0.8571428571428571),
#  ('honey', 'sparkling water'): (('frozen smoothie',), 0.8333333333333334),
#  ('frozen smoothie', 'spinach'): (('mineral water',), 0.8888888888888888),
#  ('shallot', 'white wine'): (('escalope',), 1.0),
#  ('french fries', 'low fat yogurt', 'shallot'): (('cookies',), 0.875),
#  ('almonds', 'strong cheese'): (('spaghetti',), 0.8333333333333334),
#  ('shrimp', 'strong cheese'): (('mineral water',), 0.875),
#  ('shrimp', 'spaghetti', 'strong cheese'): (('mineral water',), 1.0),
#  ('frozen vegetables', 'ground beef', 'strong cheese'): (('spaghetti',), 1.0),
#  ('frozen vegetables', 'spaghetti', 'strong cheese'): (('ground beef',),
#   0.8333333333333334),
#  ('ground beef', 'mineral water', 'strong cheese'): (('spaghetti',),
#   0.8333333333333334),
#  ('chocolate', 'milk', 'strong cheese'): (('spaghetti',), 0.8333333333333334),
#  ('milk', 'spaghetti', 'strong cheese'): (('mineral water',), 0.8),
#  ('clothes accessories', 'salmon'): (('mineral water',), 1.0),
#  ('clothes accessories', 'milk', 'shrimp'): (('mineral water',),
#   0.8333333333333334),
#  ('bacon', 'ground beef', 'herb & pepper'): (('spaghetti',), 1.0),
#  ('bacon', 'herb & pepper', 'spaghetti'): (('ground beef',),
#   0.8333333333333334),
#  ('bacon', 'ground beef', 'milk'): (('spaghetti',), 0.8333333333333334),
#  ('bacon', 'burgers', 'pancakes'): (('spaghetti',), 1.0),
#  ('bacon', 'burgers', 'green tea'): (('eggs',), 0.8333333333333334),
#  ('bacon', 'ground beef', 'pancakes'): (('spaghetti',), 0.8571428571428571),
#  ('bacon', 'eggs', 'pancakes'): (('spaghetti',), 1.0),
#  ('bacon', 'mineral water', 'pancakes'): (('spaghetti',), 0.8571428571428571),
#  ('green beans', 'honey'): (('french fries',), 0.8333333333333334),
#  ('green beans', 'tomatoes'): (('spaghetti',), 0.8571428571428571),
#  ('green beans', 'mineral water', 'pancakes'): (('spaghetti',),
#   0.8333333333333334),
#  ('frozen vegetables', 'green grapes', 'spaghetti'): (('mineral water',),
#   0.8571428571428571),
#  ('salt', 'tomato sauce'): (('chocolate', 'french fries', 'red wine'), 1.0),
#  ('chocolate', 'red wine', 'salt'): (('french fries',), 1.0),
#  ('chocolate', 'salt', 'tomato sauce'): (('french fries', 'red wine'), 1.0),
#  ('red wine', 'salt', 'tomato sauce'): (('chocolate', 'french fries'), 1.0),
#  ('french fries', 'red wine', 'salt'): (('chocolate',), 0.8333333333333334),
#  ('french fries', 'red wine', 'tomato sauce'): (('chocolate',),
#   0.8333333333333334),
#  ('french fries', 'salt', 'tomato sauce'): (('chocolate', 'red wine'), 1.0),
#  ('chocolate', 'french fries', 'salt'): (('red wine',), 0.8333333333333334),
#  ('chocolate', 'french fries', 'red wine', 'salt'): (('tomato sauce',), 1.0),
#  ('chocolate', 'french fries', 'red wine', 'tomato sauce'): (('salt',), 1.0),
#  ('chocolate', 'french fries', 'salt', 'tomato sauce'): (('red wine',), 1.0),
#  ('chocolate', 'red wine', 'salt', 'tomato sauce'): (('french fries',), 1.0),
#  ('french fries', 'red wine', 'salt', 'tomato sauce'): (('chocolate',), 1.0),
#  ('blueberries', 'red wine'): (('spaghetti',), 1.0),
#  ('blueberries', 'chocolate', 'eggs'): (('mineral water',), 1.0),
#  ('blueberries', 'chocolate', 'mineral water'): (('eggs',),
#   0.8333333333333334),
#  ('cake', 'whole weat flour'): (('mineral water',), 0.8571428571428571),
#  ('cake', 'french fries', 'whole weat flour'): (('mineral water',), 1.0),
#  ('cake', 'mineral water', 'whole weat flour'): (('french fries',),
#   0.8333333333333334),
#  ('herb & pepper', 'pancakes', 'whole weat flour'): (('milk', 'mineral water'),
#   1.0),
#  ('herb & pepper',
#   'milk',
#   'mineral water',
#   'whole weat flour'): (('pancakes',), 0.8333333333333334),
#  ('herb & pepper',
#   'milk',
#   'pancakes',
#   'whole weat flour'): (('mineral water',), 1.0),
#  ('herb & pepper',
#   'mineral water',
#   'pancakes',
#   'whole weat flour'): (('milk',), 1.0),
#  ('milk', 'mineral water', 'pancakes', 'whole weat flour'): (('french fries',),
#   0.8333333333333334),
#  ('herb & pepper', 'milk', 'whole weat flour'): (('mineral water',),
#   0.8571428571428571),
#  ('herb & pepper', 'mineral water', 'whole weat flour'): (('milk',),
#   0.8571428571428571),
#  ('ground beef', 'pancakes', 'whole weat flour'): (('milk',), 1.0),
#  ('ground beef', 'milk', 'whole weat flour'): (('mineral water',),
#   0.8571428571428571),
#  ('milk', 'pancakes', 'whole weat flour'): (('mineral water',),
#   0.8571428571428571),
#  ('french fries', 'milk', 'mineral water', 'whole weat flour'): (('pancakes',),
#   0.8333333333333334),
#  ('french fries', 'milk', 'pancakes', 'whole weat flour'): (('mineral water',),
#   1.0),
#  ('candy bars', 'milk'): (('mineral water',), 0.8333333333333334),
#  ('nonfat milk', 'soup'): (('mineral water',), 1.0),
#  ('mineral water', 'nonfat milk', 'tomatoes'): (('spaghetti',),
#   0.8571428571428571),
#  ('nonfat milk', 'spaghetti', 'tomatoes'): (('mineral water',), 1.0),
#  ('frozen vegetables', 'nonfat milk', 'turkey'): (('mineral water',),
#   0.8333333333333334),
#  ('milk', 'nonfat milk', 'turkey'): (('mineral water',), 0.8333333333333334),
#  ('ground beef', 'nonfat milk', 'spaghetti'): (('mineral water',), 1.0),
#  ('ground beef', 'milk', 'nonfat milk'): (('mineral water',), 1.0),
#  ('frozen vegetables', 'nonfat milk', 'spaghetti'): (('mineral water',), 1.0),
#  ('nonfat milk', 'pancakes', 'spaghetti'): (('mineral water',), 1.0),
#  ('milk', 'nonfat milk', 'spaghetti'): (('mineral water',),
#   0.8571428571428571),
#  ('burgers', 'cider', 'mineral water'): (('eggs',), 1.0),
#  ('barbecue sauce', 'chocolate', 'milk'): (('mineral water',),
#   0.8333333333333334),
#  ('body spray', 'frozen vegetables'): (('mineral water',), 0.8333333333333334),
#  ('french fries', 'melons', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('frozen smoothie', 'ground beef', 'gums'): (('mineral water',), 1.0),
#  ('fromage blanc', 'soup'): (('burgers',), 0.8333333333333334),
#  ('fresh tuna', 'fromage blanc', 'green tea'): (('honey',),
#   0.8333333333333334),
#  ('fromage blanc', 'green tea', 'honey'): (('fresh tuna',),
#   0.8333333333333334),
#  ('chocolate', 'fromage blanc', 'frozen vegetables'): (('french fries',), 1.0),
#  ('almonds', 'tomato sauce'): (('mineral water',), 0.8571428571428571),
#  ('almonds', 'eggs', 'tomato sauce'): (('mineral water',), 1.0),
#  ('almonds', 'mineral water', 'tomato sauce'): (('eggs',), 0.8333333333333334),
#  ('red wine', 'spaghetti', 'tomato sauce'): (('chocolate',),
#   0.8333333333333334),
#  ('chocolate', 'escalope', 'tomato sauce'): (('ground beef', 'spaghetti'),
#   0.8333333333333334),
#  ('escalope', 'ground beef', 'tomato sauce'): (('chocolate', 'spaghetti'),
#   0.8333333333333334),
#  ('escalope', 'spaghetti', 'tomato sauce'): (('chocolate', 'ground beef'),
#   0.8333333333333334),
#  ('chocolate', 'escalope', 'ground beef', 'tomato sauce'): (('spaghetti',),
#   1.0),
#  ('chocolate', 'escalope', 'spaghetti', 'tomato sauce'): (('ground beef',),
#   1.0),
#  ('escalope', 'ground beef', 'spaghetti', 'tomato sauce'): (('chocolate',),
#   1.0),
#  ('frozen smoothie', 'mineral water', 'tomato sauce'): (('spaghetti',),
#   0.8333333333333334),
#  ('cooking oil', 'mineral water', 'tomato sauce'): (('spaghetti',),
#   0.8571428571428571),
#  ('cooking oil', 'spaghetti', 'tomato sauce'): (('mineral water',),
#   0.8571428571428571),
#  ('ground beef', 'tomato sauce', 'tomatoes'): (('milk',), 0.8333333333333334),
#  ('milk', 'tomato sauce', 'tomatoes'): (('ground beef',), 0.8333333333333334),
#  ('ground beef', 'shrimp', 'tomato sauce'): (('spaghetti',), 1.0),
#  ('frozen vegetables', 'shrimp', 'tomato sauce'): (('mineral water',),
#   0.8333333333333334),
#  ('olive oil', 'soup', 'tomato sauce'): (('mineral water',), 1.0),
#  ('frozen vegetables', 'olive oil', 'tomato sauce'): (('mineral water',),
#   0.8571428571428571),
#  ('green tea', 'milk', 'tomato sauce'): (('ground beef',), 1.0),
#  ('green tea', 'mineral water', 'tomato sauce'): (('spaghetti',),
#   0.8571428571428571),
#  ('green tea', 'ground beef', 'tomato sauce'): (('spaghetti',),
#   0.8333333333333334),
#  ('black tea', 'fresh bread'): (('mineral water',), 0.8333333333333334),
#  ('black tea', 'frozen smoothie', 'mineral water'): (('milk',),
#   0.8333333333333334),
#  ('black tea', 'frozen vegetables', 'spaghetti'): (('milk',),
#   0.8333333333333334),
#  ('black tea', 'frozen vegetables', 'milk'): (('mineral water',),
#   0.8571428571428571),
#  ('black tea', 'frozen vegetables', 'mineral water'): (('milk',),
#   0.8571428571428571),
#  ('black tea', 'ground beef', 'olive oil'): (('mineral water',), 1.0),
#  ('black tea', 'spaghetti', 'turkey'): (('eggs',), 0.8888888888888888),
#  ('black tea', 'eggs', 'ground beef'): (('milk',), 0.8333333333333334),
#  ('carrots', 'honey'): (('spaghetti',), 0.8571428571428571),
#  ('chicken', 'chocolate', 'light cream', 'soup'): (('mineral water',),
#   0.8333333333333334),
#  ('light cream', 'mineral water', 'shrimp'): (('spaghetti',),
#   0.8888888888888888),
#  ('ground beef', 'light cream', 'olive oil'): (('mineral water',), 1.0),
#  ('pasta', 'soup'): (('shrimp',), 1.0),
#  ('frozen vegetables', 'pasta'): (('shrimp',), 0.8333333333333334),
#  ('eggs', 'pasta', 'spaghetti'): (('shrimp',), 1.0),
#  ('eggs', 'milk', 'pasta'): (('shrimp',), 1.0),
#  ('burgers', 'milk', 'pasta'): (('shrimp',), 0.8571428571428571),
#  ('eggs', 'mineral water', 'pasta'): (('shrimp',), 0.9090909090909091),
#  ('mineral water', 'pasta', 'shrimp'): (('eggs',), 0.8333333333333334),
#  ('chocolate', 'eggs', 'pasta'): (('shrimp',), 1.0),
#  ('mushroom cream sauce', 'pasta'): (('escalope',), 0.95),
#  ('french fries', 'mushroom cream sauce', 'pasta'): (('escalope',), 1.0),
#  ('chocolate', 'frozen vegetables', 'white wine'): (('mineral water',),
#   0.8571428571428571),
#  ('frozen vegetables', 'mineral water', 'white wine'): (('chocolate',),
#   0.8571428571428571),
#  ('eggs', 'mineral water', 'white wine'): (('chocolate',), 1.0),
#  ('chicken', 'chocolate', 'mint'): (('mineral water',), 0.8333333333333334),
#  ('chicken', 'ground beef', 'protein bar'): (('spaghetti',), 1.0),
#  ('chicken', 'mineral water', 'protein bar'): (('spaghetti',),
#   0.8333333333333334),
#  ('milk', 'protein bar', 'tomatoes'): (('spaghetti',), 0.8333333333333334),
#  ('mineral water', 'rice', 'salmon'): (('spaghetti',), 0.8333333333333334),
#  ('frozen vegetables', 'rice', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('herb & pepper', 'rice', 'shrimp'): (('ground beef',), 0.8333333333333334),
#  ('french fries', 'grated cheese', 'rice'): (('spaghetti',),
#   0.8333333333333334),
#  ('grated cheese', 'herb & pepper', 'rice'): (('ground beef', 'mineral water'),
#   0.8571428571428571),
#  ('grated cheese',
#   'ground beef',
#   'herb & pepper',
#   'rice'): (('mineral water',), 1.0),
#  ('grated cheese',
#   'herb & pepper',
#   'mineral water',
#   'rice'): (('ground beef',), 1.0),
#  ('grated cheese', 'ground beef', 'rice'): (('mineral water',), 0.8),
#  ('grated cheese', 'mineral water', 'rice'): (('ground beef',),
#   0.8888888888888888),
#  ('ground beef', 'herb & pepper', 'rice', 'spaghetti'): (('mineral water',),
#   1.0),
#  ('herb & pepper', 'mineral water', 'rice', 'spaghetti'): (('ground beef',),
#   0.8571428571428571),
#  ('herb & pepper', 'mineral water', 'rice'): (('ground beef',),
#   0.9090909090909091),
#  ('chicken', 'mushroom cream sauce'): (('chocolate',), 0.8333333333333334),
#  ('mushroom cream sauce', 'turkey'): (('spaghetti',), 0.8333333333333334),
#  ('fresh bread', 'mushroom cream sauce'): (('escalope',), 0.8571428571428571),
#  ('cake', 'french fries', 'mushroom cream sauce'): (('mineral water',),
#   0.8333333333333334),
#  ('cake', 'mineral water', 'mushroom cream sauce'): (('french fries',),
#   0.8333333333333334),
#  ('frozen vegetables', 'parmesan cheese', 'vegetables mix'): (('spaghetti',),
#   0.8333333333333334),
#  ('parmesan cheese', 'spaghetti', 'vegetables mix'): (('frozen vegetables',),
#   0.8333333333333334),
#  ('avocado', 'milk', 'parmesan cheese'): (('spaghetti',), 0.8333333333333334),
#  ('ground beef', 'herb & pepper', 'parmesan cheese'): (('eggs',),
#   0.8333333333333334),
#  ('frozen vegetables',
#   'parmesan cheese',
#   'whole wheat rice'): (('mineral water',), 0.8333333333333334),
#  ('mineral water',
#   'parmesan cheese',
#   'whole wheat rice'): (('frozen vegetables',), 0.8333333333333334),
#  ('frozen smoothie', 'parmesan cheese', 'spaghetti'): (('frozen vegetables',),
#   0.8333333333333334),
#  ('chocolate', 'frozen smoothie', 'parmesan cheese'): (('frozen vegetables',),
#   1.0),
#  ('frozen smoothie', 'parmesan cheese', 'shrimp'): (('frozen vegetables',),
#   0.8571428571428571),
#  ('cake', 'chocolate', 'parmesan cheese'): (('olive oil',),
#   0.8333333333333334),
#  ('cake', 'olive oil', 'parmesan cheese'): (('chocolate',), 1.0),
#  ('milk', 'parmesan cheese', 'turkey'): (('mineral water', 'spaghetti'),
#   0.8333333333333334),
#  ('milk', 'mineral water', 'parmesan cheese', 'turkey'): (('spaghetti',), 1.0),
#  ('milk', 'parmesan cheese', 'spaghetti', 'turkey'): (('mineral water',), 1.0),
#  ('mineral water', 'parmesan cheese', 'spaghetti', 'turkey'): (('milk',),
#   0.8333333333333334),
#  ('mineral water', 'parmesan cheese', 'turkey'): (('spaghetti',),
#   0.8571428571428571),
#  ('french fries', 'parmesan cheese', 'tomatoes'): (('frozen vegetables',),
#   1.0),
#  ('ground beef', 'parmesan cheese', 'tomatoes'): (('frozen vegetables',), 1.0),
#  ('ground beef', 'milk', 'parmesan cheese'): (('spaghetti',),
#   0.8333333333333334),
#  ('chocolate',
#   'frozen vegetables',
#   'milk',
#   'parmesan cheese'): (('spaghetti',), 0.8333333333333334),
#  ('chocolate',
#   'milk',
#   'parmesan cheese',
#   'spaghetti'): (('frozen vegetables',), 1.0),
#  ('milk', 'mineral water', 'parmesan cheese'): (('spaghetti',), 0.8),
#  ('frozen vegetables',
#   'milk',
#   'mineral water',
#   'parmesan cheese'): (('spaghetti',), 1.0),
#  ('chocolate',
#   'frozen vegetables',
#   'mineral water',
#   'parmesan cheese'): (('spaghetti',), 0.8571428571428571),
#  ('chocolate',
#   'frozen vegetables',
#   'parmesan cheese',
#   'spaghetti'): (('mineral water',), 0.8571428571428571),
#  ('chocolate',
#   'mineral water',
#   'parmesan cheese',
#   'spaghetti'): (('frozen vegetables',), 0.8571428571428571),
#  ('almonds', 'cooking oil', 'french fries'): (('chocolate',),
#   0.8333333333333334),
#  ('almonds', 'grated cheese', 'green tea'): (('ground beef',),
#   0.8333333333333334),
#  ('almonds', 'burgers', 'soup'): (('chocolate',), 0.8333333333333334),
#  ('almonds', 'eggs', 'soup'): (('chocolate',), 0.8333333333333334),
#  ('almonds', 'cake', 'pancakes'): (('chocolate',), 1.0),
#  ('almonds', 'french fries', 'pancakes'): (('chocolate',), 0.8571428571428571),
#  ('almonds', 'burgers', 'chocolate', 'pancakes'): (('spaghetti',),
#   0.8333333333333334),
#  ('almonds', 'burgers', 'pancakes', 'spaghetti'): (('chocolate',), 1.0),
#  ('almonds', 'chocolate', 'pancakes', 'spaghetti'): (('burgers',),
#   0.8333333333333334),
#  ('almonds', 'chocolate', 'ground beef', 'milk'): (('spaghetti',),
#   0.8333333333333334),
#  ('almonds', 'chocolate', 'ground beef', 'spaghetti'): (('milk',),
#   0.8333333333333334),
#  ('almonds', 'ground beef', 'milk', 'spaghetti'): (('chocolate',), 1.0),
#  ('cake', 'meatballs', 'milk'): (('mineral water',), 0.8888888888888888),
#  ('cake', 'meatballs', 'mineral water'): (('milk',), 1.0),
#  ('cake', 'eggs', 'meatballs'): (('milk', 'mineral water'), 1.0),
#  ('cake', 'eggs', 'meatballs', 'milk'): (('mineral water',), 1.0),
#  ('cake', 'eggs', 'meatballs', 'mineral water'): (('milk',), 1.0),
#  ('eggs', 'meatballs', 'milk', 'mineral water'): (('cake',),
#   0.8333333333333334),
#  ('burgers', 'meatballs', 'milk'): (('mineral water',), 1.0),
#  ('frozen smoothie', 'meatballs', 'milk'): (('mineral water',),
#   0.8333333333333334),
#  ('meatballs', 'milk', 'turkey'): (('spaghetti',), 0.8333333333333334),
#  ('frozen vegetables', 'meatballs', 'milk'): (('mineral water',),
#   0.8333333333333334),
#  ('ground beef', 'meatballs', 'milk'): (('mineral water',),
#   0.8333333333333334),
#  ('ground beef', 'meatballs', 'tomatoes'): (('spaghetti',),
#   0.8333333333333334),
#  ('fresh tuna', 'tomato juice'): (('mineral water',), 0.8333333333333334),
#  ('eggs', 'fresh tuna', 'light mayo'): (('pancakes',), 1.0),
#  ('fresh tuna', 'light mayo', 'pancakes'): (('eggs',), 1.0),
#  ('avocado', 'fresh tuna', 'frozen smoothie'): (('mineral water',),
#   0.8333333333333334),
#  ('fresh tuna', 'olive oil', 'tomatoes'): (('mineral water',), 1.0),
#  ('fresh tuna', 'frozen vegetables', 'milk', 'tomatoes'): (('spaghetti',),
#   1.0),
#  ('fresh tuna', 'milk', 'spaghetti', 'tomatoes'): (('frozen vegetables',),
#   1.0),
#  ('fresh tuna',
#   'frozen vegetables',
#   'mineral water',
#   'tomatoes'): (('spaghetti',), 1.0),
#  ('french fries', 'fresh tuna', 'frozen smoothie'): (('mineral water',),
#   0.8333333333333334),
#  ('burgers', 'chocolate', 'fresh tuna'): (('spaghetti',), 0.8333333333333334),
#  ('fresh tuna', 'mineral water', 'olive oil', 'pancakes'): (('spaghetti',),
#   0.8333333333333334),
#  ('fresh tuna', 'olive oil', 'pancakes', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('french fries', 'fresh tuna', 'pancakes'): (('spaghetti',),
#   0.8571428571428571),
#  ('french wine', 'milk', 'soup'): (('mineral water',), 0.8333333333333334),
#  ('french wine', 'mineral water', 'soup'): (('milk',), 0.8333333333333334),
#  ('chocolate', 'french wine', 'shrimp'): (('spaghetti',), 0.8333333333333334),
#  ('burgers', 'french wine', 'shrimp'): (('spaghetti',), 0.875),
#  ('french wine', 'frozen vegetables', 'milk'): (('mineral water',),
#   0.8571428571428571),
#  ('french wine', 'olive oil', 'pancakes'): (('spaghetti',), 1.0),
#  ('chocolate', 'french wine', 'green tea'): (('spaghetti',),
#   0.8333333333333334),
#  ('eggs', 'french wine', 'ground beef'): (('spaghetti',), 0.875),
#  ('french wine', 'ground beef', 'milk', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('burgers', 'chocolate', 'french wine'): (('spaghetti',), 0.875),
#  ('chocolate', 'herb & pepper', 'oil'): (('ground beef',), 1.0),
#  ('eggs', 'ground beef', 'oil'): (('herb & pepper',), 1.0),
#  ('low fat yogurt', 'oil', 'spaghetti'): (('mineral water',), 1.0),
#  ('frozen smoothie', 'oil', 'shrimp'): (('milk',), 1.0),
#  ('frozen smoothie', 'green tea', 'oil'): (('mineral water',),
#   0.8333333333333334),
#  ('oil', 'shrimp', 'spaghetti'): (('mineral water',), 0.8),
#  ('cake', 'frozen vegetables', 'muffins'): (('spaghetti',),
#   0.8333333333333334),
#  ('cake', 'muffins', 'tomatoes'): (('frozen vegetables',), 1.0),
#  ('cake', 'mineral water', 'muffins'): (('spaghetti',), 0.8333333333333334),
#  ('burgers', 'chocolate', 'muffins'): (('spaghetti',), 0.8333333333333334),
#  ('burgers', 'muffins', 'spaghetti'): (('chocolate',), 0.8333333333333334),
#  ('tomatoes', 'vegetables mix', 'whole wheat rice'): (('spaghetti',),
#   0.8333333333333334),
#  ('frozen vegetables', 'turkey', 'vegetables mix'): (('spaghetti',), 1.0),
#  ('milk', 'turkey', 'vegetables mix'): (('mineral water',), 1.0),
#  ('frozen vegetables',
#   'milk',
#   'mineral water',
#   'vegetables mix'): (('tomatoes',), 0.8571428571428571),
#  ('frozen vegetables',
#   'milk',
#   'tomatoes',
#   'vegetables mix'): (('mineral water',), 0.8571428571428571),
#  ('milk',
#   'mineral water',
#   'tomatoes',
#   'vegetables mix'): (('frozen vegetables',), 0.8571428571428571),
#  ('frozen smoothie', 'green tea', 'vegetables mix'): (('mineral water',),
#   0.8333333333333334),
#  ('cereals', 'frozen smoothie', 'low fat yogurt'): (('mineral water',),
#   0.8333333333333334),
#  ('cereals', 'frozen smoothie', 'spaghetti'): (('milk',), 0.875),
#  ('cereals', 'frozen smoothie', 'milk', 'mineral water'): (('spaghetti',),
#   0.8333333333333334),
#  ('cereals', 'frozen smoothie', 'mineral water', 'spaghetti'): (('milk',),
#   1.0),
#  ('cereals', 'milk', 'soup'): (('mineral water',), 0.8333333333333334),
#  ('cake', 'cereals', 'tomatoes'): (('frozen vegetables',), 0.8333333333333334),
#  ('cereals', 'spaghetti', 'tomatoes'): (('ground beef',), 0.8571428571428571),
#  ('cereals', 'chicken', 'spaghetti'): (('ground beef',), 0.8333333333333334),
#  ('cereals', 'ground beef', 'olive oil'): (('spaghetti',), 0.8571428571428571),
#  ('cereals', 'cooking oil', 'ground beef'): (('spaghetti',),
#   0.8333333333333334),
#  ('cereals', 'chocolate', 'mineral water', 'shrimp'): (('milk',),
#   0.8333333333333334),
#  ('ground beef', 'pepper', 'salmon'): (('spaghetti',), 0.8333333333333334),
#  ('burgers', 'eggs', 'pepper'): (('spaghetti',), 0.8333333333333334),
#  ('frozen smoothie', 'olive oil', 'pepper'): (('spaghetti',),
#   0.8333333333333334),
#  ('energy drink', 'red wine'): (('spaghetti',), 0.8333333333333334),
#  ('energy bar', 'frozen vegetables', 'olive oil'): (('spaghetti',),
#   0.8333333333333334),
#  ('energy bar', 'olive oil', 'spaghetti'): (('frozen vegetables',),
#   0.8333333333333334),
#  ('chocolate', 'energy bar', 'low fat yogurt'): (('mineral water',), 1.0),
#  ('burgers', 'energy bar', 'spaghetti'): (('eggs',), 1.0),
#  ('ham', 'hot dogs'): (('spaghetti',), 0.8571428571428571),
#  ('cooking oil', 'ham', 'mineral water'): (('spaghetti',), 0.8333333333333334),
#  ('cookies', 'eggs', 'ham'): (('burgers',), 1.0),
#  ('cookies', 'green tea', 'ham'): (('burgers',), 0.8333333333333334),
#  ('french fries', 'ham', 'olive oil'): (('mineral water',),
#   0.8333333333333334),
#  ('burgers', 'ground beef', 'ham'): (('spaghetti',), 0.8333333333333334),
#  ('burgers', 'french fries', 'ham', 'spaghetti'): (('chocolate',),
#   0.8571428571428571),
#  ('cookies', 'french fries', 'light mayo'): (('green tea',),
#   0.8333333333333334),
#  ('burgers', 'light mayo', 'milk'): (('ground beef',), 0.8333333333333334),
#  ('escalope', 'milk', 'yogurt cake'): (('mineral water',), 1.0),
#  ('chocolate', 'olive oil', 'yogurt cake'): (('mineral water',),
#   0.8571428571428571),
#  ('ground beef', 'milk', 'yogurt cake'): (('mineral water',),
#   0.8333333333333334),
#  ('chocolate', 'milk', 'yogurt cake'): (('mineral water',),
#   0.8333333333333334),
#  ('cottage cheese', 'red wine'): (('mineral water',), 0.8571428571428571),
#  ('grated cheese', 'herb & pepper', 'red wine'): (('mineral water',),
#   0.8333333333333334),
#  ('milk', 'red wine', 'soup'): (('mineral water',), 1.0),
#  ('eggs', 'red wine', 'soup'): (('mineral water',), 0.8333333333333334),
#  ('red wine', 'soup', 'spaghetti'): (('mineral water',), 0.875),
#  ('chocolate', 'cooking oil', 'red wine'): (('spaghetti',),
#   0.8333333333333334),
#  ('cooking oil', 'eggs', 'red wine'): (('mineral water',), 0.8571428571428571),
#  ('cooking oil', 'eggs', 'mineral water', 'red wine'): (('spaghetti',),
#   0.8333333333333334),
#  ('cooking oil', 'eggs', 'red wine', 'spaghetti'): (('mineral water',), 1.0),
#  ('cooking oil', 'mineral water', 'red wine'): (('spaghetti',), 0.8),
#  ('green tea', 'red wine', 'tomatoes'): (('spaghetti',), 0.8333333333333334),
#  ('eggs', 'red wine', 'turkey'): (('mineral water',), 0.8333333333333334),
#  ('milk', 'red wine', 'turkey'): (('mineral water',), 0.8333333333333334),
#  ('pancakes', 'red wine', 'turkey'): (('mineral water',), 0.875),
#  ('cake', 'milk', 'red wine'): (('mineral water',), 0.8333333333333334),
#  ('chocolate', 'milk', 'red wine'): (('spaghetti',), 0.8333333333333334),
#  ('salmon', 'spaghetti', 'whole wheat pasta'): (('milk',), 1.0),
#  ('mineral water', 'salmon', 'whole wheat pasta'): (('milk',),
#   0.8333333333333334),
#  ('milk', 'turkey', 'whole wheat pasta'): (('mineral water',),
#   0.8333333333333334),
#  ('spaghetti', 'turkey', 'whole wheat pasta'): (('mineral water',), 1.0),
#  ('cooking oil', 'eggs', 'whole wheat pasta'): (('mineral water',),
#   0.8333333333333334),
#  ('cake', 'pancakes', 'whole wheat pasta'): (('mineral water',), 1.0),
#  ('green tea', 'ground beef', 'whole wheat pasta'): (('spaghetti',),
#   0.8571428571428571),
#  ('chocolate',
#   'frozen vegetables',
#   'olive oil',
#   'whole wheat pasta'): (('mineral water',), 1.0),
#  ('chocolate',
#   'frozen vegetables',
#   'milk',
#   'whole wheat pasta'): (('mineral water',), 1.0),
#  ('butter', 'tomato juice', 'tomatoes'): (('frozen vegetables',), 1.0),
#  ('butter', 'chicken', 'ground beef'): (('french fries',), 1.0),
#  ('champagne', 'mineral water', 'tomato juice'): (('green tea',),
#   0.8333333333333334),
#  ('cooking oil', 'green tea', 'tomato juice'): (('mineral water',),
#   0.8333333333333334),
#  ('eggs', 'low fat yogurt', 'tomato juice'): (('spaghetti',),
#   0.8333333333333334),
#  ('cake', 'chocolate', 'tomato juice'): (('mineral water',),
#   0.8333333333333334),
#  ('cottage cheese', 'green tea', 'salmon'): (('mineral water',),
#   0.8333333333333334),
#  ('cottage cheese', 'soup', 'spaghetti'): (('mineral water',), 1.0),
#  ('cottage cheese', 'frozen vegetables', 'olive oil'): (('spaghetti',),
#   0.8333333333333334),
#  ('cottage cheese',
#   'frozen smoothie',
#   'frozen vegetables'): (('mineral water',), 0.8333333333333334),
#  ('cottage cheese', 'eggs', 'milk'): (('mineral water',), 1.0),
#  ('hot dogs', 'milk', 'salmon'): (('mineral water', 'spaghetti'),
#   0.8333333333333334),
#  ('hot dogs', 'milk', 'mineral water', 'salmon'): (('spaghetti',), 1.0),
#  ('hot dogs', 'milk', 'salmon', 'spaghetti'): (('mineral water',), 1.0),
#  ('hot dogs', 'mineral water', 'salmon'): (('spaghetti',), 0.875),
#  ('hot dogs', 'salmon', 'spaghetti'): (('mineral water',), 1.0),
#  ('hot dogs', 'olive oil', 'turkey'): (('spaghetti',), 1.0),
#  ('escalope', 'hot dogs', 'spaghetti'): (('milk',), 0.8333333333333334),
#  ('escalope', 'frozen smoothie', 'hot dogs', 'milk'): (('mineral water',),
#   1.0),
#  ('escalope', 'frozen smoothie', 'hot dogs', 'mineral water'): (('milk',),
#   1.0),
#  ('frozen smoothie', 'hot dogs', 'milk', 'mineral water'): (('escalope',),
#   0.8333333333333334),
#  ('escalope', 'hot dogs', 'milk'): (('mineral water',), 0.8),
#  ('escalope', 'hot dogs', 'mineral water'): (('milk',), 0.8888888888888888),
#  ('hot dogs', 'milk', 'tomatoes'): (('mineral water',), 1.0),
#  ('frozen vegetables',
#   'hot dogs',
#   'olive oil'): (('mineral water', 'spaghetti'), 1.0),
#  ('frozen vegetables',
#   'hot dogs',
#   'mineral water',
#   'olive oil'): (('spaghetti',), 1.0),
#  ('frozen vegetables',
#   'hot dogs',
#   'olive oil',
#   'spaghetti'): (('mineral water',), 1.0),
#  ('hot dogs', 'olive oil', 'pancakes'): (('mineral water', 'spaghetti'),
#   0.8333333333333334),
#  ('hot dogs', 'mineral water', 'olive oil', 'pancakes'): (('spaghetti',), 1.0),
#  ('hot dogs', 'mineral water', 'pancakes', 'spaghetti'): (('olive oil',),
#   0.8333333333333334),
#  ('hot dogs', 'olive oil', 'pancakes', 'spaghetti'): (('mineral water',), 1.0),
#  ('chocolate', 'hot dogs', 'olive oil'): (('mineral water',),
#   0.8571428571428571),
#  ('ground beef', 'hot dogs', 'milk'): (('spaghetti',), 0.8333333333333334),
#  ('green tea', 'ground beef', 'hot dogs'): (('spaghetti',),
#   0.8333333333333334),
#  ('frozen vegetables', 'ground beef', 'hot dogs'): (('mineral water',), 0.875),
#  ('frozen vegetables',
#   'ground beef',
#   'hot dogs',
#   'spaghetti'): (('mineral water',), 1.0),
#  ('frozen vegetables', 'hot dogs', 'milk'): (('spaghetti',),
#   0.8571428571428571),
#  ('chocolate', 'frozen vegetables', 'hot dogs', 'milk'): (('spaghetti',), 1.0),
#  ('chocolate', 'hot dogs', 'milk', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('frozen vegetables', 'hot dogs', 'milk', 'spaghetti'): (('chocolate',),
#   0.8333333333333334),
#  ('frozen vegetables',
#   'green tea',
#   'hot dogs',
#   'mineral water'): (('spaghetti',), 1.0),
#  ('frozen vegetables',
#   'green tea',
#   'hot dogs',
#   'spaghetti'): (('mineral water',), 0.8333333333333334),
#  ('chocolate', 'hot dogs', 'pancakes'): (('mineral water',),
#   0.8333333333333334),
#  ('french fries', 'hot dogs', 'milk'): (('spaghetti',), 0.8333333333333334),
#  ('avocado', 'chocolate', 'cookies'): (('french fries',), 0.8333333333333334),
#  ('avocado', 'grated cheese', 'milk'): (('spaghetti',), 0.8333333333333334),
#  ('avocado', 'frozen vegetables', 'olive oil'): (('spaghetti',), 1.0),
#  ('avocado', 'burgers', 'olive oil'): (('spaghetti',), 1.0),
#  ('avocado', 'chocolate', 'milk', 'olive oil'): (('spaghetti',), 1.0),
#  ('avocado', 'french fries', 'tomatoes'): (('spaghetti',), 0.8571428571428571),
#  ('avocado', 'mineral water', 'soup', 'spaghetti'): (('milk',),
#   0.8333333333333334),
#  ('avocado', 'burgers', 'chocolate', 'milk'): (('spaghetti',), 1.0),
#  ('avocado', 'burgers', 'chocolate', 'spaghetti'): (('milk',),
#   0.8333333333333334),
#  ('avocado', 'frozen vegetables', 'milk', 'mineral water'): (('spaghetti',),
#   0.8333333333333334),
#  ('brownies', 'cookies', 'french fries'): (('pancakes',), 0.8333333333333334),
#  ('brownies', 'eggs', 'milk', 'olive oil'): (('mineral water',), 1.0),
#  ('brownies', 'milk', 'mineral water', 'olive oil'): (('eggs',), 1.0),
#  ('brownies', 'chocolate', 'eggs', 'french fries'): (('spaghetti',),
#   0.8333333333333334),
#  ('brownies', 'chocolate', 'eggs', 'spaghetti'): (('french fries',), 1.0),
#  ('brownies', 'eggs', 'ground beef'): (('mineral water',), 0.8888888888888888),
#  ('brownies', 'french fries', 'mineral water', 'spaghetti'): (('eggs',),
#   0.8333333333333334),
#  ('fresh bread', 'salmon', 'spaghetti'): (('mineral water',),
#   0.8571428571428571),
#  ('grated cheese', 'salmon', 'whole wheat rice'): (('mineral water',),
#   0.8333333333333334),
#  ('escalope', 'ground beef', 'salmon'): (('spaghetti',), 0.8333333333333334),
#  ('escalope', 'milk', 'salmon', 'spaghetti'): (('mineral water',), 1.0),
#  ('escalope', 'mineral water', 'salmon', 'spaghetti'): (('milk',),
#   0.8333333333333334),
#  ('honey', 'salmon', 'shrimp'): (('mineral water',), 0.8333333333333334),
#  ('cooking oil', 'olive oil', 'salmon'): (('spaghetti',), 0.8333333333333334),
#  ('cooking oil', 'ground beef', 'salmon'): (('spaghetti',),
#   0.8333333333333334),
#  ('chicken', 'ground beef', 'salmon'): (('spaghetti',), 1.0),
#  ('chicken', 'chocolate', 'ground beef', 'salmon'): (('spaghetti',), 1.0),
#  ('chicken', 'chocolate', 'salmon', 'spaghetti'): (('ground beef',), 1.0),
#  ('burgers', 'milk', 'salmon'): (('spaghetti',), 0.8888888888888888),
#  ('ground beef', 'salmon', 'shrimp'): (('spaghetti',), 0.8888888888888888),
#  ('ground beef', 'mineral water', 'salmon', 'shrimp'): (('spaghetti',), 1.0),
#  ('milk', 'salmon', 'shrimp', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('frozen smoothie', 'frozen vegetables', 'salmon'): (('spaghetti',), 1.0),
#  ('frozen smoothie', 'milk', 'mineral water', 'salmon'): (('spaghetti',),
#   0.8571428571428571),
#  ('frozen smoothie', 'milk', 'salmon', 'spaghetti'): (('mineral water',),
#   0.8571428571428571),
#  ('chocolate', 'frozen smoothie', 'mineral water', 'salmon'): (('spaghetti',),
#   0.8333333333333334),
#  ('green tea', 'olive oil', 'salmon'): (('mineral water',), 1.0),
#  ('french fries', 'olive oil', 'salmon'): (('milk',), 0.8333333333333334),
#  ('milk', 'mineral water', 'olive oil', 'salmon'): (('spaghetti',),
#   0.8571428571428571),
#  ('chocolate', 'ground beef', 'mineral water', 'salmon'): (('spaghetti',),
#   0.8571428571428571),
#  ('fresh bread', 'pancakes', 'whole wheat rice'): (('chocolate',), 1.0),
#  ('fresh bread', 'frozen smoothie', 'ground beef'): (('chocolate',),
#   0.8333333333333334),
#  ('fresh bread', 'green tea', 'olive oil'): (('mineral water',),
#   0.8571428571428571),
#  ('chocolate', 'fresh bread', 'olive oil', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('chicken', 'fresh bread', 'pancakes', 'spaghetti'): (('mineral water',),
#   1.0),
#  ('chicken', 'chocolate', 'fresh bread', 'pancakes'): (('mineral water',),
#   1.0),
#  ('fresh bread', 'green tea', 'milk'): (('mineral water',),
#   0.8571428571428571),
#  ('cake', 'champagne', 'frozen vegetables'): (('french fries',), 1.0),
#  ('cake', 'champagne', 'mineral water'): (('french fries',), 1.0),
#  ('champagne', 'chocolate', 'whole wheat rice'): (('mineral water',),
#   0.8333333333333334),
#  ('champagne', 'frozen smoothie', 'frozen vegetables'): (('spaghetti',),
#   0.8571428571428571),
#  ('honey', 'soup', 'tomatoes'): (('milk',), 0.8333333333333334),
#  ('cooking oil', 'honey', 'pancakes'): (('mineral water',), 1.0),
#  ('honey', 'shrimp', 'turkey'): (('olive oil',), 0.8333333333333334),
#  ('ground beef', 'honey', 'shrimp'): (('spaghetti',), 0.8333333333333334),
#  ('frozen vegetables',
#   'herb & pepper',
#   'whole wheat rice'): (('mineral water',), 0.8333333333333334),
#  ('herb & pepper', 'pancakes', 'soup'): (('mineral water',), 1.0),
#  ('burgers', 'grated cheese', 'herb & pepper'): (('ground beef',),
#   0.8571428571428571),
#  ('burgers',
#   'frozen vegetables',
#   'ground beef',
#   'herb & pepper'): (('mineral water',), 1.0),
#  ('burgers',
#   'frozen vegetables',
#   'herb & pepper',
#   'mineral water'): (('ground beef',), 1.0),
#  ('herb & pepper', 'olive oil', 'tomatoes'): (('spaghetti',), 1.0),
#  ('eggs', 'herb & pepper', 'mineral water', 'tomatoes'): (('spaghetti',), 1.0),
#  ('eggs', 'herb & pepper', 'spaghetti', 'tomatoes'): (('mineral water',),
#   0.8333333333333334),
#  ('frozen vegetables',
#   'herb & pepper',
#   'mineral water',
#   'tomatoes'): (('spaghetti',), 1.0),
#  ('frozen vegetables',
#   'herb & pepper',
#   'spaghetti',
#   'tomatoes'): (('mineral water',), 0.8571428571428571),
#  ('eggs', 'herb & pepper', 'milk', 'turkey'): (('mineral water',),
#   0.8333333333333334),
#  ('ground beef', 'herb & pepper', 'milk', 'turkey'): (('eggs',),
#   0.8333333333333334),
#  ('herb & pepper', 'milk', 'mineral water', 'turkey'): (('eggs',),
#   0.8333333333333334),
#  ('chicken', 'herb & pepper', 'milk', 'mineral water'): (('ground beef',),
#   0.8333333333333334),
#  ('cooking oil', 'green tea', 'herb & pepper'): (('spaghetti',),
#   0.8333333333333334),
#  ('herb & pepper', 'low fat yogurt', 'pancakes'): (('spaghetti',), 0.875),
#  ('frozen vegetables',
#   'herb & pepper',
#   'milk',
#   'spaghetti'): (('mineral water',), 0.8571428571428571),
#  ('eggs', 'frozen vegetables', 'herb & pepper', 'milk'): (('mineral water',),
#   0.8571428571428571),
#  ('eggs',
#   'frozen vegetables',
#   'herb & pepper',
#   'milk',
#   'mineral water'): (('spaghetti',), 0.8333333333333334),
#  ('eggs',
#   'frozen vegetables',
#   'herb & pepper',
#   'milk',
#   'spaghetti'): (('mineral water',), 1.0),
#  ('eggs',
#   'herb & pepper',
#   'milk',
#   'mineral water',
#   'spaghetti'): (('frozen vegetables',), 1.0),
#  ('frozen vegetables',
#   'herb & pepper',
#   'milk',
#   'mineral water',
#   'spaghetti'): (('eggs',), 0.8333333333333334),
#  ('eggs',
#   'frozen vegetables',
#   'herb & pepper',
#   'spaghetti'): (('mineral water',), 0.875),
#  ('french fries', 'herb & pepper', 'milk', 'pancakes'): (('mineral water',),
#   1.0),
#  ('french fries', 'herb & pepper', 'mineral water', 'pancakes'): (('milk',),
#   0.8571428571428571),
#  ('french fries',
#   'herb & pepper',
#   'pancakes',
#   'spaghetti'): (('mineral water',), 0.8333333333333334),
#  ('french fries', 'herb & pepper', 'milk'): (('mineral water',),
#   0.8181818181818182),
#  ('french fries', 'herb & pepper', 'milk', 'spaghetti'): (('mineral water',),
#   1.0),
#  ('herb & pepper', 'mineral water', 'shrimp', 'spaghetti'): (('ground beef',),
#   0.875),
#  ('frozen smoothie', 'ground beef', 'soup'): (('mineral water',),
#   0.8333333333333334),
#  ('french fries', 'grated cheese', 'soup'): (('mineral water',),
#   0.8333333333333334),
#  ('frozen vegetables', 'grated cheese', 'soup'): (('mineral water',), 1.0),
#  ('grated cheese', 'milk', 'soup'): (('mineral water',), 0.8571428571428571),
#  ('pancakes', 'soup', 'whole wheat rice'): (('mineral water',), 1.0),
#  ('olive oil', 'soup', 'turkey'): (('spaghetti',), 0.8333333333333334),
#  ('chocolate', 'soup', 'turkey'): (('mineral water',), 0.8888888888888888),
#  ('chocolate', 'soup', 'spaghetti', 'turkey'): (('mineral water',), 1.0),
#  ('milk', 'soup', 'spaghetti', 'turkey'): (('mineral water',),
#   0.8333333333333334),
#  ('cooking oil', 'eggs', 'soup', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('chocolate', 'olive oil', 'shrimp', 'soup'): (('mineral water',), 1.0),
#  ('chocolate', 'milk', 'shrimp', 'soup'): (('mineral water',),
#   0.8333333333333334),
#  ('milk', 'shrimp', 'soup', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('frozen vegetables', 'low fat yogurt', 'soup'): (('ground beef',),
#   0.8571428571428571),
#  ('frozen vegetables', 'ground beef', 'low fat yogurt', 'soup'): (('milk',),
#   0.8333333333333334),
#  ('frozen vegetables', 'low fat yogurt', 'milk', 'soup'): (('ground beef',),
#   1.0),
#  ('burgers', 'chicken', 'soup'): (('spaghetti',), 0.8333333333333334),
#  ('chicken', 'frozen vegetables', 'milk', 'soup'): (('spaghetti',),
#   0.8333333333333334),
#  ('chicken', 'frozen vegetables', 'soup', 'spaghetti'): (('milk',),
#   0.8333333333333334),
#  ('chicken', 'mineral water', 'olive oil', 'soup'): (('milk',),
#   0.8571428571428571),
#  ('chicken', 'olive oil', 'soup', 'spaghetti'): (('milk',),
#   0.8571428571428571),
#  ('chicken', 'chocolate', 'ground beef', 'soup'): (('milk',),
#   0.8571428571428571),
#  ('cake', 'milk', 'soup', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('chocolate', 'milk', 'soup', 'tomatoes'): (('mineral water',),
#   0.8333333333333334),
#  ('frozen vegetables', 'mineral water', 'soup', 'tomatoes'): (('milk',),
#   0.875),
#  ('frozen vegetables', 'milk', 'olive oil', 'soup'): (('mineral water',),
#   0.8181818181818182),
#  ('cookies', 'cooking oil', 'pancakes'): (('mineral water',),
#   0.8333333333333334),
#  ('cooking oil', 'frozen smoothie', 'pancakes'): (('mineral water',),
#   0.8333333333333334),
#  ('cooking oil', 'eggs', 'milk', 'olive oil'): (('mineral water',),
#   0.8333333333333334),
#  ('chocolate', 'cooking oil', 'eggs', 'olive oil'): (('mineral water',),
#   0.8571428571428571),
#  ('chocolate', 'cooking oil', 'mineral water', 'olive oil'): (('eggs',),
#   0.8571428571428571),
#  ('chicken', 'cooking oil', 'escalope'): (('spaghetti',), 0.8333333333333334),
#  ('cooking oil', 'escalope', 'pancakes', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('chocolate', 'cooking oil', 'escalope', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('cooking oil', 'pancakes', 'whole wheat rice'): (('mineral water',),
#   0.8333333333333334),
#  ('burgers', 'chicken', 'cooking oil'): (('eggs',), 0.8333333333333334),
#  ('chocolate', 'cooking oil', 'frozen vegetables', 'ground beef'): (('milk',),
#   0.8333333333333334),
#  ('cooking oil', 'frozen vegetables', 'ground beef', 'milk'): (('chocolate',),
#   0.8333333333333334),
#  ('chocolate', 'cooking oil', 'eggs', 'frozen vegetables'): (('milk',),
#   0.8333333333333334),
#  ('cooking oil', 'eggs', 'pancakes', 'spaghetti'): (('mineral water',),
#   0.8571428571428571),
#  ('cooking oil', 'eggs', 'ground beef', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('chocolate', 'cooking oil', 'eggs', 'ground beef'): (('mineral water',),
#   1.0),
#  ('frozen smoothie', 'grated cheese', 'pancakes'): (('spaghetti',),
#   0.8333333333333334),
#  ('french fries', 'grated cheese', 'tomatoes'): (('spaghetti',), 1.0),
#  ('frozen vegetables',
#   'grated cheese',
#   'olive oil',
#   'spaghetti'): (('tomatoes',), 1.0),
#  ('frozen vegetables',
#   'grated cheese',
#   'olive oil',
#   'tomatoes'): (('spaghetti',), 0.8333333333333334),
#  ('frozen vegetables',
#   'grated cheese',
#   'spaghetti',
#   'tomatoes'): (('olive oil',), 1.0),
#  ('grated cheese',
#   'olive oil',
#   'spaghetti',
#   'tomatoes'): (('frozen vegetables',), 0.8333333333333334),
#  ('escalope', 'grated cheese', 'pancakes'): (('mineral water',),
#   0.8333333333333334),
#  ('grated cheese', 'ground beef', 'milk', 'turkey'): (('mineral water',),
#   0.8571428571428571),
#  ('grated cheese', 'ground beef', 'mineral water', 'turkey'): (('milk',),
#   0.8571428571428571),
#  ('burgers', 'grated cheese', 'olive oil'): (('mineral water',),
#   0.8333333333333334),
#  ('frozen vegetables', 'grated cheese', 'pancakes'): (('mineral water',),
#   0.8333333333333334),
#  ('frozen vegetables',
#   'grated cheese',
#   'ground beef',
#   'milk'): (('mineral water',), 0.8333333333333334),
#  ('frozen vegetables',
#   'grated cheese',
#   'ground beef',
#   'mineral water'): (('milk',), 0.8333333333333334),
#  ('olive oil', 'tomatoes', 'whole wheat rice'): (('spaghetti',), 1.0),
#  ('chicken', 'tomatoes', 'whole wheat rice'): (('mineral water',), 1.0),
#  ('ground beef',
#   'shrimp',
#   'spaghetti',
#   'whole wheat rice'): (('mineral water',), 0.8333333333333334),
#  ('ground beef',
#   'tomatoes',
#   'whole wheat rice'): (('mineral water', 'spaghetti'), 0.8333333333333334),
#  ('ground beef',
#   'mineral water',
#   'tomatoes',
#   'whole wheat rice'): (('spaghetti',), 1.0),
#  ('ground beef',
#   'spaghetti',
#   'tomatoes',
#   'whole wheat rice'): (('mineral water',), 0.8333333333333334),
#  ('chocolate', 'tomatoes', 'whole wheat rice'): (('spaghetti',),
#   0.8571428571428571),
#  ('chocolate', 'milk', 'tomatoes', 'whole wheat rice'): (('spaghetti',), 1.0),
#  ('chocolate', 'spaghetti', 'tomatoes', 'whole wheat rice'): (('milk',),
#   0.8333333333333334),
#  ('frozen vegetables',
#   'milk',
#   'mineral water',
#   'tomatoes',
#   'whole wheat rice'): (('spaghetti',), 0.8333333333333334),
#  ('frozen vegetables',
#   'milk',
#   'spaghetti',
#   'tomatoes',
#   'whole wheat rice'): (('mineral water',), 0.8333333333333334),
#  ('burgers', 'french fries', 'spaghetti', 'whole wheat rice'): (('chocolate',),
#   0.8333333333333334),
#  ('burgers', 'chocolate', 'eggs', 'whole wheat rice'): (('spaghetti',),
#   0.8571428571428571),
#  ('burgers', 'eggs', 'spaghetti', 'whole wheat rice'): (('chocolate',),
#   0.8571428571428571),
#  ('chocolate',
#   'frozen vegetables',
#   'spaghetti',
#   'whole wheat rice'): (('milk',), 0.8333333333333334),
#  ('chicken', 'escalope', 'pancakes'): (('spaghetti',), 0.8333333333333334),
#  ('cake', 'chicken', 'milk', 'turkey'): (('mineral water',), 1.0),
#  ('cake', 'chicken', 'mineral water', 'turkey'): (('milk',),
#   0.8333333333333334),
#  ('chicken', 'eggs', 'milk', 'turkey'): (('mineral water',), 1.0),
#  ('chicken', 'eggs', 'spaghetti', 'turkey'): (('mineral water',), 1.0),
#  ('chicken', 'mineral water', 'olive oil', 'shrimp'): (('spaghetti',), 0.875),
#  ('chicken', 'olive oil', 'shrimp', 'spaghetti'): (('mineral water',), 0.875),
#  ('chicken', 'pancakes', 'shrimp', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('chicken', 'milk', 'mineral water', 'shrimp'): (('spaghetti',),
#   0.8333333333333334),
#  ('chicken', 'chocolate', 'shrimp', 'spaghetti'): (('mineral water',), 0.875),
#  ('burgers', 'chicken', 'olive oil'): (('milk',), 0.8333333333333334),
#  ('burgers', 'chicken', 'ground beef'): (('chocolate',), 0.8333333333333334),
#  ('cake', 'chicken', 'olive oil'): (('mineral water',), 0.8333333333333334),
#  ('cake', 'chicken', 'milk', 'spaghetti'): (('mineral water',), 1.0),
#  ('chicken', 'chocolate', 'frozen smoothie', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('chicken', 'frozen vegetables', 'milk', 'olive oil'): (('spaghetti',),
#   0.875),
#  ('chicken', 'chocolate', 'frozen vegetables', 'ground beef'): (('milk',),
#   0.8333333333333334),
#  ('chicken', 'eggs', 'frozen vegetables', 'ground beef'): (('milk',),
#   0.8333333333333334),
#  ('chicken', 'chocolate', 'eggs', 'frozen vegetables'): (('mineral water',),
#   0.8333333333333334),
#  ('chicken', 'ground beef', 'milk', 'pancakes'): (('mineral water',),
#   0.8333333333333334),
#  ('cake', 'frozen smoothie', 'turkey'): (('mineral water',),
#   0.8333333333333334),
#  ('low fat yogurt', 'shrimp', 'turkey'): (('spaghetti',), 0.8333333333333334),
#  ('low fat yogurt', 'milk', 'turkey'): (('eggs',), 0.8571428571428571),
#  ('frozen vegetables', 'milk', 'olive oil', 'turkey'): (('mineral water',),
#   1.0),
#  ('ground beef', 'shrimp', 'turkey'): (('spaghetti',), 0.8333333333333334),
#  ('frozen vegetables',
#   'mineral water',
#   'tomatoes',
#   'turkey'): (('milk', 'spaghetti'), 1.0),
#  ('frozen vegetables', 'spaghetti', 'tomatoes', 'turkey'): (('milk',),
#   0.8333333333333334),
#  ('frozen vegetables', 'milk', 'tomatoes', 'turkey'): (('spaghetti',),
#   0.8333333333333334),
#  ('frozen vegetables',
#   'milk',
#   'mineral water',
#   'tomatoes',
#   'turkey'): (('spaghetti',), 1.0),
#  ('frozen vegetables',
#   'milk',
#   'spaghetti',
#   'tomatoes',
#   'turkey'): (('mineral water',), 1.0),
#  ('frozen vegetables',
#   'mineral water',
#   'spaghetti',
#   'tomatoes',
#   'turkey'): (('milk',), 1.0),
#  ('milk', 'mineral water', 'tomatoes', 'turkey'): (('spaghetti',), 0.875),
#  ('burgers', 'cake', 'milk', 'turkey'): (('mineral water',),
#   0.8571428571428571),
#  ('cake', 'eggs', 'milk', 'turkey'): (('mineral water',), 0.8),
#  ('burgers',
#   'frozen vegetables',
#   'ground beef',
#   'turkey'): (('mineral water',), 1.0),
#  ('burgers', 'frozen vegetables', 'milk', 'turkey'): (('mineral water',), 1.0),
#  ('frozen vegetables', 'ground beef', 'milk', 'turkey'): (('mineral water',),
#   0.875),
#  ('eggs', 'frozen vegetables', 'milk', 'turkey'): (('mineral water',),
#   0.8571428571428571),
#  ('frozen vegetables', 'milk', 'spaghetti', 'turkey'): (('mineral water',),
#   0.9),
#  ('eggs', 'ground beef', 'mineral water', 'turkey'): (('milk',), 1.0),
#  ('frozen smoothie', 'milk', 'mineral water', 'tomatoes'): (('spaghetti',),
#   0.8333333333333334),
#  ('frozen smoothie', 'frozen vegetables', 'olive oil'): (('spaghetti',),
#   0.8571428571428571),
#  ('frozen smoothie', 'frozen vegetables', 'milk', 'shrimp'): (('spaghetti',),
#   0.8333333333333334),
#  ('frozen smoothie', 'milk', 'mineral water', 'shrimp'): (('spaghetti',),
#   0.875),
#  ('frozen smoothie', 'milk', 'shrimp', 'spaghetti'): (('mineral water',),
#   0.875),
#  ('frozen smoothie',
#   'frozen vegetables',
#   'mineral water',
#   'shrimp'): (('spaghetti',), 0.8333333333333334),
#  ('frozen smoothie', 'ground beef', 'milk', 'spaghetti'): (('mineral water',),
#   0.8571428571428571),
#  ('french fries',
#   'frozen smoothie',
#   'pancakes',
#   'spaghetti'): (('mineral water',), 0.8333333333333334),
#  ('burgers', 'ground beef', 'olive oil'): (('milk',), 0.8),
#  ('burgers', 'mineral water', 'olive oil', 'shrimp'): (('spaghetti',),
#   0.8333333333333334),
#  ('burgers', 'frozen vegetables', 'olive oil'): (('mineral water',),
#   0.8181818181818182),
#  ('burgers', 'chocolate', 'french fries', 'olive oil'): (('spaghetti',), 1.0),
#  ('burgers', 'cake', 'olive oil', 'spaghetti'): (('chocolate',),
#   0.8333333333333334),
#  ('burgers',
#   'mineral water',
#   'olive oil',
#   'pancakes'): (('chocolate', 'spaghetti'), 0.8333333333333334),
#  ('burgers',
#   'chocolate',
#   'mineral water',
#   'olive oil',
#   'pancakes'): (('spaghetti',), 1.0),
#  ('burgers',
#   'mineral water',
#   'olive oil',
#   'pancakes',
#   'spaghetti'): (('chocolate',), 0.8333333333333334),
#  ('cake', 'olive oil', 'shrimp'): (('mineral water',), 1.0),
#  ('cake', 'eggs', 'olive oil', 'shrimp'): (('mineral water',), 1.0),
#  ('cake', 'chocolate', 'frozen vegetables', 'olive oil'): (('mineral water',),
#   0.8333333333333334),
#  ('eggs', 'olive oil', 'tomatoes'): (('milk',), 0.8333333333333334),
#  ('mineral water', 'olive oil', 'pancakes', 'tomatoes'): (('spaghetti',),
#   0.8571428571428571),
#  ('green tea', 'ground beef', 'olive oil', 'tomatoes'): (('spaghetti',),
#   0.8333333333333334),
#  ('frozen vegetables', 'green tea', 'olive oil', 'tomatoes'): (('spaghetti',),
#   0.8571428571428571),
#  ('frozen vegetables',
#   'ground beef',
#   'olive oil',
#   'tomatoes'): (('spaghetti',), 0.8333333333333334),
#  ('chocolate', 'milk', 'olive oil', 'tomatoes'): (('spaghetti',), 1.0),
#  ('frozen vegetables', 'milk', 'olive oil', 'tomatoes'): (('spaghetti',), 1.0),
#  ('frozen vegetables',
#   'milk',
#   'mineral water',
#   'olive oil',
#   'tomatoes'): (('spaghetti',), 1.0),
#  ('milk',
#   'mineral water',
#   'olive oil',
#   'spaghetti',
#   'tomatoes'): (('frozen vegetables',), 0.8333333333333334),
#  ('chocolate', 'frozen vegetables', 'olive oil', 'tomatoes'): (('spaghetti',),
#   1.0),
#  ('frozen vegetables',
#   'mineral water',
#   'olive oil',
#   'tomatoes'): (('spaghetti',), 0.8),
#  ('mineral water', 'olive oil', 'pancakes', 'shrimp'): (('spaghetti',),
#   0.8571428571428571),
#  ('olive oil', 'pancakes', 'shrimp', 'spaghetti'): (('mineral water',),
#   0.8571428571428571),
#  ('frozen vegetables',
#   'olive oil',
#   'shrimp',
#   'spaghetti'): (('mineral water',), 0.875),
#  ('chocolate',
#   'frozen vegetables',
#   'olive oil',
#   'shrimp',
#   'spaghetti'): (('mineral water',), 1.0),
#  ('chocolate',
#   'frozen vegetables',
#   'olive oil',
#   'shrimp'): (('mineral water',), 0.9),
#  ('french fries', 'olive oil', 'pancakes', 'spaghetti'): (('mineral water',),
#   0.8333333333333334),
#  ('chocolate', 'french fries', 'mineral water', 'olive oil'): (('spaghetti',),
#   0.8),
#  ('chocolate', 'frozen vegetables', 'green tea', 'olive oil'): (('spaghetti',),
#   1.0),
#  ('chocolate', 'eggs', 'frozen vegetables', 'olive oil'): (('mineral water',),
#   0.875),
#  ('chocolate',
#   'eggs',
#   'frozen vegetables',
#   'milk',
#   'olive oil'): (('mineral water',), 1.0),
#  ('chocolate', 'eggs', 'milk', 'olive oil'): (('mineral water',), 0.8),
#  ('chocolate', 'eggs', 'olive oil', 'spaghetti'): (('mineral water',),
#   0.8181818181818182),
#  ('escalope', 'shrimp', 'tomatoes'): (('chocolate',), 0.8333333333333334),
#  ('frozen vegetables', 'ground beef', 'shrimp', 'tomatoes'): (('spaghetti',),
#   1.0),
#  ('frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'tomatoes'): (('spaghetti',), 0.8181818181818182),
#  ('escalope', 'french fries', 'shrimp'): (('chocolate',), 0.8888888888888888),
#  ('cake', 'ground beef', 'shrimp'): (('spaghetti',), 0.8571428571428571),
#  ('cake', 'chocolate', 'eggs', 'shrimp'): (('mineral water',), 1.0),
#  ('burgers', 'eggs', 'french fries', 'shrimp'): (('chocolate',),
#   0.8333333333333334),
#  ('burgers', 'eggs', 'shrimp', 'spaghetti'): (('chocolate',), 0.875),
#  ('french fries', 'frozen vegetables', 'mineral water', 'shrimp'): (('milk',),
#   0.8333333333333334),
#  ('eggs', 'french fries', 'mineral water', 'shrimp'): (('chocolate',),
#   0.8333333333333334),
#  ('chocolate', 'green tea', 'pancakes', 'shrimp'): (('mineral water',),
#   0.8333333333333334),
#  ('green tea', 'mineral water', 'pancakes', 'shrimp'): (('chocolate',),
#   0.8333333333333334),
#  ('frozen vegetables', 'pancakes', 'shrimp', 'spaghetti'): (('mineral water',),
#   0.8571428571428571),
#  ('chocolate',
#   'frozen vegetables',
#   'pancakes',
#   'shrimp',
#   'spaghetti'): (('mineral water',), 1.0),
#  ('frozen vegetables',
#   'mineral water',
#   'pancakes',
#   'shrimp',
#   'spaghetti'): (('chocolate',), 0.8333333333333334),
#  ('frozen vegetables',
#   'milk',
#   'mineral water',
#   'pancakes',
#   'shrimp'): (('chocolate',), 1.0),
#  ('chocolate', 'frozen vegetables', 'pancakes', 'shrimp'): (('mineral water',),
#   0.8),
#  ('frozen vegetables',
#   'ground beef',
#   'milk',
#   'shrimp'): (('mineral water', 'spaghetti'), 0.8333333333333334),
#  ('frozen vegetables',
#   'ground beef',
#   'milk',
#   'mineral water',
#   'shrimp'): (('spaghetti',), 1.0),
#  ('frozen vegetables',
#   'ground beef',
#   'milk',
#   'shrimp',
#   'spaghetti'): (('mineral water',), 0.8333333333333334),
#  ('chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'shrimp'): (('spaghetti',), 0.8333333333333334),
#  ('chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'shrimp',
#   'spaghetti'): (('mineral water',), 1.0),
#  ('chocolate',
#   'ground beef',
#   'mineral water',
#   'shrimp',
#   'spaghetti'): (('frozen vegetables',), 0.8333333333333334),
#  ('frozen vegetables',
#   'ground beef',
#   'mineral water',
#   'shrimp'): (('spaghetti',), 0.8666666666666667),
#  ('frozen vegetables', 'milk', 'shrimp', 'spaghetti'): (('mineral water',),
#   0.8461538461538461),
#  ('chocolate',
#   'frozen vegetables',
#   'milk',
#   'shrimp',
#   'spaghetti'): (('mineral water',), 1.0),
#  ('chocolate',
#   'frozen vegetables',
#   'shrimp',
#   'spaghetti'): (('mineral water',), 0.8666666666666667),
#  ('chocolate', 'milk', 'shrimp', 'spaghetti'): (('mineral water',),
#   0.8181818181818182),
#  ('escalope', 'low fat yogurt', 'pancakes'): (('spaghetti',),
#   0.8571428571428571),
#  ('burgers', 'chocolate', 'french fries', 'low fat yogurt'): (('eggs',), 1.0),
#  ('burgers', 'eggs', 'french fries', 'low fat yogurt'): (('chocolate',),
#   0.8571428571428571),
#  ('burgers', 'french fries', 'low fat yogurt', 'spaghetti'): (('eggs',),
#   0.8333333333333334),
#  ('burgers', 'low fat yogurt', 'milk', 'mineral water'): (('eggs',),
#   0.8333333333333334),
#  ('chocolate',
#   'frozen vegetables',
#   'ground beef',
#   'low fat yogurt'): (('milk',), 1.0),
#  ('eggs', 'french fries', 'frozen vegetables', 'low fat yogurt'): (('milk',),
#   0.8333333333333334),
#  ('french fries',
#   'frozen vegetables',
#   'low fat yogurt',
#   'mineral water'): (('spaghetti',), 0.8333333333333334),
#  ('chocolate', 'frozen vegetables', 'low fat yogurt', 'spaghetti'): (('milk',),
#   0.8571428571428571),
#  ('eggs', 'frozen vegetables', 'low fat yogurt', 'spaghetti'): (('milk',),
#   1.0),
#  ('eggs', 'french fries', 'low fat yogurt', 'mineral water'): (('spaghetti',),
#   1.0),
#  ('escalope', 'green tea', 'milk', 'mineral water'): (('chocolate',), 1.0),
#  ('cookies', 'milk', 'spaghetti'): (('french fries',), 1.0),
#  ('cookies', 'green tea', 'milk', 'spaghetti'): (('french fries',), 1.0),
#  ('burgers', 'cookies', 'milk'): (('french fries',), 0.875),
#  ('cookies', 'green tea', 'milk'): (('french fries',), 0.8),
#  ('burgers', 'cake', 'eggs', 'ground beef'): (('milk',), 0.8333333333333334),
#  ('cake', 'eggs', 'ground beef', 'milk'): (('burgers',), 0.8333333333333334),
#  ('cake',
#   'chocolate',
#   'french fries',
#   'frozen vegetables'): (('mineral water',), 1.0),
#  ('cake', 'eggs', 'frozen vegetables', 'milk'): (('mineral water',), 0.875),
#  ('burgers', 'cake', 'chocolate', 'french fries'): (('mineral water',), 0.875),
#  ('cake', 'milk', 'mineral water', 'pancakes'): (('spaghetti',),
#   0.8571428571428571),
#  ('cake', 'milk', 'pancakes', 'spaghetti'): (('mineral water',),
#   0.8571428571428571),
#  ('burgers', 'french fries', 'mineral water', 'pancakes'): (('spaghetti',),
#   0.8571428571428571),
#  ('burgers', 'chocolate', 'frozen vegetables', 'pancakes'): (('spaghetti',),
#   1.0),
#  ('burgers',
#   'frozen vegetables',
#   'mineral water',
#   'pancakes'): (('spaghetti',), 1.0),
#  ('burgers', 'frozen vegetables', 'ground beef', 'milk'): (('mineral water',),
#   0.8333333333333334),
#  ('burgers', 'eggs', 'frozen vegetables', 'milk'): (('mineral water',),
#   0.8333333333333334),
#  ('french fries', 'milk', 'pancakes', 'spaghetti'): (('mineral water',), 0.8),
#  ('chocolate',
#   'eggs',
#   'frozen vegetables',
#   'ground beef',
#   'milk'): (('mineral water',), 1.0),
#  ('chocolate',
#   'ground beef',
#   'milk',
#   'mineral water',
#   'spaghetti'): (('frozen vegetables',), 0.8888888888888888)}
